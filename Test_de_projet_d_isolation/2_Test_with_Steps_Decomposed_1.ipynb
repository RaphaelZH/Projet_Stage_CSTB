# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Importation-of-necessary-libraries" data-toc-modified-id="Importation-of-necessary-libraries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Importation of necessary libraries</a></span></li><li><span><a href="#Extraction-of-data-from-CSV-files" data-toc-modified-id="Extraction-of-data-from-CSV-files-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Extraction of data from CSV files</a></span></li><li><span><a href="#Combination-of-all-the-necessary-data" data-toc-modified-id="Combination-of-all-the-necessary-data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Combination of all the necessary data</a></span><ul class="toc-item"><li><span><a href="#Class-for-all-types-of-dwellings" data-toc-modified-id="Class-for-all-types-of-dwellings-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Class for all types of dwellings</a></span></li><li><span><a href="#Class-for-the-CID-type-dwellings" data-toc-modified-id="Class-for-the-CID-type-dwellings-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Class for the CID type dwellings</a></span></li><li><span><a href="#Class-for-the-CCD-type-dwellings" data-toc-modified-id="Class-for-the-CCD-type-dwellings-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Class for the CCD type dwellings</a></span></li><li><span><a href="#Class-for-the-ID-type-dwellings" data-toc-modified-id="Class-for-the-ID-type-dwellings-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Class for the ID type dwellings</a></span></li><li><span><a href="#Class-instantiation-for-each-type-of-dwelling" data-toc-modified-id="Class-instantiation-for-each-type-of-dwelling-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Class instantiation for each type of dwelling</a></span></li><li><span><a href="#Data-retention" data-toc-modified-id="Data-retention-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Data retention</a></span></li></ul></li><li><span><a href="#Creation-of-some-calculable-columns" data-toc-modified-id="Creation-of-some-calculable-columns-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Creation of some calculable columns</a></span><ul class="toc-item"><li><span><a href="#Class-for-all-types-of-dwellings" data-toc-modified-id="Class-for-all-types-of-dwellings-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Class for all types of dwellings</a></span></li><li><span><a href="#Class-for-the-collective-dwellings" data-toc-modified-id="Class-for-the-collective-dwellings-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Class for the collective dwellings</a></span><ul class="toc-item"><li><span><a href="#Class-for-the-DataFrame-with-U-Factors" data-toc-modified-id="Class-for-the-DataFrame-with-U-Factors-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Class for the DataFrame with U Factors</a></span></li><li><span><a href="#Class-for-the-DataFrame-with-U-Prices" data-toc-modified-id="Class-for-the-DataFrame-with-U-Prices-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Class for the DataFrame with U Prices</a></span></li></ul></li><li><span><a href="#Class-for-the-individual-dwellings" data-toc-modified-id="Class-for-the-individual-dwellings-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Class for the individual dwellings</a></span><ul class="toc-item"><li><span><a href="#Class-for-the-DataFrame-with-U-Factors" data-toc-modified-id="Class-for-the-DataFrame-with-U-Factors-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Class for the DataFrame with U Factors</a></span></li><li><span><a href="#Class-for-the-DataFrame-with-U-Prices" data-toc-modified-id="Class-for-the-DataFrame-with-U-Prices-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Class for the DataFrame with U Prices</a></span></li></ul></li><li><span><a href="#Class-instantiation-for-each-type-of-dwelling" data-toc-modified-id="Class-instantiation-for-each-type-of-dwelling-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Class instantiation for each type of dwelling</a></span></li></ul></li><li><span><a href="#Creation-of-some-calculable-DataFrames" data-toc-modified-id="Creation-of-some-calculable-DataFrames-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Creation of some calculable DataFrames</a></span><ul class="toc-item"><li><span><a href="#Class-for-all-types-of-dwellings" data-toc-modified-id="Class-for-all-types-of-dwellings-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Class for all types of dwellings</a></span></li><li><span><a href="#Class-for-the-CID-type-dwellings" data-toc-modified-id="Class-for-the-CID-type-dwellings-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Class for the CID type dwellings</a></span><ul class="toc-item"><li><span><a href="#Class-for-the-DataFrame-with-U-Factors" data-toc-modified-id="Class-for-the-DataFrame-with-U-Factors-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Class for the DataFrame with U Factors</a></span></li><li><span><a href="#Class-for-the-DataFrame-with-U-Prices" data-toc-modified-id="Class-for-the-DataFrame-with-U-Prices-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Class for the DataFrame with U Prices</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Importation of necessary libraries

# %%
import pandas as pd

import itertools

import numpy as np

# %% [markdown]
# # Extraction of data from CSV files

# %%
df_Wall_Investment = pd.read_csv('../Input_Data_CSV/Wall_Investment.csv',
                                 sep=';',
                                 index_col=None,
                                 header=0)

df_Window_Investment = pd.read_csv('../Input_Data_CSV/Window_Investment.csv',
                                   sep=';',
                                   index_col=None,
                                   header=0)

df_Roof_Investment = pd.read_csv('../Input_Data_CSV/Roof_Investment.csv',
                                 sep=';',
                                 index_col=None,
                                 header=0)

df_Floor_Investment = pd.read_csv('../Input_Data_CSV/Floor_Investment.csv',
                                  sep=';',
                                  index_col=None,
                                  header=0)

df_Housing_Characteristics = pd.read_csv(
    '../Input_Data_CSV/Housing_Characteristics.csv',
    sep=';',
    index_col=None,
    header=0)

df_Climate_Zone = pd.read_csv('../Input_Data_CSV/Climate_Zone.csv',
                              sep=';',
                              index_col=None,
                              header=0)

df_Heating_System = pd.read_csv('../Input_Data_CSV/Heating_System.csv',
                                sep=';',
                                index_col=None,
                                header=0)

df_Headcount = pd.read_csv('../Input_Data_CSV/Headcount.csv',
                           sep=';',
                           index_col=None,
                           header=0)

df_Economic_Hypothesis = pd.read_csv(
    '../Input_Data_CSV/Economic_Hypothesis.csv',
    sep=';',
    index_col=None,
    header=0)

# %% [markdown]
# # Combination of all the necessary data
#
# ## Class for all types of dwellings

# %%
class All_Types:
    def __init__(self, *args):
        self.df_1 = df_Climate_Zone
        self.df_2 = df_Housing_Characteristics
        self.df_3 = df_Headcount
        self.df_4 = df_Heating_System
        self.df_5 = df_Economic_Hypothesis
        self.df_6 = df_Wall_Investment
        self.df_7 = df_Window_Investment
        self.df_8 = df_Roof_Investment
        self.df_9 = df_Floor_Investment

# %% [markdown]
# ## Class for the CID type dwellings

# %%
class CID_Type(All_Types):
    def init(self, *args):
        super().init(*args)

    def Combine_Lists(self):
        self.list_combined = []
        list_dwelling_type = ['CID']
        list_climate_type = self.df_1.iloc[:, 0].tolist()
        list_construction_period = self.df_2.iloc[:21, 1].tolist()[::3]
        list_size_factor = self.df_2.iloc[:3, 2].tolist()
        list_heating_system = [
            'ER', 'GB', 'CGB', 'OB', 'COB', 'EHP2', 'WB', 'WPB', 'EHP'
        ]
        list_initial_age = self.df_3.iloc[:20, 5].tolist()
        self.list_combined.append(list_dwelling_type)
        self.list_combined.append(list_climate_type)
        self.list_combined.append(list_construction_period)
        self.list_combined.append(list_size_factor)
        self.list_combined.append(list_heating_system)
        self.list_combined.append(list_initial_age)
        return self.list_combined

    def Generate_DF(self):
        self.Combine_Lists()
        itertools_product = list(itertools.product(*self.list_combined))
        self.df = pd.DataFrame(itertools_product,
                               columns=[
                                   'Dwelling Type', 'Climate Type',
                                   'Construction Period', 'Size Factor',
                                   'Heating System', 'Initial Age'
                               ])
        return self.df

    def Merge_DFs(self):
        self.Generate_DF()
        self.df = self.df.merge(self.df_1, how='left', on=['Climate Type'])
        self.df = self.df.merge(self.df_2.iloc[:21, 1:9],
                                how='left',
                                on=['Construction Period', 'Size Factor'])
        self.df = self.df.merge(self.df_4.iloc[:9, :],
                                how='left',
                                on=['Heating System'])
        return self.df

    def Add_Columns(self):
        self.Merge_DFs()
        self.df[self.df_5.columns[1]] = self.df_5.iloc[0, 1]
        self.df[self.df_5.columns[2]] = self.df_5.iloc[0, 2]
        self.df[self.df_5.columns[3]] = self.df_5.iloc[0, 3]
        self.df[self.df_5.columns[4]] = self.df_5.iloc[0, 4]
        return self.df

    def Concat_DFs(self):
        self.Add_Columns()
        self.df = pd.concat([self.df, self.df_3.iloc[0:11340, 6]],
                            axis=1,
                            join='outer')
        return self.df

    def Reorder_Columns(self):
        self.Concat_DFs()
        cols = self.df.columns.tolist()
        reordered_cols = cols[:2] + cols[6:7] + cols[2:4] + cols[7:13] + cols[
            4:5] + cols[13:28] + cols[5:6] + cols[28:29]
        self.df = self.df[reordered_cols]
        return self.df

    def Add_U_Factors(self):
        self.Reorder_Columns()
        self.df = self.df.merge(
            self.df_2.loc[:20, ['Construction Period', 'Size Factor', 'Um0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for m in range(18):
            self.df['Um' + str(m + 1)] = self.df_6.iloc[m, 2]
        self.df = self.df.merge(
            self.df_2.loc[:20, ['Construction Period', 'Size Factor', 'Uw0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for w in range(3):
            self.df['Uw' + str(w + 1)] = self.df_7.iloc[w, 2]
        self.df = self.df.merge(
            self.df_2.loc[:20, ['Construction Period', 'Size Factor', 'Ur0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for r in range(3):
            self.df['Ur' + str(r + 1)] = self.df_8.iloc[r, 2]
        self.df = self.df.merge(
            self.df_2.loc[:20, ['Construction Period', 'Size Factor', 'Uf0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for f in range(5):
            self.df['Uf' + str(f + 1)] = self.df_9.iloc[f, 2]
        return self.df

    def Add_U_Prices(self):
        self.Reorder_Columns()
        self.df['Um0'] = 0
        for m in range(18):
            self.df['Um' + str(m + 1)] = self.df_6.iloc[m, 3]
        self.df['Uw0'] = 0
        for w in range(3):
            self.df['Uw' + str(w + 1)] = self.df_7.iloc[w, 3]
        self.df['Ur0'] = 0
        for r in range(3):
            self.df['Ur' + str(r + 1)] = self.df_8.iloc[r, 3]
        self.df['Uf0'] = 0
        for f in range(5):
            self.df['Uf' + str(f + 1)] = self.df_9.iloc[f, 3]
        return self.df

# %% [markdown]
# ## Class for the CCD type dwellings

# %% [markdown]
# class CCD_Type(All_Types):
#     def init(self, *args):
#         super().init(*args)
#
#     def Combine_Lists(self):
#         self.list_combined = []
#         list_dwelling_type = ['CCD']
#         list_climate_type = self.df_1.iloc[:, 0].tolist()
#         list_construction_period = self.df_2.iloc[:21, 1].tolist()[::3]
#         list_size_factor = self.df_2.iloc[:3, 2].tolist()
#         list_heating_system = [
#             'GB', 'CGB', 'OB', 'COB', 'EHP2', 'WB', 'WPB', 'EHP'
#         ]
#         list_initial_age = self.df_3.iloc[:20, 5].tolist()
#         self.list_combined.append(list_dwelling_type)
#         self.list_combined.append(list_climate_type)
#         self.list_combined.append(list_construction_period)
#         self.list_combined.append(list_size_factor)
#         self.list_combined.append(list_heating_system)
#         self.list_combined.append(list_initial_age)
#         return self.list_combined
#
#     def Generate_DF(self):
#         self.Combine_Lists()
#         itertools_product = list(itertools.product(*self.list_combined))
#         self.df = pd.DataFrame(itertools_product,
#                                columns=[
#                                    'Dwelling Type', 'Climate Type',
#                                    'Construction Period', 'Size Factor',
#                                    'Heating System', 'Initial Age'
#                                ])
#         return self.df
#
#     def Merge_DFs(self):
#         self.Generate_DF()
#         self.df = self.df.merge(self.df_1, how='left', on=['Climate Type'])
#         self.df = self.df.merge(self.df_2.iloc[:21, 1:9],
#                                 how='left',
#                                 on=['Construction Period', 'Size Factor'])
#         self.df = self.df.merge(self.df_4.iloc[9:17, :],
#                                 how='left',
#                                 on=['Heating System'])
#         return self.df
#
#     def Add_Columns(self):
#         self.Merge_DFs()
#         self.df[self.df_5.columns[0]] = self.df_5.iloc[0, 0]
#         self.df[self.df_5.columns[1]] = self.df_5.iloc[0, 1]
#         self.df[self.df_5.columns[2]] = self.df_5.iloc[0, 2]
#         self.df[self.df_5.columns[3]] = self.df_5.iloc[0, 3]
#         return self.df
#
#     def Concat_DFs(self):
#         self.Add_Columns()
#         self.df = pd.concat(
#             [self.df, self.df_3.iloc[11340:21420, 6].reset_index(drop=True)],
#             axis=1,
#             join='outer')
#         return self.df
#
#     def Reorder_Columns(self):
#         self.Concat_DFs()
#         cols = self.df.columns.tolist()
#         reordered_cols = cols[:2] + cols[6:7] + cols[2:4] + cols[7:13] + cols[
#             4:5] + cols[13:28] + cols[5:6] + cols[28:29]
#         self.df = self.df[reordered_cols]
#         return self.df
#
#     def Add_U_Factors(self):
#         self.Reorder_Columns()
#         self.df = self.df.merge(
#             self.df_2.loc[:20, ['Construction Period', 'Size Factor', 'Um0']],
#             how='left',
#             on=['Construction Period', 'Size Factor'])
#         for m in range(18):
#             self.df['Um' + str(m + 1)] = self.df_6.iloc[m, 2]
#         self.df = self.df.merge(
#             self.df_2.loc[:20, ['Construction Period', 'Size Factor', 'Uw0']],
#             how='left',
#             on=['Construction Period', 'Size Factor'])
#         for w in range(3):
#             self.df['Uw' + str(w + 1)] = self.df_7.iloc[w, 2]
#         self.df = self.df.merge(
#             self.df_2.loc[:20, ['Construction Period', 'Size Factor', 'Ur0']],
#             how='left',
#             on=['Construction Period', 'Size Factor'])
#         for r in range(3):
#             self.df['Ur' + str(r + 1)] = self.df_8.iloc[r, 2]
#         self.df = self.df.merge(
#             self.df_2.loc[:20, ['Construction Period', 'Size Factor', 'Uf0']],
#             how='left',
#             on=['Construction Period', 'Size Factor'])
#         for f in range(5):
#             self.df['Uf' + str(f + 1)] = self.df_9.iloc[f, 2]
#         return self.df
#
#     def Add_U_Prices(self):
#         self.Reorder_Columns()
#         self.df['Um0'] = 0
#         for m in range(18):
#             self.df['Um' + str(m + 1)] = self.df_6.iloc[m, 3]
#         self.df['Uw0'] = 0
#         for w in range(3):
#             self.df['Uw' + str(w + 1)] = self.df_7.iloc[w, 3]
#         self.df['Ur0'] = 0
#         for r in range(3):
#             self.df['Ur' + str(r + 1)] = self.df_8.iloc[r, 3]
#         self.df['Uf0'] = 0
#         for f in range(5):
#             self.df['Uf' + str(f + 1)] = self.df_9.iloc[f, 3]
#         return self.df

# %% [markdown]
# ## Class for the ID type dwellings

# %% [markdown]
# class ID_Type(All_Types):
#     def init(self, *args):
#         super().init(*args)
#
#     def Combine_Lists(self):
#         self.list_combined = []
#         list_dwelling_type = ['ID']
#         list_climate_type = self.df_1.iloc[:, 0].tolist()
#         list_construction_period = self.df_2.iloc[21:, 1].tolist()[::3]
#         list_size_factor = self.df_2.iloc[:3, 2].tolist()
#         list_heating_system = [
#             'ER', 'GB', 'CGB', 'OB', 'COB', 'EHP2', 'WB', 'WPB', 'EHP'
#         ]
#         list_initial_age = self.df_3.iloc[:20, 5].tolist()
#         self.list_combined.append(list_dwelling_type)
#         self.list_combined.append(list_climate_type)
#         self.list_combined.append(list_construction_period)
#         self.list_combined.append(list_size_factor)
#         self.list_combined.append(list_heating_system)
#         self.list_combined.append(list_initial_age)
#         return self.list_combined
#
#     def Generate_DF(self):
#         self.Combine_Lists()
#         itertools_product = list(itertools.product(*self.list_combined))
#         self.df = pd.DataFrame(itertools_product,
#                                columns=[
#                                    'Dwelling Type', 'Climate Type',
#                                    'Construction Period', 'Size Factor',
#                                    'Heating System', 'Initial Age'
#                                ])
#         return self.df
#
#     def Merge_DFs(self):
#         self.Generate_DF()
#         self.df = self.df.merge(self.df_1, how='left', on=['Climate Type'])
#         self.df = self.df.merge(self.df_2.iloc[21:, 1:9],
#                                 how='left',
#                                 on=['Construction Period', 'Size Factor'])
#         self.df = self.df.merge(self.df_4.iloc[17:, :],
#                                 how='left',
#                                 on=['Heating System'])
#         return self.df
#
#     def Add_Columns(self):
#         self.Merge_DFs()
#         self.df[self.df_5.columns[0]] = self.df_5.iloc[0, 0]
#         self.df[self.df_5.columns[1]] = self.df_5.iloc[0, 1]
#         self.df[self.df_5.columns[2]] = self.df_5.iloc[0, 2]
#         self.df[self.df_5.columns[3]] = self.df_5.iloc[0, 3]
#         return self.df
#
#     def Concat_DFs(self):
#         self.Add_Columns()
#         self.df = pd.concat(
#             [self.df, self.df_3.iloc[21420:, 6].reset_index(drop=True)],
#             axis=1,
#             join='outer')
#         return self.df
#
#     def Reorder_Columns(self):
#         self.Concat_DFs()
#         cols = self.df.columns.tolist()
#         reordered_cols = cols[:2] + cols[6:7] + cols[2:4] + cols[7:13] + cols[
#             4:5] + cols[13:28] + cols[5:6] + cols[28:29]
#         self.df = self.df[reordered_cols]
#         return self.df
#
#     def Add_U_Factors(self):
#         self.Reorder_Columns()
#         self.df = self.df.merge(
#             self.df_2.loc[21:, ['Construction Period', 'Size Factor', 'Um0']],
#             how='left',
#             on=['Construction Period', 'Size Factor'])
#         for m in range(19):
#             self.df['Um' + str(m + 1)] = self.df_6.iloc[m + 18, 2]
#         self.df = self.df.merge(
#             self.df_2.loc[21:, ['Construction Period', 'Size Factor', 'Uw0']],
#             how='left',
#             on=['Construction Period', 'Size Factor'])
#         for w in range(3):
#             self.df['Uw' + str(w + 1)] = self.df_7.iloc[w + 3, 2]
#         self.df = self.df.merge(
#             self.df_2.loc[21:, ['Construction Period', 'Size Factor', 'Ur0']],
#             how='left',
#             on=['Construction Period', 'Size Factor'])
#         for r in range(7):
#             self.df['Ur' + str(r + 1)] = self.df_8.iloc[r + 3, 2]
#         self.df = self.df.merge(
#             self.df_2.loc[21:, ['Construction Period', 'Size Factor', 'Uf0']],
#             how='left',
#             on=['Construction Period', 'Size Factor'])
#         for f in range(3):
#             self.df['Uf' + str(f + 1)] = self.df_9.iloc[f + 5, 2]
#         return self.df
#
#     def Add_U_Prices(self):
#         self.Reorder_Columns()
#         self.df['Um0'] = 0
#         for m in range(19):
#             self.df['Um' + str(m + 1)] = self.df_6.iloc[m + 18, 3]
#         self.df['Uw0'] = 0
#         for w in range(3):
#             self.df['Uw' + str(w + 1)] = self.df_7.iloc[w + 3, 3]
#         self.df['Ur0'] = 0
#         for r in range(7):
#             self.df['Ur' + str(r + 1)] = self.df_8.iloc[r + 3, 3]
#         self.df['Uf0'] = 0
#         for f in range(3):
#             self.df['Uf' + str(f + 1)] = self.df_9.iloc[f + 5, 3]
#         return self.df

# %% [markdown]
# ## Class instantiation for each type of dwelling

# %%
Instance_CID = CID_Type()

df_CID = Instance_CID.Reorder_Columns()
df_CID_UF = Instance_CID.Add_U_Factors()
df_CID_UP = Instance_CID.Add_U_Prices()

df_CID.shape
# Out:
# (11340, 29)

# %% [markdown]
# Instance_CCD = CCD_Type()
#
# df_CCD = Instance_CCD.Reorder_Columns()
# df_CCD_UF = Instance_CCD.Add_U_Factors()
# df_CCD_UP = Instance_CCD.Add_U_Prices()
#
# df_CCD.shape

# %% [markdown]
# Instance_ID = ID_Type()
#
# df_ID = Instance_ID.Reorder_Columns()
# df_ID_UF = Instance_ID.Add_U_Factors()
# df_ID_UP = Instance_ID.Add_U_Prices()
#
# df_ID.shape

# %% [markdown]
# ## Data retention

# %%
df_CID.to_csv(
    '../Output_Data_CSV/Combination_with_Input_Data/CID_Type_Dwellings.csv',
    sep=';',
    index=None,
    header=True,
    encoding='utf-8')

df_CID_UF.to_csv(
    '../Output_Data_CSV/Combination_with_Input_Data/CID_Type_Dwellings_with_U_Factors.csv',
    sep=';',
    index=None,
    header=True,
    encoding='utf-8')

df_CID_UP.to_csv(
    '../Output_Data_CSV/Combination_with_Input_Data/CID_Type_Dwellings_with_U_Prices.csv',
    sep=';',
    index=None,
    header=True,
    encoding='utf-8')

#df_CCD.to_csv(
#    '../Output_Data_CSV/Combination_with_Input_Data/CCD_Type_Dwellings.csv',
#    sep=';',
#    index=None,
#    header=True,
#    encoding='utf-8')
#
#df_CCD_UF.to_csv(
#    '../Output_Data_CSV/Combination_with_Input_Data/CCD_Type_Dwellings_with_U_Factors.csv',
#    sep=';',
#    index=None,
#    header=True,
#    encoding='utf-8')
#
#df_CCD_UP.to_csv(
#    '../Output_Data_CSV/Combination_with_Input_Data/CCD_Type_Dwellings_with_U_Prices.csv',
#    sep=';',
#    index=None,
#    header=True,
#    encoding='utf-8')
#
#df_ID.to_csv(
#    '../Output_Data_CSV/Combination_with_Input_Data/ID_Type_Dwellings.csv',
#    sep=';',
#    index=None,
#    header=True,
#    encoding='utf-8')
#
#df_ID_UF.to_csv(
#    '../Output_Data_CSV/Combination_with_Input_Data/ID_Type_Dwellings_with_U_Factors.csv',
#    sep=';',
#    index=None,
#    header=True,
#    encoding='utf-8')
#
#df_ID_UP.to_csv(
#    '../Output_Data_CSV/Combination_with_Input_Data/ID_Type_Dwellings_with_U_Prices.csv',
#    sep=';',
#    index=None,
#    header=True,
#    encoding='utf-8')

# %% [markdown]
# # Creation of some calculable columns
#
# ## Class for all types of dwellings

# %%
class Calculable_Columns:
    def __init__(self, df, year):
        self.df = df
        self.year = year

    def Rename_Columns(self):
        self.df.columns = self.df.columns.str.replace(' ', '_')
        return self.df

    def Carbon_Tax(self):
        self.Rename_Columns()
        self.df['Carbon_Tax'] = np.multiply(self.df.Emission_Factor,
                                            self.df.Carbon_Price)
        return self.df

    def Energy_Bill(self):
        self.Carbon_Tax()
        self.df['Energy_Bill'] = 0
        for i in range(1, 41):
            self.df['Energy_Bill'] = np.add(
                np.divide(
                    np.add(
                        np.multiply(
                            self.df.Energy_Price,
                            np.power(np.add(1, self.df.Annual_Variation),
                                     np.add(i, np.subtract(self.year, 2)))),
                        self.df.Carbon_Tax),
                    np.power(np.add(1, self.df.Discount_Rate), i)),
                self.df.Energy_Bill)
        return self.df

    def Inflation_Rate_1st(self):
        self.Rename_Columns()
        self.df['Inflation_Rate_1st'] = np.power(
            np.add(1, self.df.Inflation_Rate),
            np.subtract(np.add(18, self.year), self.df.Initial_Age))
        return self.df

    def Inflation_Rate_2nd(self):
        self.Rename_Columns()
        self.df['Inflation_Rate_2nd'] = np.power(
            np.add(1, self.df.Inflation_Rate),
            np.subtract(np.add(38, self.year), self.df.Initial_Age))
        return self.df

    def Discount_1st(self):
        self.Rename_Columns()
        self.df['Discount_1st'] = np.power(
            np.add(1, self.df.Discount_Rate),
            np.subtract(19, self.df.Initial_Age))
        return self.df

    def Discount_2nd(self):
        self.Rename_Columns()
        self.df['Discount_2nd'] = np.power(
            np.add(1, self.df.Discount_Rate),
            np.subtract(39, self.df.Initial_Age))
        return self.df

    def Time_Factor_1(self):
        self.Inflation_Rate_1st()
        self.Inflation_Rate_2nd()
        self.Discount_1st()
        self.Discount_2nd()
        self.df['Time_Factor_1'] = np.divide(
            np.add(
                np.multiply(self.df.Inflation_Rate_1st, self.df.Discount_2nd),
                np.multiply(self.df.Inflation_Rate_2nd, self.df.Discount_1st)),
            np.multiply(self.df.Discount_1st, self.df.Discount_2nd))
        return self.df

    def UEN_Cost_1(self):
        self.Energy_Bill()
        self.Time_Factor_1()
        self.df['UEN_Cost_1'] = np.add(
            np.multiply(self.df.B_Investment, self.df.Time_Factor_1),
            np.divide(self.df.Energy_Bill, self.df.Efficiency))
        return self.df

    def Discount_20(self):
        self.Rename_Columns()
        self.df['Discount_20'] = np.power(np.add(1, self.df.Discount_Rate), 20)
        return self.df

    def Inflation_Rate_0(self):
        self.Rename_Columns()
        self.df['Inflation_Rate_0'] = np.power(
            np.add(1, self.df.Inflation_Rate), np.subtract(self.year, 1))
        return self.df

    def Inflation_Rate_20(self):
        self.Rename_Columns()
        self.df['Inflation_Rate_20'] = np.power(
            np.add(1, self.df.Inflation_Rate), np.add(19, self.year))
        return self.df

    def Time_Factor_2(self):
        self.Inflation_Rate_0()
        self.Inflation_Rate_20()
        self.Discount_20()
        self.df['Time_Factor_2'] = np.divide(
            np.add(np.multiply(self.df.Discount_20, self.df.Inflation_Rate_0),
                   self.df.Inflation_Rate_20), self.df.Discount_20)
        return self.df

    def UEN_Cost_2(self):
        self.Energy_Bill()
        self.Time_Factor_2()
        self.df['UEN_Cost_2'] = np.add(
            np.multiply(self.df.B_Investment, self.df.Time_Factor_2),
            np.divide(self.df.Energy_Bill, self.df.Efficiency))
        return self.df

    def No_Gas_Prices(self):
        self.Carbon_Tax()
        self.df['No_Gas_Prices'] = 0
        for i in range(1, 41):
            self.df['No_Gas_Prices'] = np.add(
                np.divide(
                    np.add(
                        np.multiply(
                            self.df.Specific_Gas_Price,
                            np.power(np.add(1, self.df.Annual_Variation),
                                     np.add(i, np.subtract(self.year, 2)))),
                        self.df.Carbon_Tax),
                    np.power(np.add(1, self.df.Discount_Rate), i),
                ), self.df.No_Gas_Prices)
        return self.df

    def UEN_Cost_3(self):
        self.No_Gas_Prices()
        self.Time_Factor_2()
        self.df['UEN_Cost_3'] = np.add(
            np.multiply(self.df.B_Investment, self.df.Time_Factor_2),
            np.divide(self.df.No_Gas_Prices, self.df.Efficiency))
        return self.df

    def Maintenance(self):
        self.Rename_Columns()
        self.df['Maintenance'] = 0
        for i in range(40):
            self.df['Maintenance'] = np.add(
                np.divide(
                    np.multiply(
                        self.df.Maintenance_Cost,
                        np.power(np.add(1, self.df.Inflation_Rate),
                                 np.add(i, np.subtract(self.year, 1)))),
                    np.power(np.add(1, self.df.Discount_Rate), i)),
                self.df.Maintenance)
        return self.df

    def Fixed_Cost_1(self):
        self.Maintenance()
        self.Time_Factor_1()
        self.df['Fixed_Cost_1'] = np.add(
            np.multiply(self.df.A_Investment, self.df.Time_Factor_1),
            self.df.Maintenance)
        return self.df

    def Fixed_Cost_2(self):
        self.Maintenance()
        self.Time_Factor_2()
        self.df['Fixed_Cost_2'] = np.add(
            np.multiply(self.df.A_Investment, self.df.Time_Factor_2),
            np.add(self.df.Maintenance, self.df.Same_Switch_Cost))
        return self.df

    def Fixed_Cost_4(self):
        self.Maintenance()
        self.Time_Factor_2()
        self.df['Fixed_Cost_4'] = np.add(
            np.multiply(self.df.A_Investment, self.df.Time_Factor_2),
            np.add(self.df.Maintenance, self.df.Different_Switch_Cost))
        return self.df

    def Control_Cost(self):
        self.Rename_Columns()
        self.df['Control_Cost'] = np.multiply(self.df.Delevery_Type_Cost,
                                              self.df.Surface)
        return self.df

    def Fixed_Cost_3(self):
        self.Fixed_Cost_2()
        self.Control_Cost()
        self.df['Fixed_Cost_3'] = np.add(self.df.Fixed_Cost_2,
                                         self.df.Control_Cost)
        return self.df

    def Fixed_Cost_5(self):
        self.Fixed_Cost_4()
        self.Control_Cost()
        self.df['Fixed_Cost_5'] = np.add(self.df.Fixed_Cost_4,
                                         self.df.Control_Cost)
        return self.df

# %% [markdown]
# ## Class for the collective dwellings

# %%
class Calculable_Columns_for_CxD(Calculable_Columns):
    def init(self, df, year):
        super().init(df)

    def Surface_M(self):
        self.Rename_Columns()
        self.df['Surface_M'] = np.multiply(
            np.multiply(
                np.multiply(
                    np.subtract(1, self.df.Share_of_Windows),
                    np.sqrt(
                        np.multiply(self.df.Surface,
                                    self.df.Dwelling_per_Floor))), 4),
            np.multiply(self.df.Ceiling_Height, np.add(self.df.Floors, 1)))
        return self.df

    def Surface_W(self):
        self.Rename_Columns()
        self.df['Surface_W'] = np.multiply(
            np.multiply(
                np.multiply(
                    self.df.Share_of_Windows,
                    np.sqrt(
                        np.multiply(self.df.Surface,
                                    self.df.Dwelling_per_Floor))), 4),
            np.multiply(self.df.Ceiling_Height, np.add(self.df.Floors, 1)))
        return self.df

# %% [markdown]
# ### Class for the DataFrame with U Factors

# %%
class Columns_for_CxD_U_Factors(Calculable_Columns_for_CxD):
    def init(self, df):
        super().init(df)

    def Surface_R(self):
        self.Rename_Columns()
        self.df['Surface_R'] = np.multiply(self.df.Surface,
                                           self.df.Dwelling_per_Floor)
        return self.df

    def Heightened_Surface_Habitable(self):
        self.Surface_R()
        self.df['Heightened_Surface_Habitable'] = np.multiply(
            np.multiply(self.df.Surface_R, np.add(self.df.Floors, 1)),
            self.df.Ceiling_Height)
        return self.df

    def UEN_per_Dwelling_2(self):
        self.Rename_Columns()
        self.df['UEN_per_Dwelling_2'] = np.multiply(
            np.multiply(
                np.multiply(self.df.Ceiling_Height, self.df.Intermittence),
                np.multiply(self.df.Degrees_of_Reference, self.df.Surface)),
            0.01)
        return self.df

    def Weighted_Surface(self):
        self.Surface_M()
        self.Surface_W()
        self.Surface_R()
        self.df.loc[:, 'Um0':'Um18'] = self.df.loc[:, 'Um0':'Um18'].apply(
            lambda x: np.multiply(x, self.df.Surface_M))
        self.df.loc[:, 'Uw0':'Uw3'] = self.df.loc[:, 'Uw0':'Uw3'].apply(
            lambda x: np.multiply(x, self.df.Surface_W))
        self.df.loc[:, 'Ur0':'Ur3'] = self.df.loc[:, 'Ur0':'Ur3'].apply(
            lambda x: np.multiply(x, self.df.Surface_R))
        self.df.loc[:, 'Uf0':'Uf5'] = self.df.loc[:, 'Uf0':'Uf5'].apply(
            lambda x: np.multiply(x, self.df.Surface_R))
        return self.df

    def Duo_Weighted_Surface(self):
        self.Weighted_Surface()
        columns_list = []
        columns_list_1 = []
        columns_list_2 = []
        for m in range(19):
            for w in range(4):
                column_name = 'U_m' + str(m) + '_w' + str(w)
                columns_list_1.append(column_name)
        for r in range(4):
            for f in range(6):
                column_name = 'U_r' + str(r) + '_f' + str(f)
                columns_list_2.append(column_name)
        columns_list = columns_list_1 + columns_list_2
        self.df = pd.concat([
            self.df,
            pd.DataFrame(0, index=self.df.index, columns=columns_list)
        ],
                            axis=1)
        self.df[columns_list_1] = self.df[columns_list_1].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        self.df[columns_list_2] = self.df[columns_list_2].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        selected_columns = self.df.loc[:, 'Um0':'Uf5'].columns.tolist()
        self.df = self.df.drop(selected_columns, axis=1)
        return self.df

    def Add_Created_Columns(self):
        self.Heightened_Surface_Habitable()
        self.UEN_per_Dwelling_2()
        self.Duo_Weighted_Surface()
        self.UEN_Cost_1()
        self.UEN_Cost_2()
        self.UEN_Cost_3()
        return self.df

# %% [markdown]
# ### Class for the DataFrame with U Prices

# %%
class Columns_for_CxD_U_Prices(Calculable_Columns_for_CxD):
    def init(self, df):
        super().init(df)

    def Dwelling_Total(self):
        self.Rename_Columns()
        self.df['Dwelling_Total'] = np.multiply(self.df.Dwelling_per_Floor,
                                                np.add(self.df.Floors, 1))
        return self.df

    def Priced_Surface(self):
        self.Surface_M()
        self.Surface_W()
        self.Dwelling_Total()
        self.df.loc[:, 'Um0':'Um18'] = self.df.loc[:, 'Um0':'Um18'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface_M, self.df.Dwelling_Total)))
        self.df.loc[:, 'Uw0':'Uw3'] = self.df.loc[:, 'Uw0':'Uw3'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface_W, self.df.Dwelling_Total)))
        self.df.loc[:, 'Ur0':'Ur3'] = self.df.loc[:, 'Ur0':'Ur3'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface, np.add(self.df.Floors, 1))))
        self.df.loc[:, 'Uf0':'Uf5'] = self.df.loc[:, 'Uf0':'Uf5'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface, np.add(self.df.Floors, 1))))
        return self.df

    def Duo_Priced_Surface(self):
        self.Priced_Surface()
        columns_list = []
        columns_list_1 = []
        columns_list_2 = []
        for m in range(19):
            for w in range(4):
                column_name = 'U_m' + str(m) + '_w' + str(w)
                columns_list_1.append(column_name)
        for r in range(4):
            for f in range(6):
                column_name = 'U_r' + str(r) + '_f' + str(f)
                columns_list_2.append(column_name)
        columns_list = columns_list_1 + columns_list_2
        self.df = pd.concat([
            self.df,
            pd.DataFrame(0, index=self.df.index, columns=columns_list)
        ],
                            axis=1)
        self.df[columns_list_1] = self.df[columns_list_1].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        self.df[columns_list_2] = self.df[columns_list_2].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        selected_columns = self.df.loc[:, 'Um0':'Uf5'].columns.tolist()
        self.df = self.df.drop(selected_columns, axis=1)
        return self.df

    def Add_Created_Columns(self):
        self.Duo_Priced_Surface()
        self.Fixed_Cost_1()
        self.Fixed_Cost_3()
        self.Fixed_Cost_5()
        return self.df

# %% [markdown]
# ## Class for the individual dwellings

# %%
class Calculable_Columns_for_ID(Calculable_Columns):
    def init(self, df, year):
        super().init(df)

    def Surface_M(self):
        self.Rename_Columns()
        self.df['Surface_M'] = np.multiply(
            np.multiply(
                np.multiply(
                    np.subtract(1, self.df.Share_of_Windows),
                    np.sqrt(
                        np.divide(self.df.Surface, np.add(self.df.Floors,
                                                          1)))), 4),
            np.multiply(self.df.Ceiling_Height, np.add(self.df.Floors, 1)))
        return self.df

    def Surface_W(self):
        self.Rename_Columns()
        self.df['Surface_W'] = np.multiply(
            np.multiply(
                np.multiply(
                    self.df.Share_of_Windows,
                    np.sqrt(
                        np.divide(self.df.Surface, np.add(self.df.Floors,
                                                          1)))), 4),
            np.multiply(self.df.Ceiling_Height, np.add(self.df.Floors, 1)))
        return self.df

# %% [markdown]
# ### Class for the DataFrame with U Factors

# %%
class Columns_for_ID_U_Factors(Calculable_Columns_for_ID):
    def init(self, df):
        super().init(df)

    def Surface_R(self):
        self.Rename_Columns()
        self.df['Surface_R'] = np.divide(self.df.Surface,
                                         np.add(self.df.Floors, 1))
        return self.df

    def Heightened_Surface_Habitable(self):
        self.Surface_R()
        self.df['Heightened_Surface_Habitable'] = np.multiply(
            self.df.Surface, self.df.Ceiling_Height)
        return self.df

    def UEN_per_Dwelling_2(self):
        self.Rename_Columns()
        self.df['UEN_per_Dwelling_2'] = np.multiply(
            np.multiply(
                np.multiply(self.df.Ceiling_Height, self.df.Intermittence),
                np.multiply(self.df.Degrees_of_Reference, self.df.Surface)),
            0.01)
        return self.df

    def Weighted_Surface(self):
        self.Surface_M()
        self.Surface_W()
        self.Surface_R()
        self.df.loc[:, 'Um0':'Um19'] = self.df.loc[:, 'Um0':'Um19'].apply(
            lambda x: np.multiply(x, self.df.Surface_M))
        self.df.loc[:, 'Uw0':'Uw3'] = self.df.loc[:, 'Uw0':'Uw3'].apply(
            lambda x: np.multiply(x, self.df.Surface_W))
        self.df.loc[:, 'Ur0':'Ur7'] = self.df.loc[:, 'Ur0':'Ur7'].apply(
            lambda x: np.multiply(x, self.df.Surface_R))
        self.df.loc[:, 'Uf0':'Uf3'] = self.df.loc[:, 'Uf0':'Uf3'].apply(
            lambda x: np.multiply(x, self.df.Surface_R))
        return self.df

    def Duo_Weighted_Surface(self):
        self.Weighted_Surface()
        columns_list = []
        columns_list_1 = []
        columns_list_2 = []
        for m in range(20):
            for w in range(4):
                column_name = 'U_m' + str(m) + '_w' + str(w)
                columns_list_1.append(column_name)
        for r in range(8):
            for f in range(4):
                column_name = 'U_r' + str(r) + '_f' + str(f)
                columns_list_2.append(column_name)
        columns_list = columns_list_1 + columns_list_2
        self.df = pd.concat([
            self.df,
            pd.DataFrame(0, index=self.df.index, columns=columns_list)
        ],
                            axis=1)
        self.df[columns_list_1] = self.df[columns_list_1].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        self.df[columns_list_2] = self.df[columns_list_2].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        selected_columns = self.df.loc[:, 'Um0':'Uf3'].columns.tolist()
        self.df = self.df.drop(selected_columns, axis=1)
        return self.df

    def Add_Created_Columns(self):
        self.Heightened_Surface_Habitable()
        self.UEN_per_Dwelling_2()
        self.Duo_Weighted_Surface()
        self.UEN_Cost_1()
        self.UEN_Cost_2()
        self.UEN_Cost_3()
        return self.df

# %% [markdown]
# ### Class for the DataFrame with U Prices

# %%
class Columns_for_ID_U_Prices(Calculable_Columns_for_ID):
    def init(self, df):
        super().init(df)

    def Dwelling_Total(self):
        self.Rename_Columns()
        self.df['Dwelling_Total'] = 1
        return self.df

    def Priced_Surface(self):
        self.Surface_M()
        self.Surface_W()
        self.Dwelling_Total()
        self.df.loc[:, 'Um0':'Um19'] = self.df.loc[:, 'Um0':'Um19'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface_M, self.df.Dwelling_Total)))
        self.df.loc[:, 'Uw0':'Uw3'] = self.df.loc[:, 'Uw0':'Uw3'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface_W, self.df.Dwelling_Total)))
        self.df.loc[:, 'Ur0':'Ur7'] = self.df.loc[:, 'Ur0':'Ur7'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface, np.add(self.df.Floors, 1))))
        self.df.loc[:, 'Uf0':'Uf3'] = self.df.loc[:, 'Uf0':'Uf3'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface, np.add(self.df.Floors, 1))))
        return self.df

    def Duo_Priced_Surface(self):
        self.Priced_Surface()
        columns_list = []
        columns_list_1 = []
        columns_list_2 = []
        for m in range(20):
            for w in range(4):
                column_name = 'U_m' + str(m) + '_w' + str(w)
                columns_list_1.append(column_name)
        for r in range(8):
            for f in range(4):
                column_name = 'U_r' + str(r) + '_f' + str(f)
                columns_list_2.append(column_name)
        columns_list = columns_list_1 + columns_list_2
        self.df = pd.concat([
            self.df,
            pd.DataFrame(0, index=self.df.index, columns=columns_list)
        ],
                            axis=1)
        self.df[columns_list_1] = self.df[columns_list_1].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        self.df[columns_list_2] = self.df[columns_list_2].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        selected_columns = self.df.loc[:, 'Um0':'Uf3'].columns.tolist()
        self.df = self.df.drop(selected_columns, axis=1)
        return self.df

    def Add_Created_Columns(self):
        self.Duo_Priced_Surface()
        self.Fixed_Cost_1()
        self.Fixed_Cost_3()
        self.Fixed_Cost_5()
        return self.df

# %% [markdown]
# ## Class instantiation for each type of dwelling

# %%
Instance_df_CID_UF = Columns_for_CxD_U_Factors(df_CID_UF, 1)

Prepared_df_CID_UF = Instance_df_CID_UF.Add_Created_Columns()

Prepared_df_CID_UF.shape
# Out:
# (11340, 149)

# %%
Instance_df_CID_UP = Columns_for_CxD_U_Prices(df_CID_UP, 1)

Prepared_df_CID_UP = Instance_df_CID_UP.Add_Created_Columns()

Prepared_df_CID_UP.shape
# Out:
# (11340, 148)

# %% [markdown]
# Instance_df_CCD_UF = Columns_for_CxD_U_Factors(df_CCD_UF, 0)
#
# Prepared_df_CCD_UF = Instance_df_CCD_UF.Add_Created_Columns()
#
# Prepared_df_CCD_UF.shape

# %% [markdown]
# Instance_df_CCD_UP = Columns_for_CxD_U_Prices(df_CCD_UP, 0)
#
# Prepared_df_CCD_UP = Instance_df_CCD_UP.Add_Created_Columns()
#
# Prepared_df_CCD_UP.shape

# %% [markdown]
# Instance_df_ID_UF = Columns_for_ID_U_Factors(df_ID_UF, 0)
#
# Prepared_df_ID_UF = Instance_df_ID_UF.Add_Created_Columns()
#
# Prepared_df_ID_UF.shape

# %% [markdown]
# Instance_df_ID_UP = Columns_for_ID_U_Prices(df_ID_UF, 0)
#
# Prepared_df_ID_UP = Instance_df_ID_UP.Add_Created_Columns()
#
# Prepared_df_ID_UP.shape

# %% [markdown]
# # Creation of some calculable DataFrames
#
# ## Class for all types of dwellings

# %%
class Calculable_DFs:
    def __init__(self, df):
        self.df = df

# %% [markdown]
# ## Class for the CID type dwellings

# %%
class Calculable_DFs_for_CID(Calculable_DFs):
    def init(self, df):
        super().init(df)

    def Add_ER_Columns(self):
        columns_list = []
        for m in range(19):
            for w in range(4):
                for r in range(4):
                    for f in range(6):
                        column_name = 'ER_m' + str(m) + '_w' + str(
                            w) + '_r' + str(r) + '_f' + str(f)
                        columns_list.append(column_name)
        self.df = pd.concat([
            self.df,
            pd.DataFrame(0, index=self.df.index, columns=columns_list)
        ],
                            axis=1)
        return self.df

    def Fill_ER_Columns(self):
        self.Add_ER_Columns()
        selected_columns = self.df.loc[:, 'ER_m0_w0_r0_f0':
                                       'ER_m18_w3_r3_f5'].columns.tolist()
        self.df[selected_columns] = self.df[selected_columns].apply(
            lambda x: np.add(
                self.df['U_' + x.name.split('_')[1] + '_' + x.name.split('_')[
                    2]], self.df['U_' + x.name.split('_')[3] + '_' + x.name.
                                 split('_')[4]]))
        selected_columns = self.df.loc[:, 'U_m0_w0':'U_r3_f5'].columns.tolist()
        self.df = self.df.drop(selected_columns, axis=1)
        return self.df

    def Generate_GB_Columns(self):
        self.Generate_ER_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'GB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_CGB_Columns(self):
        self.Generate_GB_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'CGB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_OB_Columns(self):
        self.Generate_CGB_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'OB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_COB_Columns(self):
        self.Generate_OB_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'COB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_EHP2_Columns(self):
        self.Generate_COB_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'EHP2_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_WB_Columns(self):
        self.Generate_EHP2_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'WB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_WPB_Columns(self):
        self.Generate_WB_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'WPB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_EHP_Columns(self):
        self.Generate_WPB_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'EHP_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

# %% [markdown]
# ### Class for the DataFrame with U Factors

# %%
class DF_for_CID_U_Factors(Calculable_DFs_for_CID):
    def init(self, df):
        super().init(df)

    def Weighted_Surface_Total(self):
        self.Fill_ER_Columns()
        return self.df

    def Enlarged_Weighted_Surface_Total(self):
        self.Weighted_Surface_Total()
        selected_columns = self.df.loc[:, 'ER_m0_w0_r0_f0':
                                       'ER_m18_w3_r3_f5'].columns.tolist()
        self.copied_df = self.df[selected_columns].copy()
        self.copied_df = self.copied_df.apply(lambda x: np.add(
            np.multiply(9, self.df.Heightened_Surface_Habitable),
            np.multiply(2.5, x)))
        return self.copied_df

    def UEN_per_Dwelling_1(self):
        self.Enlarged_Weighted_Surface_Total()
        selected_columns = self.df.loc[:, 'ER_m0_w0_r0_f0':
                                       'ER_m18_w3_r3_f5'].columns.tolist()
        self.df[selected_columns] = self.df[selected_columns].div(
            self.copied_df)
        del self.copied_df
        return self.df

    def UEN_per_Dwelling(self):
        self.UEN_per_Dwelling_1()
        selected_columns = self.df.loc[:, 'ER_m0_w0_r0_f0':
                                       'ER_m18_w3_r3_f5'].columns.tolist()
        self.df[selected_columns] = self.df[selected_columns].apply(
            lambda x: np.multiply(x, self.df.UEN_per_Dwelling_2))
        return self.df

    def Generate_ER_Columns(self):
        self.UEN_per_Dwelling()
        return self.df

    def GHC_UEN_ER(self):
        self.Generate_EHP_Columns()
        selected_columns = self.df.loc[:, 'ER_m0_w0_r0_f0':
                                       'ER_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'ER'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        A = np.array(self.df.loc[:, 'UEN_Cost_1']).reshape(self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'UEN_Cost_2']).reshape(self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, A, B, matrix, df_matrix
        return self.df

    def GHC_UEN_GB(self):
        self.GHC_UEN_ER()
        selected_columns = self.df.loc[:, 'GB_m0_w0_r0_f0':
                                       'GB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'GB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WB') | (
                        self.df.Heating_System == 'WPB') | (
                            self.df.Heating_System == 'EHP')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'OB') | (
            self.df.Heating_System == 'COB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        A = np.array(self.df.loc[:, 'UEN_Cost_1']).reshape(self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'UEN_Cost_2']).reshape(self.df.shape[0], 1)
        C = np.array(self.df.loc[:, 'UEN_Cost_3']).reshape(self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(
            matrix, np.multiply(condition_1, A)) + np.multiply(
                matrix, np.multiply(condition_2, B)) + np.multiply(
                    matrix, np.multiply(condition_3, C))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_matrix
        return self.df

    def GHC_UEN_CGB(self):
        self.GHC_UEN_GB()
        selected_columns = self.df.loc[:, 'CGB_m0_w0_r0_f0':
                                       'CGB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'CGB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'GB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WB') | (
                        self.df.Heating_System == 'WPB') | (
                            self.df.Heating_System == 'EHP')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'OB') | (
            self.df.Heating_System == 'COB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        A = np.array(self.df.loc[:, 'UEN_Cost_1']).reshape(self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'UEN_Cost_2']).reshape(self.df.shape[0], 1)
        C = np.array(self.df.loc[:, 'UEN_Cost_3']).reshape(self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(
            matrix, np.multiply(condition_1, A)) + np.multiply(
                matrix, np.multiply(condition_2, B)) + np.multiply(
                    matrix, np.multiply(condition_3, C))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_matrix
        return self.df

    def GHC_UEN_OB(self):
        self.GHC_UEN_CGB()
        selected_columns = self.df.loc[:, 'OB_m0_w0_r0_f0':
                                       'OB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'OB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        A = np.array(self.df.loc[:, 'UEN_Cost_1']).reshape(self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'UEN_Cost_2']).reshape(self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, A, B, matrix, df_matrix
        return self.df

    def GHC_UEN_COB(self):
        self.GHC_UEN_OB()
        selected_columns = self.df.loc[:, 'COB_m0_w0_r0_f0':
                                       'COB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'COB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        A = np.array(self.df.loc[:, 'UEN_Cost_1']).reshape(self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'UEN_Cost_2']).reshape(self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, A, B, matrix, df_matrix
        return self.df

    def GHC_UEN_EHP2(self):
        self.GHC_UEN_COB()
        selected_columns = self.df.loc[:, 'EHP2_m0_w0_r0_f0':
                                       'EHP2_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'EHP2'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        A = np.array(self.df.loc[:, 'UEN_Cost_1']).reshape(self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'UEN_Cost_2']).reshape(self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, A, B, matrix, df_matrix
        return self.df

    def GHC_UEN_WB(self):
        self.GHC_UEN_EHP2()
        selected_columns = self.df.loc[:, 'WB_m0_w0_r0_f0':
                                       'WB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'WB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        A = np.array(self.df.loc[:, 'UEN_Cost_1']).reshape(self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'UEN_Cost_2']).reshape(self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, A, B, matrix, df_matrix
        return self.df

    def GHC_UEN_WPB(self):
        self.GHC_UEN_WB()
        selected_columns = self.df.loc[:, 'WPB_m0_w0_r0_f0':
                                       'WPB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'WPB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        A = np.array(self.df.loc[:, 'UEN_Cost_1']).reshape(self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'UEN_Cost_2']).reshape(self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, A, B, matrix, df_matrix
        return self.df

    def GHC_UEN_EHP(self):
        self.GHC_UEN_WPB()
        selected_columns = self.df.loc[:, 'EHP_m0_w0_r0_f0':
                                       'EHP_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'EHP'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        A = np.array(self.df.loc[:, 'UEN_Cost_1']).reshape(self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'UEN_Cost_2']).reshape(self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, A, B, matrix, df_matrix
        return self.df

# %% [markdown]
# ### Class for the DataFrame with U Prices

# %%
class DF_for_CID_U_Prices(Calculable_DFs_for_CID):
    def init(self, df):
        super().init(df)

    def Insulation_Cost(self):
        self.Fill_ER_Columns()
        return self.df

    def Generate_ER_Columns(self):
        self.Insulation_Cost()
        return self.df

    def Multiple_Cost_ER(self):
        self.Generate_EHP_Columns()
        selected_columns = self.df.loc[:, 'ER_m0_w0_r0_f0':
                                       'ER_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'ER'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'WB') | (
            self.df.Heating_System == 'EHP')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'OB') | (
                    self.df.Heating_System == 'COB') | (
                        self.df.Heating_System == 'EHP2') | (
                            self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        A = np.array(self.df.loc[:, 'Fixed_Cost_1']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'Fixed_Cost_2']).reshape(
            self.df.shape[0], 1)
        C = np.array(self.df.loc[:, 'Fixed_Cost_5']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.add(matrix, np.multiply(condition_1, A)) + np.add(
            matrix, np.multiply(condition_2, B)) + np.add(
                matrix, np.multiply(condition_3, C))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_matrix
        return self.df

    def Multiple_Cost_GB(self):
        self.Multiple_Cost_ER()
        selected_columns = self.df.loc[:, 'GB_m0_w0_r0_f0':
                                       'GB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'GB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'CGB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'OB') | (
            self.df.Heating_System == 'COB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'WB') | (self.df.Heating_System == 'EHP')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        A = np.array(self.df.loc[:, 'Fixed_Cost_1']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'Fixed_Cost_2']).reshape(
            self.df.shape[0], 1)
        C = np.array(self.df.loc[:, 'Fixed_Cost_4']).reshape(
            self.df.shape[0], 1)
        D = np.array(self.df.loc[:, 'Fixed_Cost_5']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.add(matrix, np.multiply(condition_1, A)) + np.add(
            matrix, np.multiply(condition_2, B)) + np.add(
                matrix, np.multiply(condition_3, C)) + np.add(
                    matrix, np.multiply(condition_4, D))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_matrix
        return self.df

    def Multiple_Cost_CGB(self):
        self.Multiple_Cost_GB()
        selected_columns = self.df.loc[:, 'CGB_m0_w0_r0_f0':
                                       'CGB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'CGB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'GB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'OB') | (
            self.df.Heating_System == 'COB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'WB') | (self.df.Heating_System == 'EHP')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        A = np.array(self.df.loc[:, 'Fixed_Cost_1']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'Fixed_Cost_2']).reshape(
            self.df.shape[0], 1)
        C = np.array(self.df.loc[:, 'Fixed_Cost_4']).reshape(
            self.df.shape[0], 1)
        D = np.array(self.df.loc[:, 'Fixed_Cost_5']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.add(matrix, np.multiply(condition_1, A)) + np.add(
            matrix, np.multiply(condition_2, B)) + np.add(
                matrix, np.multiply(condition_3, C)) + np.add(
                    matrix, np.multiply(condition_4, D))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_matrix
        return self.df

    def Multiple_Cost_OB(self):
        self.Multiple_Cost_CGB()
        selected_columns = self.df.loc[:, 'OB_m0_w0_r0_f0':
                                       'OB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'OB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'COB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'WB') | (self.df.Heating_System == 'EHP')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        A = np.array(self.df.loc[:, 'Fixed_Cost_1']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'Fixed_Cost_2']).reshape(
            self.df.shape[0], 1)
        C = np.array(self.df.loc[:, 'Fixed_Cost_4']).reshape(
            self.df.shape[0], 1)
        D = np.array(self.df.loc[:, 'Fixed_Cost_5']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.add(matrix, np.multiply(condition_1, A)) + np.add(
            matrix, np.multiply(condition_2, B)) + np.add(
                matrix, np.multiply(condition_3, C)) + np.add(
                    matrix, np.multiply(condition_4, D))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_matrix
        return self.df

    def Multiple_Cost_COB(self):
        self.Multiple_Cost_OB()
        selected_columns = self.df.loc[:, 'COB_m0_w0_r0_f0':
                                       'COB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'COB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'OB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'WB') | (self.df.Heating_System == 'EHP')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        A = np.array(self.df.loc[:, 'Fixed_Cost_1']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'Fixed_Cost_2']).reshape(
            self.df.shape[0], 1)
        C = np.array(self.df.loc[:, 'Fixed_Cost_4']).reshape(
            self.df.shape[0], 1)
        D = np.array(self.df.loc[:, 'Fixed_Cost_5']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.add(matrix, np.multiply(condition_1, A)) + np.add(
            matrix, np.multiply(condition_2, B)) + np.add(
                matrix, np.multiply(condition_3, C)) + np.add(
                    matrix, np.multiply(condition_4, D))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_matrix
        return self.df

    def Multiple_Cost_EHP2(self):
        self.Multiple_Cost_COB()
        selected_columns = self.df.loc[:, 'EHP2_m0_w0_r0_f0':
                                       'EHP2_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'EHP2'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'OB') | (
                    self.df.Heating_System == 'COB') | (
                        self.df.Heating_System == 'WPB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'WB') | (self.df.Heating_System == 'EHP')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        A = np.array(self.df.loc[:, 'Fixed_Cost_1']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'Fixed_Cost_4']).reshape(
            self.df.shape[0], 1)
        C = np.array(self.df.loc[:, 'Fixed_Cost_5']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.add(matrix, np.multiply(condition_1, A)) + np.add(
            matrix, np.multiply(condition_2, B)) + np.add(
                matrix, np.multiply(condition_3, C))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_matrix
        return self.df

    def Multiple_Cost_WB(self):
        self.Multiple_Cost_EHP2()
        selected_columns = self.df.loc[:, 'WB_m0_w0_r0_f0':
                                       'WB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'WB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'EHP')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'OB') | (
                    self.df.Heating_System == 'COB') | (
                        self.df.Heating_System == 'EHP2') | (
                            self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        A = np.array(self.df.loc[:, 'Fixed_Cost_1']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'Fixed_Cost_2']).reshape(
            self.df.shape[0], 1)
        C = np.array(self.df.loc[:, 'Fixed_Cost_5']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.add(matrix, np.multiply(condition_1, A)) + np.add(
            matrix, np.multiply(condition_2, B)) + np.add(
                matrix, np.multiply(condition_3, C))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_matrix
        return self.df

    def Multiple_Cost_WPB(self):
        self.Multiple_Cost_WB()
        selected_columns = self.df.loc[:, 'WPB_m0_w0_r0_f0':
                                       'WPB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'WPB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'WB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'OB') | (
                    self.df.Heating_System == 'COB') | (
                        self.df.Heating_System == 'EHP2')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'EHP')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        A = np.array(self.df.loc[:, 'Fixed_Cost_1']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'Fixed_Cost_3']).reshape(
            self.df.shape[0], 1)
        C = np.array(self.df.loc[:, 'Fixed_Cost_4']).reshape(
            self.df.shape[0], 1)
        D = np.array(self.df.loc[:, 'Fixed_Cost_5']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.add(matrix, np.multiply(condition_1, A)) + np.add(
            matrix, np.multiply(condition_2, B)) + np.add(
                matrix, np.multiply(condition_3, C)) + np.add(
                    matrix, np.multiply(condition_4, D))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_matrix
        return self.df

    def Multiple_Cost_EHP(self):
        self.Multiple_Cost_WPB()
        selected_columns = self.df.loc[:, 'EHP_m0_w0_r0_f0':
                                       'EHP_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'EHP'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'WB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'OB') | (
                    self.df.Heating_System == 'COB') | (
                        self.df.Heating_System == 'EHP2') | (
                            self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        A = np.array(self.df.loc[:, 'Fixed_Cost_1']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'Fixed_Cost_2']).reshape(
            self.df.shape[0], 1)
        C = np.array(self.df.loc[:, 'Fixed_Cost_5']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.add(matrix, np.multiply(condition_1, A)) + np.add(
            matrix, np.multiply(condition_2, B)) + np.add(
                matrix, np.multiply(condition_3, C))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_matrix
        return self.df

# %%
a = DF_for_CID_U_Factors(Prepared_df_CID_UF)
b = a.GHC_UEN_EHP()

# %%
a = DF_for_CID_U_Factors(Prepared_df_CID_UF)
UEN_per_Dwelling = a.UEN_per_Dwelling()

# %%
UEN_per_Dwelling.ER_m0_w0_r0_f0
# Out:
# 0        11179.449406
# 1        11179.449406
# 2        11179.449406
# 3        11179.449406
# 4        11179.449406
# 5        11179.449406
# 6        11179.449406
# 7        11179.449406
# 8        11179.449406
# 9        11179.449406
# 10       11179.449406
# 11       11179.449406
# 12       11179.449406
# 13       11179.449406
# 14       11179.449406
# 15       11179.449406
# 16       11179.449406
# 17       11179.449406
# 18       11179.449406
# 19       11179.449406
# 20       11179.449406
# 21       11179.449406
# 22       11179.449406
# 23       11179.449406
# 24       11179.449406
# 25       11179.449406
# 26       11179.449406
# 27       11179.449406
# 28       11179.449406
# 29       11179.449406
#              ...
# 11310     2301.868116
# 11311     2301.868116
# 11312     2301.868116
# 11313     2301.868116
# 11314     2301.868116
# 11315     2301.868116
# 11316     2301.868116
# 11317     2301.868116
# 11318     2301.868116
# 11319     2301.868116
# 11320     2301.868116
# 11321     2301.868116
# 11322     2301.868116
# 11323     2301.868116
# 11324     2301.868116
# 11325     2301.868116
# 11326     2301.868116
# 11327     2301.868116
# 11328     2301.868116
# 11329     2301.868116
# 11330     2301.868116
# 11331     2301.868116
# 11332     2301.868116
# 11333     2301.868116
# 11334     2301.868116
# 11335     2301.868116
# 11336     2301.868116
# 11337     2301.868116
# 11338     2301.868116
# 11339     2301.868116
# Name: ER_m0_w0_r0_f0, Length: 11340, dtype: float64

# %%
A = DF_for_CID_U_Prices(Prepared_df_CID_UP)
B = A.Multiple_Cost_EHP()

# %%
selected_columns = b.loc[:, 'ER_m0_w0_r0_f0':
                         'EHP_m18_w3_r3_f5'].columns.tolist()

Total = b[selected_columns] + B[selected_columns]
Total = Total.astype(np.int32)
Total
# Out:
#        ER_m0_w0_r0_f0  ER_m0_w0_r0_f1  ER_m0_w0_r0_f2  ER_m0_w0_r0_f3  \
# 0               51614           54266           54087           54062
# 1               51675           54326           54147           54122
# 2               51738           54387           54208           54183
# 3               51802           54451           54272           54246
# 4               51868           54516           54337           54311
# 5               51937           54584           54404           54378
# 6               52007           54653           54473           54447
# 7               52079           54724           54544           54518
# 8               52154           54798           54617           54590
# 9               52230           54873           54692           54665
# 10              52309           54951           54769           54743
# 11              52390           55031           54849           54822
# 12              52474           55114           54931           54904
# 13              52560           55198           55015           54988
# 14              52648           55286           55102           55075
# 15              52740           55376           55192           55164
# 16              52833           55468           55284           55256
# 17              52930           55564           55379           55351
# 18              53030           55662           55476           55448
# 19              53132           55763           55577           55549
# 20             216008          219141          219133          219185
# 21             216008          219141          219133          219185
# 22             216008          219141          219133          219185
# 23             216008          219141          219133          219185
# 24             216008          219141          219133          219185
# 25             216008          219141          219133          219185
# 26             216008          219141          219133          219185
# 27             216008          219141          219133          219185
# 28             216008          219141          219133          219185
# 29             216008          219141          219133          219185
# ...               ...             ...             ...             ...
# 11310         1383221         1388249         1388343         1388459
# 11311         1383221         1388249         1388343         1388459
# 11312         1383221         1388249         1388343         1388459
# 11313         1383221         1388249         1388343         1388459
# 11314         1383221         1388249         1388343         1388459
# 11315         1383221         1388249         1388343         1388459
# 11316         1383221         1388249         1388343         1388459
# 11317         1383221         1388249         1388343         1388459
# 11318         1383221         1388249         1388343         1388459
# 11319         1383221         1388249         1388343         1388459
# 11320           19942           25191           25169           25233
# 11321           19942           25191           25169           25233
# 11322           19942           25191           25169           25233
# 11323           19942           25191           25169           25233
# 11324           19942           25191           25169           25233
# 11325           19942           25191           25169           25233
# 11326           19942           25191           25169           25233
# 11327           19942           25191           25169           25233
# 11328           19942           25191           25169           25233
# 11329           19942           25191           25169           25233
# 11330           19942           25191           25169           25233
# 11331           19942           25191           25169           25233
# 11332           19942           25191           25169           25233
# 11333           19942           25191           25169           25233
# 11334           19942           25191           25169           25233
# 11335           19942           25191           25169           25233
# 11336           19942           25191           25169           25233
# 11337           19942           25191           25169           25233
# 11338           19942           25191           25169           25233
# 11339           19942           25191           25169           25233
#
#        ER_m0_w0_r0_f4  ER_m0_w0_r0_f5  ER_m0_w0_r1_f0  ER_m0_w0_r1_f1  \
# 0               54137           54229           51030           53633
# 1               54196           54288           51088           53690
# 2               54258           54349           51147           53748
# 3               54321           54412           51208           53808
# 4               54385           54477           51271           53870
# 5               54452           54543           51336           53934
# 6               54521           54612           51402           54000
# 7               54592           54683           51471           54067
# 8               54664           54755           51541           54137
# 9               54739           54830           51614           54208
# 10              54817           54907           51689           54282
# 11              54896           54987           51766           54358
# 12              54978           55068           51845           54436
# 13              55062           55152           51927           54516
# 14              55148           55239           52011           54599
# 15              55238           55328           52097           54684
# 16              55329           55420           52186           54772
# 17              55424           55514           52278           54862
# 18              55521           55611           52372           54955
# 19              55621           55711           52469           55050
# 20             219303          219429          217249          220358
# 21             219303          219429          217249          220358
# 22             219303          219429          217249          220358
# 23             219303          219429          217249          220358
# 24             219303          219429          217249          220358
# 25             219303          219429          217249          220358
# 26             219303          219429          217249          220358
# 27             219303          219429          217249          220358
# 28             219303          219429          217249          220358
# 29             219303          219429          217249          220358
# ...               ...             ...             ...             ...
# 11310         1388642         1388831         1387383         1392410
# 11311         1388642         1388831         1387383         1392410
# 11312         1388642         1388831         1387383         1392410
# 11313         1388642         1388831         1387383         1392410
# 11314         1388642         1388831         1387383         1392410
# 11315         1388642         1388831         1387383         1392410
# 11316         1388642         1388831         1387383         1392410
# 11317         1388642         1388831         1387383         1392410
# 11318         1388642         1388831         1387383         1392410
# 11319         1388642         1388831         1387383         1392410
# 11320           25387           25552           24227           29473
# 11321           25387           25552           24227           29473
# 11322           25387           25552           24227           29473
# 11323           25387           25552           24227           29473
# 11324           25387           25552           24227           29473
# 11325           25387           25552           24227           29473
# 11326           25387           25552           24227           29473
# 11327           25387           25552           24227           29473
# 11328           25387           25552           24227           29473
# 11329           25387           25552           24227           29473
# 11330           25387           25552           24227           29473
# 11331           25387           25552           24227           29473
# 11332           25387           25552           24227           29473
# 11333           25387           25552           24227           29473
# 11334           25387           25552           24227           29473
# 11335           25387           25552           24227           29473
# 11336           25387           25552           24227           29473
# 11337           25387           25552           24227           29473
# 11338           25387           25552           24227           29473
# 11339           25387           25552           24227           29473
#
#        ER_m0_w0_r1_f2  ER_m0_w0_r1_f3  ...  EHP_m18_w3_r2_f2  \
# 0               53437           53405  ...             72380
# 1               53494           53461  ...             72380
# 2               53552           53519  ...             72380
# 3               53612           53579  ...             72380
# 4               53673           53640  ...             72380
# 5               53737           53703  ...             72380
# 6               53802           53768  ...             72380
# 7               53869           53835  ...             72380
# 8               53938           53904  ...             72380
# 9               54009           53975  ...             72380
# 10              54083           54048  ...             72380
# 11              54158           54124  ...             72380
# 12              54236           54201  ...             72380
# 13              54316           54281  ...
# <b>limit_output extension: Maximum message size of 10000 exceeded with 30741 characters</b>

# %%
Total.shape
# Out:
# (11340, 16416)

# %%
columns = Total.columns.tolist()
list_all = []
for i in range(1824):
    list_i = columns[i::1824]
    list_all += list_i
Total_new = Total[list_all]
Total_new
# Out:
#        ER_m0_w0_r0_f0  GB_m0_w0_r0_f0  CGB_m0_w0_r0_f0  OB_m0_w0_r0_f0  \
# 0               51614          234632           234632          234632
# 1               51675          234632           234632          234632
# 2               51738          234632           234632          234632
# 3               51802          234632           234632          234632
# 4               51868          234632           234632          234632
# 5               51937          234632           234632          234632
# 6               52007          234632           234632          234632
# 7               52079          234632           234632          234632
# 8               52154          234632           234632          234632
# 9               52230          234632           234632          234632
# 10              52309          234632           234632          234632
# 11              52390          234632           234632          234632
# 12              52474          234632           234632          234632
# 13              52560          234632           234632          234632
# 14              52648          234632           234632          234632
# 15              52740          234632           234632          234632
# 16              52833          234632           234632          234632
# 17              52930          234632           234632          234632
# 18              53030          234632           234632          234632
# 19              53132          234632           234632          234632
# 20             216008           30812            33908           34508
# 21             216008           30936            33908           34508
# 22             216008           31064            33908           34508
# 23             216008           31195            33908           34508
# 24             216008           31330            33908           34508
# 25             216008           31469            33908           34508
# 26             216008           31613            33908           34508
# 27             216008           31760            33908           34508
# 28             216008           31912            33908           34508
# 29             216008           32068            33908           34508
# ...               ...             ...              ...             ...
# 11310         1383221         1101221          1101221         1101221
# 11311         1383221         1101221          1101221         1101221
# 11312         1383221         1101221          1101221         1101221
# 11313         1383221         1101221          1101221         1101221
# 11314         1383221         1101221          1101221         1101221
# 11315         1383221         1101221          1101221         1101221
# 11316         1383221         1101221          1101221         1101221
# 11317         1383221         1101221          1101221         1101221
# 11318         1383221         1101221          1101221         1101221
# 11319         1383221         1101221          1101221         1101221
# 11320           19942          301942           301942          301942
# 11321           19942          301942           301942          301942
# 11322           19942          301942           301942          301942
# 11323           19942          301942           301942          301942
# 11324           19942          301942           301942          301942
# 11325           19942          301942           301942          301942
# 11326           19942          301942           301942          301942
# 11327           19942          301942           301942          301942
# 11328           19942          301942           301942          301942
# 11329           19942          301942           301942          301942
# 11330           19942          301942           301942          301942
# 11331           19942          301942           301942          301942
# 11332           19942          301942           301942          301942
# 11333           19942          301942           301942          301942
# 11334           19942          301942           301942          301942
# 11335           19942          301942           301942          301942
# 11336           19942          301942           301942          301942
# 11337           19942          301942           301942          301942
# 11338           19942          301942           301942          301942
# 11339           19942          301942           301942          301942
#
#        COB_m0_w0_r0_f0  EHP2_m0_w0_r0_f0  WB_m0_w0_r0_f0  WPB_m0_w0_r0_f0  \
# 0               234632            234632           53132           234632
# 1               234632            234632           53132           234632
# 2               234632            234632           53132           234632
# 3               234632            234632           53132           234632
# 4               234632            234632           53132           234632
# 5               234632            234632           53132           234632
# 6               234632            234632           53132           234632
# 7               234632            234632           53132           234632
# 8               234632            234632           53132           234632
# 9               234632            234632           53132           234632
# 10              234632            234632           53132           234632
# 11              234632            234632           53132           234632
# 12              234632            234632           53132           234632
# 13              234632            234632           53132           234632
# 14              234632            234632           53132           234632
# 15              234632            234632           53132           234632
# 16              234632            234632           53132           234632
# 17              234632            234632           53132           234632
# 18              234632            234632           53132           234632
# 19              234632            234632           53132           234632
# 20               34508             34508          216008            34508
# 21               34508             34508          216008            34508
# 22               34508             34508          216008            34508
# 23               34508             34508          216008            34508
# 24               34508             34508          216008            34508
# 25               34508             34508          216008            34508
# 26               34508             34508          216008            34508
# 27               34508             34508          216008            34508
# 28               34508             34508          216008            34508
# 29               34508             34508          216008            34508
# ...                ...               ...             ...              ...
# 11310          1101221           1101221         1383221           847873
# 11311          1101221           1101221         1383221           872624
# 11312          1101221           1101221         1383221           898103
# 11313          1101221           1101221         1383221           924332
# 11314          1101221           1101221         1383221           951332
# 11315          1101221           1101221         1383221           979126
# 11316          1101221           1101221         1383221          1007737
# 11317          1101221           1101221         1383221          1037190
# 11318          1101221           1101221         1383221          1067510
# 11319          1101221           1101221         1383221          1098721
# 11320           301942            301942           19942           301942
# 11321           301942            301942           19942           301942
# 11322           301942            301942           19942           301942
# 11323           301942            301942           19942           301942
# 11324           301942            301942           19942           301942
# 11325           301942            301942           19942           301942
# 11326           301942            301942           19942           301942
# 11327           301942            301942           19942           301942
# 11328           301942            301942           19942           301942
# 11329           301942            301942           19942           301942
# 11330           301942            301942           19942           301942
# 11331           301942            301942           19942           301942
# 11332           301942            301942           19942           301942
# 11333           301942            301942           19942           301942
# 11334           301942            301942           19942           301942
# 11335           301942            301942           19942           301942
# 11336           301942            301942           19942           301942
# 11337           301942            301942           19942           301942
# 11338           301942            301942           19942           301942
# 11339           301942            301942           19942           301942
#
#        EHP_m0_w0_r0_f0  ER_m0_w0_r0_f1  ...  EHP_m18_w3_r3_f4  \
# 0                53132           54266  ...             72430
# 1                53132           54326  ...             72430
# 2                53132           54387  ...             72430
# 3                53132           54451  ...             72430
# 4                53132           54516  ...             72430
# 5                53132           54584  ...             72430
# 6                53132           54653  ...             72430
# 7                53132           54724  ...             72430
# 8                53132           54798  ...
# <b>limit_output extension: Maximum message size of 10000 exceeded with 31095 characters</b>

# %%
Total_new.shape
# Out:
# (11340, 16416)

# %%
df = pd.concat([df_CID, Total_new], axis=1, join='outer')
df.shape
# Out:
# (11340, 16445)

# %%
df.to_csv('../Output_Data_CSV/Combination_with_Input_Data/df.csv',
          sep=';',
          index=None,
          header=True,
          encoding='utf-8')

# %%
b.Energy_Price + b.Carbon_Tax
# Out:
# 0        0.163500
# 1        0.163500
# 2        0.163500
# 3        0.163500
# 4        0.163500
# 5        0.163500
# 6        0.163500
# 7        0.163500
# 8        0.163500
# 9        0.163500
# 10       0.163500
# 11       0.163500
# 12       0.163500
# 13       0.163500
# 14       0.163500
# 15       0.163500
# 16       0.163500
# 17       0.163500
# 18       0.163500
# 19       0.163500
# 20       0.078246
# 21       0.078246
# 22       0.078246
# 23       0.078246
# 24       0.078246
# 25       0.078246
# 26       0.078246
# 27       0.078246
# 28       0.078246
# 29       0.078246
#            ...
# 11310    0.057200
# 11311    0.057200
# 11312    0.057200
# 11313    0.057200
# 11314    0.057200
# 11315    0.057200
# 11316    0.057200
# 11317    0.057200
# 11318    0.057200
# 11319    0.057200
# 11320    0.163500
# 11321    0.163500
# 11322    0.163500
# 11323    0.163500
# 11324    0.163500
# 11325    0.163500
# 11326    0.163500
# 11327    0.163500
# 11328    0.163500
# 11329    0.163500
# 11330    0.163500
# 11331    0.163500
# 11332    0.163500
# 11333    0.163500
# 11334    0.163500
# 11335    0.163500
# 11336    0.163500
# 11337    0.163500
# 11338    0.163500
# 11339    0.163500
# Length: 11340, dtype: float64

# %%
np.divide(np.add(b.Energy_Price, b.Carbon_Tax), np.add(1, b.Discount_Rate))
# Out:
# 0        0.155714
# 1        0.155714
# 2        0.155714
# 3        0.155714
# 4        0.155714
# 5        0.155714
# 6        0.155714
# 7        0.155714
# 8        0.155714
# 9        0.155714
# 10       0.155714
# 11       0.155714
# 12       0.155714
# 13       0.155714
# 14       0.155714
# 15       0.155714
# 16       0.155714
# 17       0.155714
# 18       0.155714
# 19       0.155714
# 20       0.074520
# 21       0.074520
# 22       0.074520
# 23       0.074520
# 24       0.074520
# 25       0.074520
# 26       0.074520
# 27       0.074520
# 28       0.074520
# 29       0.074520
#            ...
# 11310    0.054476
# 11311    0.054476
# 11312    0.054476
# 11313    0.054476
# 11314    0.054476
# 11315    0.054476
# 11316    0.054476
# 11317    0.054476
# 11318    0.054476
# 11319    0.054476
# 11320    0.155714
# 11321    0.155714
# 11322    0.155714
# 11323    0.155714
# 11324    0.155714
# 11325    0.155714
# 11326    0.155714
# 11327    0.155714
# 11328    0.155714
# 11329    0.155714
# 11330    0.155714
# 11331    0.155714
# 11332    0.155714
# 11333    0.155714
# 11334    0.155714
# 11335    0.155714
# 11336    0.155714
# 11337    0.155714
# 11338    0.155714
# 11339    0.155714
# Name: Energy_Price, Length: 11340, dtype: float64

# %%
A = np.divide(
    np.add(
        np.multiply(
            b.Energy_Price,
            np.power(np.add(1, b.Annual_Variation),
                     np.add(2, np.subtract(0, 2)))), b.Carbon_Tax),
    np.power(np.add(1, b.Discount_Rate), 2))

# %%
A
# Out:
# 0        0.148299
# 1        0.148299
# 2        0.148299
# 3        0.148299
# 4        0.148299
# 5        0.148299
# 6        0.148299
# 7        0.148299
# 8        0.148299
# 9        0.148299
# 10       0.148299
# 11       0.148299
# 12       0.148299
# 13       0.148299
# 14       0.148299
# 15       0.148299
# 16       0.148299
# 17       0.148299
# 18       0.148299
# 19       0.148299
# 20       0.070972
# 21       0.070972
# 22       0.070972
# 23       0.070972
# 24       0.070972
# 25       0.070972
# 26       0.070972
# 27       0.070972
# 28       0.070972
# 29       0.070972
#            ...
# 11310    0.051882
# 11311    0.051882
# 11312    0.051882
# 11313    0.051882
# 11314    0.051882
# 11315    0.051882
# 11316    0.051882
# 11317    0.051882
# 11318    0.051882
# 11319    0.051882
# 11320    0.148299
# 11321    0.148299
# 11322    0.148299
# 11323    0.148299
# 11324    0.148299
# 11325    0.148299
# 11326    0.148299
# 11327    0.148299
# 11328    0.148299
# 11329    0.148299
# 11330    0.148299
# 11331    0.148299
# 11332    0.148299
# 11333    0.148299
# 11334    0.148299
# 11335    0.148299
# 11336    0.148299
# 11337    0.148299
# 11338    0.148299
# 11339    0.148299
# Name: Energy_Price, Length: 11340, dtype: float64

# %%
B = np.add(
    np.multiply(
        b.Energy_Price,
        np.power(np.add(1, b.Annual_Variation), np.add(2, np.subtract(1, 2)))),
    b.Carbon_Tax)
B
# Out:
# 0        0.168270
# 1        0.168270
# 2        0.168270
# 3        0.168270
# 4        0.168270
# 5        0.168270
# 6        0.168270
# 7        0.168270
# 8        0.168270
# 9        0.168270
# 10       0.168270
# 11       0.168270
# 12       0.168270
# 13       0.168270
# 14       0.168270
# 15       0.168270
# 16       0.168270
# 17       0.168270
# 18       0.168270
# 19       0.168270
# 20       0.079708
# 21       0.079708
# 22       0.079708
# 23       0.079708
# 24       0.079708
# 25       0.079708
# 26       0.079708
# 27       0.079708
# 28       0.079708
# 29       0.079708
#            ...
# 11310    0.057772
# 11311    0.057772
# 11312    0.057772
# 11313    0.057772
# 11314    0.057772
# 11315    0.057772
# 11316    0.057772
# 11317    0.057772
# 11318    0.057772
# 11319    0.057772
# 11320    0.168270
# 11321    0.168270
# 11322    0.168270
# 11323    0.168270
# 11324    0.168270
# 11325    0.168270
# 11326    0.168270
# 11327    0.168270
# 11328    0.168270
# 11329    0.168270
# 11330    0.168270
# 11331    0.168270
# 11332    0.168270
# 11333    0.168270
# 11334    0.168270
# 11335    0.168270
# 11336    0.168270
# 11337    0.168270
# 11338    0.168270
# 11339    0.168270
# Name: Energy_Price, Length: 11340, dtype: float64
