# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Importation-of-necessary-libraries" data-toc-modified-id="Importation-of-necessary-libraries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Importation of necessary libraries</a></span></li><li><span><a href="#Combination-of-all-the-necessary-data" data-toc-modified-id="Combination-of-all-the-necessary-data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Combination of all the necessary data</a></span><ul class="toc-item"><li><span><a href="#Class-for-all-types-of-dwellings" data-toc-modified-id="Class-for-all-types-of-dwellings-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Class for all types of dwellings</a></span></li><li><span><a href="#Class-for-the-CID-type-dwellings" data-toc-modified-id="Class-for-the-CID-type-dwellings-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Class for the CID type dwellings</a></span><ul class="toc-item"><li><span><a href="#Class-for-the-DataFrame-with-U-factors" data-toc-modified-id="Class-for-the-DataFrame-with-U-factors-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Class for the DataFrame with U factors</a></span></li><li><span><a href="#Class-for-the-DataFrame-with-U-prices" data-toc-modified-id="Class-for-the-DataFrame-with-U-prices-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Class for the DataFrame with U prices</a></span></li></ul></li><li><span><a href="#Class-for-the-CCD-type-dwellings" data-toc-modified-id="Class-for-the-CCD-type-dwellings-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Class for the CCD type dwellings</a></span><ul class="toc-item"><li><span><a href="#Class-for-the-DataFrame-with-U-factors" data-toc-modified-id="Class-for-the-DataFrame-with-U-factors-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Class for the DataFrame with U factors</a></span></li><li><span><a href="#Class-for-the-DataFrame-with-U-prices" data-toc-modified-id="Class-for-the-DataFrame-with-U-prices-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Class for the DataFrame with U prices</a></span></li></ul></li><li><span><a href="#Class-for-the-ID-type-dwellings" data-toc-modified-id="Class-for-the-ID-type-dwellings-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Class for the ID type dwellings</a></span><ul class="toc-item"><li><span><a href="#Class-for-the-DataFrame-with-U-factors" data-toc-modified-id="Class-for-the-DataFrame-with-U-factors-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Class for the DataFrame with U factors</a></span></li><li><span><a href="#Class-for-the-DataFrame-with-U-prices" data-toc-modified-id="Class-for-the-DataFrame-with-U-prices-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Class for the DataFrame with U prices</a></span></li></ul></li></ul></li><li><span><a href="#Creation-of-some-calculable-columns" data-toc-modified-id="Creation-of-some-calculable-columns-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Creation of some calculable columns</a></span><ul class="toc-item"><li><span><a href="#Class-for-all-types-of-dwellings" data-toc-modified-id="Class-for-all-types-of-dwellings-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Class for all types of dwellings</a></span></li><li><span><a href="#Class-for-the-collective-dwellings" data-toc-modified-id="Class-for-the-collective-dwellings-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Class for the collective dwellings</a></span><ul class="toc-item"><li><span><a href="#Class-for-the-CID-type-with-U-Factors" data-toc-modified-id="Class-for-the-CID-type-with-U-Factors-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Class for the CID type with U Factors</a></span></li><li><span><a href="#Class-for-the-CID-Type-with-U-Prices" data-toc-modified-id="Class-for-the-CID-Type-with-U-Prices-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Class for the CID Type with U Prices</a></span></li><li><span><a href="#Class-for-the-CCD-type-with-U-Factors" data-toc-modified-id="Class-for-the-CCD-type-with-U-Factors-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Class for the CCD type with U Factors</a></span></li><li><span><a href="#Class-for-the-CCD-Type-with-U-Prices" data-toc-modified-id="Class-for-the-CCD-Type-with-U-Prices-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>Class for the CCD Type with U Prices</a></span></li></ul></li><li><span><a href="#Class-for-the-individual-dwellings" data-toc-modified-id="Class-for-the-individual-dwellings-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Class for the individual dwellings</a></span><ul class="toc-item"><li><span><a href="#Class-for-the-ID-Type-with-U-Factors" data-toc-modified-id="Class-for-the-ID-Type-with-U-Factors-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Class for the ID Type with U Factors</a></span></li><li><span><a href="#Class-for-the-DataFrame-with-U-Prices" data-toc-modified-id="Class-for-the-DataFrame-with-U-Prices-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Class for the DataFrame with U Prices</a></span></li></ul></li></ul></li><li><span><a href="#Creation-of-some-calculable-DataFrames" data-toc-modified-id="Creation-of-some-calculable-DataFrames-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Creation of some calculable DataFrames</a></span><ul class="toc-item"><li><span><a href="#Class-for-the-CID-type-dwellings" data-toc-modified-id="Class-for-the-CID-type-dwellings-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Class for the CID type dwellings</a></span><ul class="toc-item"><li><span><a href="#Class-for-the-DataFrame-with-U-Factors" data-toc-modified-id="Class-for-the-DataFrame-with-U-Factors-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Class for the DataFrame with U Factors</a></span></li><li><span><a href="#Class-for-the-DataFrame-with-U-Prices" data-toc-modified-id="Class-for-the-DataFrame-with-U-Prices-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Class for the DataFrame with U Prices</a></span></li></ul></li><li><span><a href="#Class-for-the-CCD-type-dwellings" data-toc-modified-id="Class-for-the-CCD-type-dwellings-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Class for the CCD type dwellings</a></span><ul class="toc-item"><li><span><a href="#Class-for-the-DataFrame-with-U-Factors" data-toc-modified-id="Class-for-the-DataFrame-with-U-Factors-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Class for the DataFrame with U Factors</a></span></li><li><span><a href="#Class-for-the-DataFrame-with-U-Prices" data-toc-modified-id="Class-for-the-DataFrame-with-U-Prices-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Class for the DataFrame with U Prices</a></span></li></ul></li><li><span><a href="#Class-for-the-ID-type-dwellings" data-toc-modified-id="Class-for-the-ID-type-dwellings-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Class for the ID type dwellings</a></span><ul class="toc-item"><li><span><a href="#Class-for-the-DataFrame-with-U-Factors" data-toc-modified-id="Class-for-the-DataFrame-with-U-Factors-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Class for the DataFrame with U Factors</a></span></li><li><span><a href="#Class-for-the-DataFrame-with-U-Prices" data-toc-modified-id="Class-for-the-DataFrame-with-U-Prices-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Class for the DataFrame with U Prices</a></span></li></ul></li></ul></li><li><span><a href="#Class-for-the-terminal-calculator-of-GHC" data-toc-modified-id="Class-for-the-terminal-calculator-of-GHC-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Class for the terminal calculator of GHC</a></span><ul class="toc-item"><li><span><a href="#Class-instantiation-for-each-type-of-dwelling" data-toc-modified-id="Class-instantiation-for-each-type-of-dwelling-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Class instantiation for each type of dwelling</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Importation of necessary libraries

# %%
import pandas as pd

import itertools

import numpy as np

# %% [markdown]
# # Combination of all the necessary data
#
# ## Class for all types of dwellings

# %%
class All_Types:
    def __init__(self, *args):
        self.df_1 = df_Climate_Zone = pd.read_csv(
            '../Input_Data_CSV/Climate_Zone.csv',
            sep=';',
            index_col=None,
            header=0)
        self.df_2 = pd.read_csv(
            '../Input_Data_CSV/Housing_Characteristics.csv',
            sep=';',
            index_col=None,
            header=0)
        self.df_3 = pd.read_csv('../Input_Data_CSV/Headcount.csv',
                                sep=';',
                                index_col=None,
                                header=0)
        self.df_4 = pd.read_csv('../Input_Data_CSV/Heating_System.csv',
                                sep=';',
                                index_col=None,
                                header=0)
        self.df_5 = pd.read_csv('../Input_Data_CSV/Economic_Hypothesis.csv',
                                sep=';',
                                index_col=None,
                                header=0)
        self.df_6 = pd.read_csv('../Input_Data_CSV/Wall_Investment.csv',
                                sep=';',
                                index_col=None,
                                header=0)
        self.df_7 = pd.read_csv('../Input_Data_CSV/Window_Investment.csv',
                                sep=';',
                                index_col=None,
                                header=0)
        self.df_8 = pd.read_csv('../Input_Data_CSV/Roof_Investment.csv',
                                sep=';',
                                index_col=None,
                                header=0)
        self.df_9 = pd.read_csv('../Input_Data_CSV/Floor_Investment.csv',
                                sep=';',
                                index_col=None,
                                header=0)

# %%
All_Types.mro()
# Out:
# [__main__.All_Types, object]

# %% [markdown]
# ## Class for the CID type dwellings

# %%
class CID_Type(All_Types):
    def __init__(self, *args):
        super().__init__(*args)

    def Combine_Lists(self):
        self.list_combined = []
        list_dwelling_type = ['CID']
        list_climate_type = self.df_1.iloc[:, 0].tolist()
        list_construction_period = self.df_2.iloc[:21, 1].tolist()[::3]
        list_size_factor = self.df_2.iloc[:3, 2].tolist()
        list_heating_system = [
            'ER', 'GB', 'CGB', 'OB', 'COB', 'EHP2', 'WB', 'WPB', 'EHP'
        ]
        list_initial_age = list(range(20))
        self.list_combined.append(list_dwelling_type)
        self.list_combined.append(list_climate_type)
        self.list_combined.append(list_construction_period)
        self.list_combined.append(list_size_factor)
        self.list_combined.append(list_heating_system)
        self.list_combined.append(list_initial_age)
        return self.list_combined

    def Generate_DF(self):
        self.Combine_Lists()
        itertools_product = list(itertools.product(*self.list_combined))
        self.df = pd.DataFrame(itertools_product,
                               columns=[
                                   'Dwelling Type', 'Climate Type',
                                   'Construction Period', 'Size Factor',
                                   'Heating System', 'Initial Age'
                               ])
        return self.df

    def Merge_DFs(self):
        self.Generate_DF()
        self.df = self.df.merge(self.df_1, how='left', on=['Climate Type'])
        self.df = self.df.merge(self.df_2.iloc[:21, 1:9],
                                how='left',
                                on=['Construction Period', 'Size Factor'])
        self.df = self.df.merge(self.df_4.iloc[:9, :],
                                how='left',
                                on=['Heating System'])
        return self.df

    def Add_Columns(self):
        self.Merge_DFs()
        self.df[self.df_5.columns[1]] = self.df_5.iloc[0, 1]
        self.df[self.df_5.columns[2]] = self.df_5.iloc[0, 2]
        self.df[self.df_5.columns[3]] = self.df_5.iloc[0, 3]
        self.df[self.df_5.columns[4]] = self.df_5.iloc[0, 4]
        return self.df

    def Concat_DFs(self):
        self.Add_Columns()
        self.df = pd.concat([self.df, self.df_3.iloc[0:11340, 6]],
                            axis=1,
                            join='outer')
        return self.df

    def Reorder_Columns(self):
        self.Concat_DFs()
        cols = self.df.columns.tolist()
        reordered_cols = cols[:2] + cols[6:7] + cols[2:4] + cols[7:13] + cols[
            5:6] + cols[4:5] + cols[13:28] + cols[28:29]
        self.df = self.df[reordered_cols]
        return self.df

# %%
CID_Type.mro()
# Out:
# [__main__.CID_Type, __main__.All_Types, object]

# %% [markdown]
# ### Class for the DataFrame with U factors

# %%
class CID_Factors(CID_Type):
    def __init__(self, *args):
        super().__init__(*args)

    def Add_U_Factors(self):
        self.Reorder_Columns()
        self.df = self.df.merge(
            self.df_2.loc[:20, ['Construction Period', 'Size Factor', 'Um0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for m in range(18):
            self.df['Um' + str(m + 1)] = self.df_6.iloc[m, 2]
        self.df = self.df.merge(
            self.df_2.loc[:20, ['Construction Period', 'Size Factor', 'Uw0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for w in range(3):
            self.df['Uw' + str(w + 1)] = self.df_7.iloc[w, 2]
        self.df = self.df.merge(
            self.df_2.loc[:20, ['Construction Period', 'Size Factor', 'Ur0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for r in range(3):
            self.df['Ur' + str(r + 1)] = self.df_8.iloc[r, 2]
        self.df = self.df.merge(
            self.df_2.loc[:20, ['Construction Period', 'Size Factor', 'Uf0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for f in range(5):
            self.df['Uf' + str(f + 1)] = self.df_9.iloc[f, 2]
        return self.df

    def DF_with_U(self):
        self.Add_U_Factors()
        return self.df

# %%
CID_Factors.mro()
# Out:
# [__main__.CID_Factors, __main__.CID_Type, __main__.All_Types, object]

# %% [markdown]
# ### Class for the DataFrame with U prices

# %%
class CID_Prices(CID_Type):
    def __init__(self, *args):
        super().__init__(*args)

    def Add_U_Prices(self):
        self.Reorder_Columns()
        self.df['Um0'] = 0
        for m in range(18):
            self.df['Um' + str(m + 1)] = self.df_6.iloc[m, 3]
        self.df['Uw0'] = 0
        for w in range(3):
            self.df['Uw' + str(w + 1)] = self.df_7.iloc[w, 3]
        self.df['Ur0'] = 0
        for r in range(3):
            self.df['Ur' + str(r + 1)] = self.df_8.iloc[r, 3]
        self.df['Uf0'] = 0
        for f in range(5):
            self.df['Uf' + str(f + 1)] = self.df_9.iloc[f, 3]
        return self.df

    def DF_with_U(self):
        self.Add_U_Prices()
        return self.df

# %%
CID_Prices.mro()
# Out:
# [__main__.CID_Prices, __main__.CID_Type, __main__.All_Types, object]

# %% [markdown]
# ## Class for the CCD type dwellings

# %%
class CCD_Type(All_Types):
    def __init__(self, *args):
        super().__init__(*args)

    def Combine_Lists(self):
        self.list_combined = []
        list_dwelling_type = ['CCD']
        list_climate_type = self.df_1.iloc[:, 0].tolist()
        list_construction_period = self.df_2.iloc[:21, 1].tolist()[::3]
        list_size_factor = self.df_2.iloc[:3, 2].tolist()
        list_heating_system = [
            'GB', 'CGB', 'OB', 'COB', 'EHP2', 'WB', 'WPB', 'EHP'
        ]
        list_initial_age = list(range(20))
        self.list_combined.append(list_dwelling_type)
        self.list_combined.append(list_climate_type)
        self.list_combined.append(list_construction_period)
        self.list_combined.append(list_size_factor)
        self.list_combined.append(list_heating_system)
        self.list_combined.append(list_initial_age)
        return self.list_combined

    def Generate_DF(self):
        self.Combine_Lists()
        itertools_product = list(itertools.product(*self.list_combined))
        self.df = pd.DataFrame(itertools_product,
                               columns=[
                                   'Dwelling Type', 'Climate Type',
                                   'Construction Period', 'Size Factor',
                                   'Heating System', 'Initial Age'
                               ])
        return self.df

    def Merge_DFs(self):
        self.Generate_DF()
        self.df = self.df.merge(self.df_1, how='left', on=['Climate Type'])
        self.df = self.df.merge(self.df_2.iloc[:21, 1:9],
                                how='left',
                                on=['Construction Period', 'Size Factor'])
        self.df = self.df.merge(self.df_4.iloc[9:17, :],
                                how='left',
                                on=['Heating System'])
        return self.df

    def Add_Columns(self):
        self.Merge_DFs()
        self.df[self.df_5.columns[1]] = self.df_5.iloc[1, 1]
        self.df[self.df_5.columns[2]] = self.df_5.iloc[1, 2]
        self.df[self.df_5.columns[3]] = self.df_5.iloc[1, 3]
        self.df[self.df_5.columns[4]] = self.df_5.iloc[1, 4]
        return self.df

    def Concat_DFs(self):
        self.Add_Columns()
        self.df = pd.concat(
            [self.df, self.df_3.iloc[11340:21420, 6].reset_index(drop=True)],
            axis=1,
            join='outer')
        return self.df

    def Reorder_Columns(self):
        self.Concat_DFs()
        cols = self.df.columns.tolist()
        reordered_cols = cols[:2] + cols[6:7] + cols[2:4] + cols[7:13] + cols[
            5:6] + cols[4:5] + cols[13:28] + cols[28:29]
        self.df = self.df[reordered_cols]
        return self.df

# %%
CCD_Type.mro()
# Out:
# [__main__.CCD_Type, __main__.All_Types, object]

# %% [markdown]
# ### Class for the DataFrame with U factors

# %%
class CCD_Factors(CCD_Type):
    def __init__(self, *args):
        super().__init__(*args)

    def Add_U_Factors(self):
        self.Reorder_Columns()
        self.df = self.df.merge(
            self.df_2.loc[:20, ['Construction Period', 'Size Factor', 'Um0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for m in range(18):
            self.df['Um' + str(m + 1)] = self.df_6.iloc[m, 2]
        self.df = self.df.merge(
            self.df_2.loc[:20, ['Construction Period', 'Size Factor', 'Uw0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for w in range(3):
            self.df['Uw' + str(w + 1)] = self.df_7.iloc[w, 2]
        self.df = self.df.merge(
            self.df_2.loc[:20, ['Construction Period', 'Size Factor', 'Ur0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for r in range(3):
            self.df['Ur' + str(r + 1)] = self.df_8.iloc[r, 2]
        self.df = self.df.merge(
            self.df_2.loc[:20, ['Construction Period', 'Size Factor', 'Uf0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for f in range(5):
            self.df['Uf' + str(f + 1)] = self.df_9.iloc[f, 2]
        return self.df

    def DF_with_U(self):
        self.Add_U_Factors()
        return self.df

# %%
CCD_Factors.mro()
# Out:
# [__main__.CCD_Factors, __main__.CCD_Type, __main__.All_Types, object]

# %% [markdown]
# ### Class for the DataFrame with U prices

# %%
class CCD_Prices(CCD_Type):
    def __init__(self, *args):
        super().__init__(*args)

    def Add_U_Prices(self):
        self.Reorder_Columns()
        self.df['Um0'] = 0
        for m in range(18):
            self.df['Um' + str(m + 1)] = self.df_6.iloc[m, 3]
        self.df['Uw0'] = 0
        for w in range(3):
            self.df['Uw' + str(w + 1)] = self.df_7.iloc[w, 3]
        self.df['Ur0'] = 0
        for r in range(3):
            self.df['Ur' + str(r + 1)] = self.df_8.iloc[r, 3]
        self.df['Uf0'] = 0
        for f in range(5):
            self.df['Uf' + str(f + 1)] = self.df_9.iloc[f, 3]
        return self.df

    def DF_with_U(self):
        self.Add_U_Prices()
        return self.df

# %%
CCD_Prices.mro()
# Out:
# [__main__.CCD_Prices, __main__.CCD_Type, __main__.All_Types, object]

# %% [markdown]
# ## Class for the ID type dwellings

# %%
class ID_Type(All_Types):
    def __init__(self, *args):
        super().__init__(*args)

    def Combine_Lists(self):
        self.list_combined = []
        list_dwelling_type = ['ID']
        list_climate_type = self.df_1.iloc[:, 0].tolist()
        list_construction_period = self.df_2.iloc[21:, 1].tolist()[::3]
        list_size_factor = self.df_2.iloc[:3, 2].tolist()
        list_heating_system = [
            'ER', 'GB', 'CGB', 'OB', 'COB', 'EHP2', 'WB', 'WPB', 'EHP'
        ]
        list_initial_age = list(range(20))
        self.list_combined.append(list_dwelling_type)
        self.list_combined.append(list_climate_type)
        self.list_combined.append(list_construction_period)
        self.list_combined.append(list_size_factor)
        self.list_combined.append(list_heating_system)
        self.list_combined.append(list_initial_age)
        return self.list_combined

    def Generate_DF(self):
        self.Combine_Lists()
        itertools_product = list(itertools.product(*self.list_combined))
        self.df = pd.DataFrame(itertools_product,
                               columns=[
                                   'Dwelling Type', 'Climate Type',
                                   'Construction Period', 'Size Factor',
                                   'Heating System', 'Initial Age'
                               ])
        return self.df

    def Merge_DFs(self):
        self.Generate_DF()
        self.df = self.df.merge(self.df_1, how='left', on=['Climate Type'])
        self.df = self.df.merge(self.df_2.iloc[21:, 1:9],
                                how='left',
                                on=['Construction Period', 'Size Factor'])
        self.df = self.df.merge(self.df_4.iloc[17:, :],
                                how='left',
                                on=['Heating System'])
        return self.df

    def Add_Columns(self):
        self.Merge_DFs()
        self.df[self.df_5.columns[1]] = self.df_5.iloc[2, 1]
        self.df[self.df_5.columns[2]] = self.df_5.iloc[2, 2]
        self.df[self.df_5.columns[3]] = self.df_5.iloc[2, 3]
        self.df[self.df_5.columns[4]] = self.df_5.iloc[2, 4]
        return self.df

    def Concat_DFs(self):
        self.Add_Columns()
        self.df = pd.concat(
            [self.df, self.df_3.iloc[21420:, 6].reset_index(drop=True)],
            axis=1,
            join='outer')
        return self.df

    def Reorder_Columns(self):
        self.Concat_DFs()
        cols = self.df.columns.tolist()
        reordered_cols = cols[:2] + cols[6:7] + cols[2:4] + cols[7:13] + cols[
            5:6] + cols[4:5] + cols[13:28] + cols[28:29]
        self.df = self.df[reordered_cols]
        return self.df

# %%
ID_Type.mro()
# Out:
# [__main__.ID_Type, __main__.All_Types, object]

# %% [markdown]
# ### Class for the DataFrame with U factors

# %%
class ID_Factors(ID_Type):
    def __init__(self, *args):
        super().__init__(*args)

    def Add_U_Factors(self):
        self.Reorder_Columns()
        self.df = self.df.merge(
            self.df_2.loc[21:, ['Construction Period', 'Size Factor', 'Um0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for m in range(19):
            self.df['Um' + str(m + 1)] = self.df_6.iloc[m + 18, 2]
        self.df = self.df.merge(
            self.df_2.loc[21:, ['Construction Period', 'Size Factor', 'Uw0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for w in range(3):
            self.df['Uw' + str(w + 1)] = self.df_7.iloc[w + 3, 2]
        self.df = self.df.merge(
            self.df_2.loc[21:, ['Construction Period', 'Size Factor', 'Ur0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for r in range(7):
            self.df['Ur' + str(r + 1)] = self.df_8.iloc[r + 3, 2]
        self.df = self.df.merge(
            self.df_2.loc[21:, ['Construction Period', 'Size Factor', 'Uf0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for f in range(3):
            self.df['Uf' + str(f + 1)] = self.df_9.iloc[f + 5, 2]
        return self.df

    def DF_with_U(self):
        self.Add_U_Factors()
        return self.df

# %%
ID_Factors.mro()
# Out:
# [__main__.ID_Factors, __main__.ID_Type, __main__.All_Types, object]

# %% [markdown]
# ### Class for the DataFrame with U prices

# %%
class ID_Prices(ID_Type):
    def __init__(self, *args):
        super().__init__(*args)

    def Add_U_Prices(self):
        self.Reorder_Columns()
        self.df['Um0'] = 0
        for m in range(19):
            self.df['Um' + str(m + 1)] = self.df_6.iloc[m + 18, 3]
        self.df['Uw0'] = 0
        for w in range(3):
            self.df['Uw' + str(w + 1)] = self.df_7.iloc[w + 3, 3]
        self.df['Ur0'] = 0
        for r in range(7):
            self.df['Ur' + str(r + 1)] = self.df_8.iloc[r + 3, 3]
        self.df['Uf0'] = 0
        for f in range(3):
            self.df['Uf' + str(f + 1)] = self.df_9.iloc[f + 5, 3]
        return self.df

    def DF_with_U(self):
        self.Add_U_Prices()
        return self.df

# %%
ID_Prices.mro()
# Out:
# [__main__.ID_Prices, __main__.ID_Type, __main__.All_Types, object]

# %% [markdown]
# # Creation of some calculable columns
#
# ## Class for all types of dwellings

# %%
class Calculable_Columns:
    def Rename_Columns(self):
        self.df.columns = self.df.columns.str.replace(' ', '_')
        return self.df

    def Carbon_Tax(self):
        self.Rename_Columns()
        self.df['Carbon_Tax'] = np.multiply(self.df.Emission_Factor,
                                            self.df.Carbon_Price)
        return self.df

    def Energy_Bill(self):
        self.Carbon_Tax()
        self.df['Energy_Bill'] = 0
        for i in range(1, 41):
            self.df['Energy_Bill'] = np.add(
                np.divide(
                    np.add(
                        np.multiply(
                            self.df.Energy_Price,
                            np.power(np.add(1, self.df.Annual_Variation),
                                     np.add(i, np.subtract(self.year, 2)))),
                        self.df.Carbon_Tax),
                    np.power(np.add(1, self.df.Discount_Rate), i)),
                self.df.Energy_Bill)
        return self.df

    def Inflation_Rate_1st(self):
        self.Rename_Columns()
        self.df['Inflation_Rate_1st'] = np.power(
            np.add(1, self.df.Inflation_Rate),
            np.subtract(np.add(18, self.year), self.df.Initial_Age))
        return self.df

    def Inflation_Rate_2nd(self):
        self.Rename_Columns()
        self.df['Inflation_Rate_2nd'] = np.power(
            np.add(1, self.df.Inflation_Rate),
            np.subtract(np.add(38, self.year), self.df.Initial_Age))
        return self.df

    def Discount_1st(self):
        self.Rename_Columns()
        self.df['Discount_1st'] = np.power(
            np.add(1, self.df.Discount_Rate),
            np.subtract(19, self.df.Initial_Age))
        return self.df

    def Discount_2nd(self):
        self.Rename_Columns()
        self.df['Discount_2nd'] = np.power(
            np.add(1, self.df.Discount_Rate),
            np.subtract(39, self.df.Initial_Age))
        return self.df

    def Time_Factor_1(self):
        self.Inflation_Rate_1st()
        self.Inflation_Rate_2nd()
        self.Discount_1st()
        self.Discount_2nd()
        self.df['Time_Factor_1'] = np.divide(
            np.add(
                np.multiply(self.df.Inflation_Rate_1st, self.df.Discount_2nd),
                np.multiply(self.df.Inflation_Rate_2nd, self.df.Discount_1st)),
            np.multiply(self.df.Discount_1st, self.df.Discount_2nd))
        return self.df

    def UEN_Cost_1(self):
        self.Energy_Bill()
        self.Time_Factor_1()
        self.df['UEN_Cost_1'] = np.add(
            np.multiply(self.df.B_Investment, self.df.Time_Factor_1),
            np.divide(self.df.Energy_Bill, self.df.Efficiency))
        return self.df

    def Discount_20(self):
        self.Rename_Columns()
        self.df['Discount_20'] = np.power(np.add(1, self.df.Discount_Rate), 20)
        return self.df

    def Inflation_Rate_0(self):
        self.Rename_Columns()
        self.df['Inflation_Rate_0'] = np.power(
            np.add(1, self.df.Inflation_Rate), np.subtract(self.year, 1))
        return self.df

    def Inflation_Rate_20(self):
        self.Rename_Columns()
        self.df['Inflation_Rate_20'] = np.power(
            np.add(1, self.df.Inflation_Rate), np.add(19, self.year))
        return self.df

    def Time_Factor_2(self):
        self.Inflation_Rate_0()
        self.Inflation_Rate_20()
        self.Discount_20()
        self.df['Time_Factor_2'] = np.divide(
            np.add(np.multiply(self.df.Discount_20, self.df.Inflation_Rate_0),
                   self.df.Inflation_Rate_20), self.df.Discount_20)
        return self.df

    def UEN_Cost_2(self):
        self.Energy_Bill()
        self.Time_Factor_2()
        self.df['UEN_Cost_2'] = np.add(
            np.multiply(self.df.B_Investment, self.df.Time_Factor_2),
            np.divide(self.df.Energy_Bill, self.df.Efficiency))
        return self.df

    def No_Gas_Prices(self):
        self.Carbon_Tax()
        self.df['No_Gas_Prices'] = 0
        for i in range(1, 41):
            self.df['No_Gas_Prices'] = np.add(
                np.divide(
                    np.add(
                        np.multiply(
                            self.df.Specific_Gas_Price,
                            np.power(np.add(1, self.df.Annual_Variation),
                                     np.add(i, np.subtract(self.year, 2)))),
                        self.df.Carbon_Tax),
                    np.power(np.add(1, self.df.Discount_Rate), i),
                ), self.df.No_Gas_Prices)
        return self.df

    def UEN_Cost_3(self):
        self.No_Gas_Prices()
        self.Time_Factor_2()
        self.df['UEN_Cost_3'] = np.add(
            np.multiply(self.df.B_Investment, self.df.Time_Factor_2),
            np.divide(self.df.No_Gas_Prices, self.df.Efficiency))
        return self.df

    def Maintenance(self):
        self.Rename_Columns()
        self.df['Maintenance'] = 0
        for i in range(40):
            self.df['Maintenance'] = np.add(
                np.divide(
                    np.multiply(
                        self.df.Maintenance_Cost,
                        np.power(np.add(1, self.df.Inflation_Rate),
                                 np.add(i, np.subtract(self.year, 1)))),
                    np.power(np.add(1, self.df.Discount_Rate), i)),
                self.df.Maintenance)
        return self.df

    def Fixed_Cost_1(self):
        self.Maintenance()
        self.Time_Factor_1()
        self.df['Fixed_Cost_1'] = np.add(
            np.multiply(self.df.A_Investment, self.df.Time_Factor_1),
            self.df.Maintenance)
        return self.df

    def Fixed_Cost_2(self):
        self.Maintenance()
        self.Time_Factor_2()
        self.df['Fixed_Cost_2'] = np.add(
            np.multiply(self.df.A_Investment, self.df.Time_Factor_2),
            np.add(self.df.Maintenance, self.df.Same_Switch_Cost))
        return self.df

    def Fixed_Cost_4(self):
        self.Maintenance()
        self.Time_Factor_2()
        self.df['Fixed_Cost_4'] = np.add(
            np.multiply(self.df.A_Investment, self.df.Time_Factor_2),
            np.add(self.df.Maintenance, self.df.Different_Switch_Cost))
        return self.df

    def Control_Cost(self):
        self.Rename_Columns()
        self.df['Control_Cost'] = np.multiply(self.df.Delevery_Type_Cost,
                                              self.df.Surface)
        return self.df

    def Fixed_Cost_3(self):
        self.Fixed_Cost_2()
        self.Control_Cost()
        self.df['Fixed_Cost_3'] = np.add(self.df.Fixed_Cost_2,
                                         self.df.Control_Cost)
        return self.df

    def Fixed_Cost_5(self):
        self.Fixed_Cost_4()
        self.Control_Cost()
        self.df['Fixed_Cost_5'] = np.add(self.df.Fixed_Cost_4,
                                         self.df.Control_Cost)
        return self.df

# %%
Calculable_Columns.mro()
# Out:
# [__main__.Calculable_Columns, object]

# %% [markdown]
# ## Class for the collective dwellings

# %%
class Calculable_Columns_for_CxD(Calculable_Columns):
    def Surface_M(self):
        self.Rename_Columns()
        self.df['Surface_M'] = np.multiply(
            np.multiply(
                np.multiply(
                    np.subtract(1, self.df.Share_of_Windows),
                    np.sqrt(
                        np.multiply(self.df.Surface,
                                    self.df.Dwelling_per_Floor))), 4),
            np.multiply(self.df.Ceiling_Height, np.add(self.df.Floors, 1)))
        return self.df

    def Surface_W(self):
        self.Rename_Columns()
        self.df['Surface_W'] = np.multiply(
            np.multiply(
                np.multiply(
                    self.df.Share_of_Windows,
                    np.sqrt(
                        np.multiply(self.df.Surface,
                                    self.df.Dwelling_per_Floor))), 4),
            np.multiply(self.df.Ceiling_Height, np.add(self.df.Floors, 1)))
        return self.df

# %%
Calculable_Columns_for_CxD.mro()
# Out:
# [__main__.Calculable_Columns_for_CxD, __main__.Calculable_Columns, object]

# %% [markdown]
# ### Class for the CID type with U Factors

# %%
class Columns_for_CID_U_Factors(CID_Factors, Calculable_Columns_for_CxD):
    def __init__(self, year, *args):
        super().__init__(*args)
        self.year = year
        self.DF_with_U()

    def Surface_R(self):
        self.Rename_Columns()
        self.df['Surface_R'] = np.multiply(self.df.Surface,
                                           self.df.Dwelling_per_Floor)
        return self.df

    def Heightened_Surface_Habitable(self):
        self.Surface_R()
        self.df['Heightened_Surface_Habitable'] = np.multiply(
            np.multiply(self.df.Surface_R, np.add(self.df.Floors, 1)),
            self.df.Ceiling_Height)
        return self.df

    def UEN_per_Dwelling_2(self):
        self.Rename_Columns()
        self.df['UEN_per_Dwelling_2'] = np.multiply(
            np.multiply(
                np.multiply(self.df.Ceiling_Height, self.df.Intermittence),
                np.multiply(self.df.Degrees_of_Reference, self.df.Surface)),
            0.01)
        return self.df

    def Weighted_Surface(self):
        self.Surface_M()
        self.Surface_W()
        self.Surface_R()
        self.df.loc[:, 'Um0':'Um18'] = self.df.loc[:, 'Um0':'Um18'].apply(
            lambda x: np.multiply(x, self.df.Surface_M))
        self.df.loc[:, 'Uw0':'Uw3'] = self.df.loc[:, 'Uw0':'Uw3'].apply(
            lambda x: np.multiply(x, self.df.Surface_W))
        self.df.loc[:, 'Ur0':'Ur3'] = self.df.loc[:, 'Ur0':'Ur3'].apply(
            lambda x: np.multiply(x, self.df.Surface_R))
        self.df.loc[:, 'Uf0':'Uf5'] = self.df.loc[:, 'Uf0':'Uf5'].apply(
            lambda x: np.multiply(x, self.df.Surface_R))
        return self.df

    def Duo_Weighted_Surface(self):
        self.Weighted_Surface()
        columns_list = []
        columns_list_1 = []
        columns_list_2 = []
        for m in range(19):
            for w in range(4):
                column_name = 'U_m' + str(m) + '_w' + str(w)
                columns_list_1.append(column_name)
        for r in range(4):
            for f in range(6):
                column_name = 'U_r' + str(r) + '_f' + str(f)
                columns_list_2.append(column_name)
        columns_list = columns_list_1 + columns_list_2
        self.df = pd.concat([
            self.df,
            pd.DataFrame(0, index=self.df.index, columns=columns_list)
        ],
                            axis=1)
        self.df[columns_list_1] = self.df[columns_list_1].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        self.df[columns_list_2] = self.df[columns_list_2].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        selected_columns = self.df.loc[:, 'Um0':'Uf5'].columns.tolist()
        self.df = self.df.drop(selected_columns, axis=1)
        return self.df

    def Add_Created_Columns(self):
        self.Heightened_Surface_Habitable()
        self.UEN_per_Dwelling_2()
        self.Duo_Weighted_Surface()
        self.UEN_Cost_1()
        self.UEN_Cost_2()
        self.UEN_Cost_3()
        return self.df

# %%
Columns_for_CID_U_Factors.mro()
# Out:
# [__main__.Columns_for_CID_U_Factors,
#  __main__.CID_Factors,
#  __main__.CID_Type,
#  __main__.All_Types,
#  __main__.Calculable_Columns_for_CxD,
#  __main__.Calculable_Columns,
#  object]

# %% [markdown]
# ### Class for the CID Type with U Prices

# %%
class Columns_for_CID_U_Prices(CID_Prices, Calculable_Columns_for_CxD):
    def __init__(self, year, *args):
        super().__init__(*args)
        self.year = year
        self.DF_with_U()

    def Dwelling_Total(self):
        self.Rename_Columns()
        self.df['Dwelling_Total'] = np.multiply(self.df.Dwelling_per_Floor,
                                                np.add(self.df.Floors, 1))
        return self.df

    def Priced_Surface(self):
        self.Surface_M()
        self.Surface_W()
        self.Dwelling_Total()
        self.df.loc[:, 'Um0':'Um18'] = self.df.loc[:, 'Um0':'Um18'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface_M, self.df.Dwelling_Total)))
        self.df.loc[:, 'Uw0':'Uw3'] = self.df.loc[:, 'Uw0':'Uw3'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface_W, self.df.Dwelling_Total)))
        self.df.loc[:, 'Ur0':'Ur3'] = self.df.loc[:, 'Ur0':'Ur3'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface, np.add(self.df.Floors, 1))))
        self.df.loc[:, 'Uf0':'Uf5'] = self.df.loc[:, 'Uf0':'Uf5'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface, np.add(self.df.Floors, 1))))
        return self.df

    def Duo_Priced_Surface(self):
        self.Priced_Surface()
        columns_list = []
        columns_list_1 = []
        columns_list_2 = []
        for m in range(19):
            for w in range(4):
                column_name = 'U_m' + str(m) + '_w' + str(w)
                columns_list_1.append(column_name)
        for r in range(4):
            for f in range(6):
                column_name = 'U_r' + str(r) + '_f' + str(f)
                columns_list_2.append(column_name)
        columns_list = columns_list_1 + columns_list_2
        self.df = pd.concat([
            self.df,
            pd.DataFrame(0, index=self.df.index, columns=columns_list)
        ],
                            axis=1)
        self.df[columns_list_1] = self.df[columns_list_1].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        self.df[columns_list_2] = self.df[columns_list_2].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        selected_columns = self.df.loc[:, 'Um0':'Uf5'].columns.tolist()
        self.df = self.df.drop(selected_columns, axis=1)
        return self.df

    def Add_Created_Columns(self):
        self.Duo_Priced_Surface()
        self.Fixed_Cost_1()
        self.Fixed_Cost_3()
        self.Fixed_Cost_5()
        return self.df

# %%
Columns_for_CID_U_Prices.mro()
# Out:
# [__main__.Columns_for_CID_U_Prices,
#  __main__.CID_Prices,
#  __main__.CID_Type,
#  __main__.All_Types,
#  __main__.Calculable_Columns_for_CxD,
#  __main__.Calculable_Columns,
#  object]

# %% [markdown]
# ### Class for the CCD type with U Factors

# %%
class Columns_for_CCD_U_Factors(CCD_Factors, Calculable_Columns_for_CxD):
    def __init__(self, year, *args):
        super().__init__(*args)
        self.year = year
        self.DF_with_U()

    def Surface_R(self):
        self.Rename_Columns()
        self.df['Surface_R'] = np.multiply(self.df.Surface,
                                           self.df.Dwelling_per_Floor)
        return self.df

    def Heightened_Surface_Habitable(self):
        self.Surface_R()
        self.df['Heightened_Surface_Habitable'] = np.multiply(
            np.multiply(self.df.Surface_R, np.add(self.df.Floors, 1)),
            self.df.Ceiling_Height)
        return self.df

    def UEN_per_Dwelling_2(self):
        self.Rename_Columns()
        self.df['UEN_per_Dwelling_2'] = np.multiply(
            np.multiply(
                np.multiply(self.df.Ceiling_Height, self.df.Intermittence),
                np.multiply(self.df.Degrees_of_Reference, self.df.Surface)),
            0.01)
        return self.df

    def Weighted_Surface(self):
        self.Surface_M()
        self.Surface_W()
        self.Surface_R()
        self.df.loc[:, 'Um0':'Um18'] = self.df.loc[:, 'Um0':'Um18'].apply(
            lambda x: np.multiply(x, self.df.Surface_M))
        self.df.loc[:, 'Uw0':'Uw3'] = self.df.loc[:, 'Uw0':'Uw3'].apply(
            lambda x: np.multiply(x, self.df.Surface_W))
        self.df.loc[:, 'Ur0':'Ur3'] = self.df.loc[:, 'Ur0':'Ur3'].apply(
            lambda x: np.multiply(x, self.df.Surface_R))
        self.df.loc[:, 'Uf0':'Uf5'] = self.df.loc[:, 'Uf0':'Uf5'].apply(
            lambda x: np.multiply(x, self.df.Surface_R))
        return self.df

    def Duo_Weighted_Surface(self):
        self.Weighted_Surface()
        columns_list = []
        columns_list_1 = []
        columns_list_2 = []
        for m in range(19):
            for w in range(4):
                column_name = 'U_m' + str(m) + '_w' + str(w)
                columns_list_1.append(column_name)
        for r in range(4):
            for f in range(6):
                column_name = 'U_r' + str(r) + '_f' + str(f)
                columns_list_2.append(column_name)
        columns_list = columns_list_1 + columns_list_2
        self.df = pd.concat([
            self.df,
            pd.DataFrame(0, index=self.df.index, columns=columns_list)
        ],
                            axis=1)
        self.df[columns_list_1] = self.df[columns_list_1].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        self.df[columns_list_2] = self.df[columns_list_2].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        selected_columns = self.df.loc[:, 'Um0':'Uf5'].columns.tolist()
        self.df = self.df.drop(selected_columns, axis=1)
        return self.df

    def Add_Created_Columns(self):
        self.Heightened_Surface_Habitable()
        self.UEN_per_Dwelling_2()
        self.Duo_Weighted_Surface()
        self.UEN_Cost_1()
        self.UEN_Cost_2()
        self.UEN_Cost_3()
        return self.df

# %%
Columns_for_CCD_U_Factors.mro()
# Out:
# [__main__.Columns_for_CCD_U_Factors,
#  __main__.CCD_Factors,
#  __main__.CCD_Type,
#  __main__.All_Types,
#  __main__.Calculable_Columns_for_CxD,
#  __main__.Calculable_Columns,
#  object]

# %% [markdown]
# ### Class for the CCD Type with U Prices

# %%
class Columns_for_CCD_U_Prices(CCD_Prices, Calculable_Columns_for_CxD):
    def __init__(self, year, *args):
        super().__init__(*args)
        self.year = year
        self.DF_with_U()

    def Dwelling_Total(self):
        self.Rename_Columns()
        self.df['Dwelling_Total'] = np.multiply(self.df.Dwelling_per_Floor,
                                                np.add(self.df.Floors, 1))
        return self.df

    def Priced_Surface(self):
        self.Surface_M()
        self.Surface_W()
        self.Dwelling_Total()
        self.df.loc[:, 'Um0':'Um18'] = self.df.loc[:, 'Um0':'Um18'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface_M, self.df.Dwelling_Total)))
        self.df.loc[:, 'Uw0':'Uw3'] = self.df.loc[:, 'Uw0':'Uw3'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface_W, self.df.Dwelling_Total)))
        self.df.loc[:, 'Ur0':'Ur3'] = self.df.loc[:, 'Ur0':'Ur3'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface, np.add(self.df.Floors, 1))))
        self.df.loc[:, 'Uf0':'Uf5'] = self.df.loc[:, 'Uf0':'Uf5'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface, np.add(self.df.Floors, 1))))
        return self.df

    def Duo_Priced_Surface(self):
        self.Priced_Surface()
        columns_list = []
        columns_list_1 = []
        columns_list_2 = []
        for m in range(19):
            for w in range(4):
                column_name = 'U_m' + str(m) + '_w' + str(w)
                columns_list_1.append(column_name)
        for r in range(4):
            for f in range(6):
                column_name = 'U_r' + str(r) + '_f' + str(f)
                columns_list_2.append(column_name)
        columns_list = columns_list_1 + columns_list_2
        self.df = pd.concat([
            self.df,
            pd.DataFrame(0, index=self.df.index, columns=columns_list)
        ],
                            axis=1)
        self.df[columns_list_1] = self.df[columns_list_1].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        self.df[columns_list_2] = self.df[columns_list_2].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        selected_columns = self.df.loc[:, 'Um0':'Uf5'].columns.tolist()
        self.df = self.df.drop(selected_columns, axis=1)
        return self.df

    def Add_Created_Columns(self):
        self.Duo_Priced_Surface()
        self.Fixed_Cost_1()
        self.Fixed_Cost_3()
        self.Fixed_Cost_5()
        return self.df

# %%
Columns_for_CCD_U_Prices.mro()
# Out:
# [__main__.Columns_for_CCD_U_Prices,
#  __main__.CCD_Prices,
#  __main__.CCD_Type,
#  __main__.All_Types,
#  __main__.Calculable_Columns_for_CxD,
#  __main__.Calculable_Columns,
#  object]

# %% [markdown]
# ## Class for the individual dwellings

# %%
class Calculable_Columns_for_ID(Calculable_Columns):
    def Surface_M(self):
        self.Rename_Columns()
        self.df['Surface_M'] = np.multiply(
            np.multiply(
                np.multiply(
                    np.subtract(1, self.df.Share_of_Windows),
                    np.sqrt(
                        np.divide(self.df.Surface, np.add(self.df.Floors,
                                                          1)))), 4),
            np.multiply(self.df.Ceiling_Height, np.add(self.df.Floors, 1)))
        return self.df

    def Surface_W(self):
        self.Rename_Columns()
        self.df['Surface_W'] = np.multiply(
            np.multiply(
                np.multiply(
                    self.df.Share_of_Windows,
                    np.sqrt(
                        np.divide(self.df.Surface, np.add(self.df.Floors,
                                                          1)))), 4),
            np.multiply(self.df.Ceiling_Height, np.add(self.df.Floors, 1)))
        return self.df

# %%
Calculable_Columns_for_ID.mro()
# Out:
# [__main__.Calculable_Columns_for_ID, __main__.Calculable_Columns, object]

# %% [markdown]
# ### Class for the ID Type with U Factors

# %%
class Columns_for_ID_U_Factors(ID_Factors, Calculable_Columns_for_ID):
    def __init__(self, year, *args):
        super().__init__(*args)
        self.year = year
        self.DF_with_U()

    def Surface_R(self):
        self.Rename_Columns()
        self.df['Surface_R'] = np.divide(self.df.Surface,
                                         np.add(self.df.Floors, 1))
        return self.df

    def Heightened_Surface_Habitable(self):
        self.Surface_R()
        self.df['Heightened_Surface_Habitable'] = np.multiply(
            self.df.Surface, self.df.Ceiling_Height)
        return self.df

    def UEN_per_Dwelling_2(self):
        self.Rename_Columns()
        self.df['UEN_per_Dwelling_2'] = np.multiply(
            np.multiply(
                np.multiply(self.df.Ceiling_Height, self.df.Intermittence),
                np.multiply(self.df.Degrees_of_Reference, self.df.Surface)),
            0.01)
        return self.df

    def Weighted_Surface(self):
        self.Surface_M()
        self.Surface_W()
        self.Surface_R()
        self.df.loc[:, 'Um0':'Um19'] = self.df.loc[:, 'Um0':'Um19'].apply(
            lambda x: np.multiply(x, self.df.Surface_M))
        self.df.loc[:, 'Uw0':'Uw3'] = self.df.loc[:, 'Uw0':'Uw3'].apply(
            lambda x: np.multiply(x, self.df.Surface_W))
        self.df.loc[:, 'Ur0':'Ur7'] = self.df.loc[:, 'Ur0':'Ur7'].apply(
            lambda x: np.multiply(x, self.df.Surface_R))
        self.df.loc[:, 'Uf0':'Uf3'] = self.df.loc[:, 'Uf0':'Uf3'].apply(
            lambda x: np.multiply(x, self.df.Surface_R))
        return self.df

    def Duo_Weighted_Surface(self):
        self.Weighted_Surface()
        columns_list = []
        columns_list_1 = []
        columns_list_2 = []
        for m in range(20):
            for w in range(4):
                column_name = 'U_m' + str(m) + '_w' + str(w)
                columns_list_1.append(column_name)
        for r in range(8):
            for f in range(4):
                column_name = 'U_r' + str(r) + '_f' + str(f)
                columns_list_2.append(column_name)
        columns_list = columns_list_1 + columns_list_2
        self.df = pd.concat([
            self.df,
            pd.DataFrame(0, index=self.df.index, columns=columns_list)
        ],
                            axis=1)
        self.df[columns_list_1] = self.df[columns_list_1].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        self.df[columns_list_2] = self.df[columns_list_2].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        selected_columns = self.df.loc[:, 'Um0':'Uf3'].columns.tolist()
        self.df = self.df.drop(selected_columns, axis=1)
        return self.df

    def Add_Created_Columns(self):
        self.Heightened_Surface_Habitable()
        self.UEN_per_Dwelling_2()
        self.Duo_Weighted_Surface()
        self.UEN_Cost_1()
        self.UEN_Cost_2()
        self.UEN_Cost_3()
        return self.df

# %%
Columns_for_ID_U_Factors.mro()
# Out:
# [__main__.Columns_for_ID_U_Factors,
#  __main__.ID_Factors,
#  __main__.ID_Type,
#  __main__.All_Types,
#  __main__.Calculable_Columns_for_ID,
#  __main__.Calculable_Columns,
#  object]

# %% [markdown]
# ### Class for the DataFrame with U Prices

# %%
class Columns_for_ID_U_Prices(ID_Prices, Calculable_Columns_for_ID):
    def __init__(self, year, *args):
        super().__init__(*args)
        self.year = year
        self.DF_with_U()

    def Dwelling_Total(self):
        self.Rename_Columns()
        self.df['Dwelling_Total'] = 1
        return self.df

    def Priced_Surface(self):
        self.Surface_M()
        self.Surface_W()
        self.Dwelling_Total()
        self.df.loc[:, 'Um0':'Um19'] = self.df.loc[:, 'Um0':'Um19'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface_M, self.df.Dwelling_Total)))
        self.df.loc[:, 'Uw0':'Uw3'] = self.df.loc[:, 'Uw0':'Uw3'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface_W, self.df.Dwelling_Total)))
        self.df.loc[:, 'Ur0':'Ur7'] = self.df.loc[:, 'Ur0':'Ur7'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface, np.add(self.df.Floors, 1))))
        self.df.loc[:, 'Uf0':'Uf3'] = self.df.loc[:, 'Uf0':'Uf3'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface, np.add(self.df.Floors, 1))))
        return self.df

    def Duo_Priced_Surface(self):
        self.Priced_Surface()
        columns_list = []
        columns_list_1 = []
        columns_list_2 = []
        for m in range(20):
            for w in range(4):
                column_name = 'U_m' + str(m) + '_w' + str(w)
                columns_list_1.append(column_name)
        for r in range(8):
            for f in range(4):
                column_name = 'U_r' + str(r) + '_f' + str(f)
                columns_list_2.append(column_name)
        columns_list = columns_list_1 + columns_list_2
        self.df = pd.concat([
            self.df,
            pd.DataFrame(0, index=self.df.index, columns=columns_list)
        ],
                            axis=1)
        self.df[columns_list_1] = self.df[columns_list_1].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        self.df[columns_list_2] = self.df[columns_list_2].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        selected_columns = self.df.loc[:, 'Um0':'Uf3'].columns.tolist()
        self.df = self.df.drop(selected_columns, axis=1)
        return self.df

    def Add_Created_Columns(self):
        self.Duo_Priced_Surface()
        self.Fixed_Cost_1()
        self.Fixed_Cost_3()
        self.Fixed_Cost_5()
        return self.df

# %%
Columns_for_ID_U_Prices.mro()
# Out:
# [__main__.Columns_for_ID_U_Prices,
#  __main__.ID_Prices,
#  __main__.ID_Type,
#  __main__.All_Types,
#  __main__.Calculable_Columns_for_ID,
#  __main__.Calculable_Columns,
#  object]

# %% [markdown]
# # Creation of some calculable DataFrames

# %% [markdown]
# ## Class for the CID type dwellings

# %%
class Calculable_DFs_for_CID():
    def Add_ER_Columns(self):
        columns_list = []
        for m in range(19):
            for w in range(4):
                for r in range(4):
                    for f in range(6):
                        column_name = 'ER_m' + str(m) + '_w' + str(
                            w) + '_r' + str(r) + '_f' + str(f)
                        columns_list.append(column_name)
        self.df = pd.concat([
            self.df,
            pd.DataFrame(0, index=self.df.index, columns=columns_list)
        ],
                            axis=1)
        return self.df

    def Fill_ER_Columns(self):
        self.Add_ER_Columns()
        selected_columns = self.df.loc[:, 'ER_m0_w0_r0_f0':
                                       'ER_m18_w3_r3_f5'].columns.tolist()
        self.df[selected_columns] = self.df[selected_columns].apply(
            lambda x: np.add(
                self.df['U_' + x.name.split('_')[1] + '_' + x.name.split('_')[
                    2]], self.df['U_' + x.name.split('_')[3] + '_' + x.name.
                                 split('_')[4]]))
        selected_columns = self.df.loc[:, 'U_m0_w0':'U_r3_f5'].columns.tolist()
        self.df = self.df.drop(selected_columns, axis=1)
        return self.df

    def Generate_GB_Columns(self):
        self.Generate_ER_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'GB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_CGB_Columns(self):
        self.Generate_GB_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'CGB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_OB_Columns(self):
        self.Generate_CGB_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'OB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_COB_Columns(self):
        self.Generate_OB_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'COB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_EHP2_Columns(self):
        self.Generate_COB_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'EHP2_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_WB_Columns(self):
        self.Generate_EHP2_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'WB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_WPB_Columns(self):
        self.Generate_WB_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'WPB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_EHP_Columns(self):
        self.Generate_WPB_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'EHP_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

# %%
Calculable_DFs_for_CID.mro()
# Out:
# [__main__.Calculable_DFs_for_CID, object]

# %% [markdown]
# ### Class for the DataFrame with U Factors

# %%
class DF_for_CID_U_Factors(Columns_for_CID_U_Factors, Calculable_DFs_for_CID):
    def __init__(self, year, *args):
        super().__init__(year, *args)
        self.Add_Created_Columns()

    def Weighted_Surface_Total(self):
        self.Fill_ER_Columns()
        return self.df

    def Enlarged_Weighted_Surface_Total(self):
        self.Weighted_Surface_Total()
        selected_columns = self.df.loc[:, 'ER_m0_w0_r0_f0':
                                       'ER_m18_w3_r3_f5'].columns.tolist()
        self.copied_df = self.df[selected_columns].copy()
        self.copied_df = self.copied_df.apply(lambda x: np.add(
            np.multiply(9, self.df.Heightened_Surface_Habitable),
            np.multiply(2.5, x)))
        return self.copied_df

    def UEN_per_Dwelling_1(self):
        self.Enlarged_Weighted_Surface_Total()
        selected_columns = self.df.loc[:, 'ER_m0_w0_r0_f0':
                                       'ER_m18_w3_r3_f5'].columns.tolist()
        self.df[selected_columns] = self.df[selected_columns].div(
            self.copied_df)
        del self.copied_df
        return self.df

    def UEN_per_Dwelling(self):
        self.UEN_per_Dwelling_1()
        selected_columns = self.df.loc[:, 'ER_m0_w0_r0_f0':
                                       'ER_m18_w3_r3_f5'].columns.tolist()
        self.df[selected_columns] = self.df[selected_columns].apply(
            lambda x: np.multiply(x, self.df.UEN_per_Dwelling_2))
        return self.df

    def Generate_ER_Columns(self):
        self.UEN_per_Dwelling()
        return self.df

    def GHC_UEN_ER(self):
        self.Generate_EHP_Columns()
        selected_columns = self.df.loc[:, 'ER_m0_w0_r0_f0':
                                       'ER_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'ER'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[:19, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, A, B, matrix, df_copy
        return self.df

    def GHC_UEN_GB(self):
        self.GHC_UEN_ER()
        selected_columns = self.df.loc[:, 'GB_m0_w0_r0_f0':
                                       'GB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'GB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WB') | (
                        self.df.Heating_System == 'WPB') | (
                            self.df.Heating_System == 'EHP')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'OB') | (
            self.df.Heating_System == 'COB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[20:39, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'UEN_Cost_3']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(
            matrix, np.multiply(condition_1, A)) + np.multiply(
                matrix, np.multiply(condition_2, B)) + np.multiply(
                    matrix, np.multiply(condition_3, C))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_copy
        return self.df

    def GHC_UEN_CGB(self):
        self.GHC_UEN_GB()
        selected_columns = self.df.loc[:, 'CGB_m0_w0_r0_f0':
                                       'CGB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'CGB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'GB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WB') | (
                        self.df.Heating_System == 'WPB') | (
                            self.df.Heating_System == 'EHP')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'OB') | (
            self.df.Heating_System == 'COB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[40:59, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'UEN_Cost_3']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(
            matrix, np.multiply(condition_1, A)) + np.multiply(
                matrix, np.multiply(condition_2, B)) + np.multiply(
                    matrix, np.multiply(condition_3, C))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_copy
        return self.df

    def GHC_UEN_OB(self):
        self.GHC_UEN_CGB()
        selected_columns = self.df.loc[:, 'OB_m0_w0_r0_f0':
                                       'OB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'OB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[60:79, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, A, B, matrix, df_copy
        return self.df

    def GHC_UEN_COB(self):
        self.GHC_UEN_OB()
        selected_columns = self.df.loc[:, 'COB_m0_w0_r0_f0':
                                       'COB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'COB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[80:99, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, A, B, matrix, df_copy
        return self.df

    def GHC_UEN_EHP2(self):
        self.GHC_UEN_COB()
        selected_columns = self.df.loc[:, 'EHP2_m0_w0_r0_f0':
                                       'EHP2_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'EHP2'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[100:119, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, A, B, matrix, df_copy
        return self.df

    def GHC_UEN_WB(self):
        self.GHC_UEN_EHP2()
        selected_columns = self.df.loc[:, 'WB_m0_w0_r0_f0':
                                       'WB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'WB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[120:139, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, A, B, matrix, df_copy
        return self.df

    def GHC_UEN_WPB(self):
        self.GHC_UEN_WB()
        selected_columns = self.df.loc[:, 'WPB_m0_w0_r0_f0':
                                       'WPB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'WPB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[140:159, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, A, B, matrix, df_copy
        return self.df

    def GHC_UEN_EHP(self):
        self.GHC_UEN_WPB()
        selected_columns = self.df.loc[:, 'EHP_m0_w0_r0_f0':
                                       'EHP_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'EHP'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[160:179, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, A, B, matrix, df_copy
        return self.df

    def GHC_UEN_Conditions(self):
        self.GHC_UEN_EHP()
        return self.df

# %%
DF_for_CID_U_Factors.mro()
# Out:
# [__main__.DF_for_CID_U_Factors,
#  __main__.Columns_for_CID_U_Factors,
#  __main__.CID_Factors,
#  __main__.CID_Type,
#  __main__.All_Types,
#  __main__.Calculable_Columns_for_CxD,
#  __main__.Calculable_Columns,
#  __main__.Calculable_DFs_for_CID,
#  object]

# %% [markdown]
# ### Class for the DataFrame with U Prices

# %%
class DF_for_CID_U_Prices(Columns_for_CID_U_Prices, Calculable_DFs_for_CID):
    def __init__(self, year, *args):
        super().__init__(year, *args)
        self.Add_Created_Columns()

    def Insulation_Cost(self):
        self.Fill_ER_Columns()
        return self.df

    def Generate_ER_Columns(self):
        self.Insulation_Cost()
        return self.df

    def Multiple_Cost_ER(self):
        self.Generate_EHP_Columns()
        selected_columns = self.df.loc[:, 'ER_m0_w0_r0_f0':
                                       'ER_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'ER'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'WB') | (
            self.df.Heating_System == 'EHP')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'OB') | (
                    self.df.Heating_System == 'COB') | (
                        self.df.Heating_System == 'EHP2') | (
                            self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[:19, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_2']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_copy
        return self.df

    def Multiple_Cost_GB(self):
        self.Multiple_Cost_ER()
        selected_columns = self.df.loc[:, 'GB_m0_w0_r0_f0':
                                       'GB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'GB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'CGB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'OB') | (
            self.df.Heating_System == 'COB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'WB') | (self.df.Heating_System == 'EHP')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[20:39, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_2']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_4']).reshape(
            df_copy.shape[0], 1)
        D = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C) + np.multiply(
                condition_4, D)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_copy
        return self.df

    def Multiple_Cost_CGB(self):
        self.Multiple_Cost_GB()
        selected_columns = self.df.loc[:, 'CGB_m0_w0_r0_f0':
                                       'CGB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'CGB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'GB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'OB') | (
            self.df.Heating_System == 'COB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'WB') | (self.df.Heating_System == 'EHP')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[40:59, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_2']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_4']).reshape(
            df_copy.shape[0], 1)
        D = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C) + np.multiply(
                condition_4, D)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_copy
        return self.df

    def Multiple_Cost_OB(self):
        self.Multiple_Cost_CGB()
        selected_columns = self.df.loc[:, 'OB_m0_w0_r0_f0':
                                       'OB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'OB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'COB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'WB') | (self.df.Heating_System == 'EHP')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[60:79, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_2']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_4']).reshape(
            df_copy.shape[0], 1)
        D = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C) + np.multiply(
                condition_4, D)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_copy
        return self.df

    def Multiple_Cost_COB(self):
        self.Multiple_Cost_OB()
        selected_columns = self.df.loc[:, 'COB_m0_w0_r0_f0':
                                       'COB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'COB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'OB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'WB') | (self.df.Heating_System == 'EHP')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[80:99, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_2']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_4']).reshape(
            df_copy.shape[0], 1)
        D = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C) + np.multiply(
                condition_4, D)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_copy
        return self.df

    def Multiple_Cost_EHP2(self):
        self.Multiple_Cost_COB()
        selected_columns = self.df.loc[:, 'EHP2_m0_w0_r0_f0':
                                       'EHP2_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'EHP2'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'OB') | (
                    self.df.Heating_System == 'COB') | (
                        self.df.Heating_System == 'WPB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'WB') | (self.df.Heating_System == 'EHP')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[100:119, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_4']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_copy
        return self.df

    def Multiple_Cost_WB(self):
        self.Multiple_Cost_EHP2()
        selected_columns = self.df.loc[:, 'WB_m0_w0_r0_f0':
                                       'WB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'WB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'EHP')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'OB') | (
                    self.df.Heating_System == 'COB') | (
                        self.df.Heating_System == 'EHP2') | (
                            self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[120:139, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_2']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_copy
        return self.df

    def Multiple_Cost_WPB(self):
        self.Multiple_Cost_WB()
        selected_columns = self.df.loc[:, 'WPB_m0_w0_r0_f0':
                                       'WPB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'WPB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'WB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'OB') | (
                    self.df.Heating_System == 'COB') | (
                        self.df.Heating_System == 'EHP2')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'EHP')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[140:159, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_3']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_4']).reshape(
            df_copy.shape[0], 1)
        D = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C) + np.multiply(
                condition_4, D)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_copy
        return self.df

    def Multiple_Cost_EHP(self):
        self.Multiple_Cost_WPB()
        selected_columns = self.df.loc[:, 'EHP_m0_w0_r0_f0':
                                       'EHP_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'EHP'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'WB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'OB') | (
                    self.df.Heating_System == 'COB') | (
                        self.df.Heating_System == 'EHP2') | (
                            self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[160:179, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_2']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_copy
        return self.df

    def Unvariable_Costs(self):
        self.Multiple_Cost_EHP()
        return self.df

# %%
DF_for_CID_U_Prices.mro()
# Out:
# [__main__.DF_for_CID_U_Prices,
#  __main__.Columns_for_CID_U_Prices,
#  __main__.CID_Prices,
#  __main__.CID_Type,
#  __main__.All_Types,
#  __main__.Calculable_Columns_for_CxD,
#  __main__.Calculable_Columns,
#  __main__.Calculable_DFs_for_CID,
#  object]

# %% [markdown]
# ## Class for the CCD type dwellings

# %%
class Calculable_DFs_for_CCD():
    def Add_GB_Columns(self):
        columns_list = []
        for m in range(19):
            for w in range(4):
                for r in range(4):
                    for f in range(6):
                        column_name = 'GB_m' + str(m) + '_w' + str(
                            w) + '_r' + str(r) + '_f' + str(f)
                        columns_list.append(column_name)
        self.df = pd.concat([
            self.df,
            pd.DataFrame(0, index=self.df.index, columns=columns_list)
        ],
                            axis=1)
        return self.df

    def Fill_GB_Columns(self):
        self.Add_GB_Columns()
        selected_columns = self.df.loc[:, 'GB_m0_w0_r0_f0':
                                       'GB_m18_w3_r3_f5'].columns.tolist()
        self.df[selected_columns] = self.df[selected_columns].apply(
            lambda x: np.add(
                self.df['U_' + x.name.split('_')[1] + '_' + x.name.split('_')[
                    2]], self.df['U_' + x.name.split('_')[3] + '_' + x.name.
                                 split('_')[4]]))
        selected_columns = self.df.loc[:, 'U_m0_w0':'U_r3_f5'].columns.tolist()
        self.df = self.df.drop(selected_columns, axis=1)
        return self.df

    def Generate_CGB_Columns(self):
        self.Generate_GB_Columns()
        duplicate_df = self.df.loc[:, 'GB_m0_w0_r0_f0':'GB_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('GB_', 'CGB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_OB_Columns(self):
        self.Generate_CGB_Columns()
        duplicate_df = self.df.loc[:, 'GB_m0_w0_r0_f0':'GB_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('GB_', 'OB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_COB_Columns(self):
        self.Generate_OB_Columns()
        duplicate_df = self.df.loc[:, 'GB_m0_w0_r0_f0':'GB_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('GB_', 'COB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_EHP2_Columns(self):
        self.Generate_COB_Columns()
        duplicate_df = self.df.loc[:, 'GB_m0_w0_r0_f0':'GB_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('GB_', 'EHP2_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_WB_Columns(self):
        self.Generate_EHP2_Columns()
        duplicate_df = self.df.loc[:, 'GB_m0_w0_r0_f0':'GB_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('GB_', 'WB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_WPB_Columns(self):
        self.Generate_WB_Columns()
        duplicate_df = self.df.loc[:, 'GB_m0_w0_r0_f0':'GB_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('GB_', 'WPB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_EHP_Columns(self):
        self.Generate_WPB_Columns()
        duplicate_df = self.df.loc[:, 'GB_m0_w0_r0_f0':'GB_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('GB_', 'EHP_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

# %%
Calculable_DFs_for_CCD.mro()
# Out:
# [__main__.Calculable_DFs_for_CCD, object]

# %% [markdown]
# ### Class for the DataFrame with U Factors

# %%
class DF_for_CCD_U_Factors(Columns_for_CCD_U_Factors, Calculable_DFs_for_CCD):
    def __init__(self, year, *args):
        super().__init__(year, *args)
        self.Add_Created_Columns()

    def Weighted_Surface_Total(self):
        self.Fill_GB_Columns()
        return self.df

    def Enlarged_Weighted_Surface_Total(self):
        self.Weighted_Surface_Total()
        selected_columns = self.df.loc[:, 'GB_m0_w0_r0_f0':
                                       'GB_m18_w3_r3_f5'].columns.tolist()
        self.copied_df = self.df[selected_columns].copy()
        self.copied_df = self.copied_df.apply(lambda x: np.add(
            np.multiply(9, self.df.Heightened_Surface_Habitable),
            np.multiply(2.5, x)))
        return self.copied_df

    def UEN_per_Dwelling_1(self):
        self.Enlarged_Weighted_Surface_Total()
        selected_columns = self.df.loc[:, 'GB_m0_w0_r0_f0':
                                       'GB_m18_w3_r3_f5'].columns.tolist()
        self.df[selected_columns] = self.df[selected_columns].div(
            self.copied_df)
        del self.copied_df
        return self.df

    def UEN_per_Dwelling(self):
        self.UEN_per_Dwelling_1()
        selected_columns = self.df.loc[:, 'GB_m0_w0_r0_f0':
                                       'GB_m18_w3_r3_f5'].columns.tolist()
        self.df[selected_columns] = self.df[selected_columns].apply(
            lambda x: np.multiply(x, self.df.UEN_per_Dwelling_2))
        return self.df

    def Generate_GB_Columns(self):
        self.UEN_per_Dwelling()
        return self.df

    def GHC_UEN_GB(self):
        self.Generate_EHP_Columns()
        selected_columns = self.df.loc[:, 'GB_m0_w0_r0_f0':
                                       'GB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'GB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'CGB') | (
            self.df.Heating_System == 'EHP2') | (
                self.df.Heating_System == 'WB') | (
                    self.df.Heating_System == 'WPB') | (
                        self.df.Heating_System == 'EHP')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'OB') | (
            self.df.Heating_System == 'COB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[:19, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'UEN_Cost_3']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(
            matrix, np.multiply(condition_1, A)) + np.multiply(
                matrix, np.multiply(condition_2, B)) + np.multiply(
                    matrix, np.multiply(condition_3, C))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_copy
        return self.df

    def GHC_UEN_CGB(self):
        self.GHC_UEN_GB()
        selected_columns = self.df.loc[:, 'CGB_m0_w0_r0_f0':
                                       'CGB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'CGB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'EHP2') | (
                self.df.Heating_System == 'WB') | (
                    self.df.Heating_System == 'WPB') | (
                        self.df.Heating_System == 'EHP')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'OB') | (
            self.df.Heating_System == 'COB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[20:39, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'UEN_Cost_3']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(
            matrix, np.multiply(condition_1, A)) + np.multiply(
                matrix, np.multiply(condition_2, B)) + np.multiply(
                    matrix, np.multiply(condition_3, C))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_copy
        return self.df

    def GHC_UEN_OB(self):
        self.GHC_UEN_CGB()
        selected_columns = self.df.loc[:, 'OB_m0_w0_r0_f0':
                                       'OB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'OB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[40:59, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, A, B, matrix, df_copy
        return self.df

    def GHC_UEN_COB(self):
        self.GHC_UEN_OB()
        selected_columns = self.df.loc[:, 'COB_m0_w0_r0_f0':
                                       'COB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'COB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[60:79, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, A, B, matrix, df_copy
        return self.df

    def GHC_UEN_EHP2(self):
        self.GHC_UEN_COB()
        selected_columns = self.df.loc[:, 'EHP2_m0_w0_r0_f0':
                                       'EHP2_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'EHP2'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[80:99, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, A, B, matrix, df_copy
        return self.df

    def GHC_UEN_WB(self):
        self.GHC_UEN_EHP2()
        selected_columns = self.df.loc[:, 'WB_m0_w0_r0_f0':
                                       'WB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'WB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[100:119, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, A, B, matrix, df_copy
        return self.df

    def GHC_UEN_WPB(self):
        self.GHC_UEN_WB()
        selected_columns = self.df.loc[:, 'WPB_m0_w0_r0_f0':
                                       'WPB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'WPB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[120:139, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, A, B, matrix, df_copy
        return self.df

    def GHC_UEN_EHP(self):
        self.GHC_UEN_WPB()
        selected_columns = self.df.loc[:, 'EHP_m0_w0_r0_f0':
                                       'EHP_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'EHP'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[140:159, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, A, B, matrix, df_copy
        return self.df

    def GHC_UEN_Conditions(self):
        self.GHC_UEN_EHP()
        return self.df

# %%
DF_for_CCD_U_Factors.mro()
# Out:
# [__main__.DF_for_CCD_U_Factors,
#  __main__.Columns_for_CCD_U_Factors,
#  __main__.CCD_Factors,
#  __main__.CCD_Type,
#  __main__.All_Types,
#  __main__.Calculable_Columns_for_CxD,
#  __main__.Calculable_Columns,
#  __main__.Calculable_DFs_for_CCD,
#  object]

# %% [markdown]
# ### Class for the DataFrame with U Prices

# %%
class DF_for_CCD_U_Prices(Columns_for_CCD_U_Prices, Calculable_DFs_for_CCD):
    def __init__(self, year, *args):
        super().__init__(year, *args)
        self.Add_Created_Columns()

    def Insulation_Cost(self):
        self.Fill_GB_Columns()
        return self.df

    def Generate_GB_Columns(self):
        self.Insulation_Cost()
        return self.df

    def Multiple_Cost_GB(self):
        self.Generate_EHP_Columns()
        selected_columns = self.df.loc[:, 'GB_m0_w0_r0_f0':
                                       'GB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'GB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'CGB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'OB') | (
            self.df.Heating_System == 'COB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'WB') | (
            self.df.Heating_System == 'EHP')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[:19, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_2']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_4']).reshape(
            df_copy.shape[0], 1)
        D = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C) + np.multiply(
                condition_4, D)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_copy
        return self.df

    def Multiple_Cost_CGB(self):
        self.Multiple_Cost_GB()
        selected_columns = self.df.loc[:, 'CGB_m0_w0_r0_f0':
                                       'CGB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'CGB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'GB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'OB') | (
            self.df.Heating_System == 'COB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'WB') | (
            self.df.Heating_System == 'EHP')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[20:39, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_2']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_4']).reshape(
            df_copy.shape[0], 1)
        D = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C) + np.multiply(
                condition_4, D)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_copy
        return self.df

    def Multiple_Cost_OB(self):
        self.Multiple_Cost_CGB()
        selected_columns = self.df.loc[:, 'OB_m0_w0_r0_f0':
                                       'OB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'OB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'COB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'WB') | (
            self.df.Heating_System == 'EHP')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[40:59, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_2']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_4']).reshape(
            df_copy.shape[0], 1)
        D = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C) + np.multiply(
                condition_4, D)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_copy
        return self.df

    def Multiple_Cost_COB(self):
        self.Multiple_Cost_OB()
        selected_columns = self.df.loc[:, 'COB_m0_w0_r0_f0':
                                       'COB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'COB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'OB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'WB') | (
            self.df.Heating_System == 'EHP')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[60:79, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_2']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_4']).reshape(
            df_copy.shape[0], 1)
        D = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C) + np.multiply(
                condition_4, D)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_copy
        return self.df

    def Multiple_Cost_EHP2(self):
        self.Multiple_Cost_COB()
        selected_columns = self.df.loc[:, 'EHP2_m0_w0_r0_f0':
                                       'EHP2_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'EHP2'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'OB') | (
                    self.df.Heating_System == 'COB') | (
                        self.df.Heating_System == 'WPB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'WB') | (
            self.df.Heating_System == 'EHP')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[80:99, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_4']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_copy
        return self.df

    def Multiple_Cost_WB(self):
        self.Multiple_Cost_EHP2()
        selected_columns = self.df.loc[:, 'WB_m0_w0_r0_f0':
                                       'WB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'WB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = self.df.Heating_System == 'WPB'
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = self.df.Heating_System == 'EHP'
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'OB') | (
                    self.df.Heating_System == 'COB') | (
                        self.df.Heating_System == 'EHP2')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[100:119, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_3']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_4']).reshape(
            df_copy.shape[0], 1)
        D = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C) + np.multiply(
                condition_4, D)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_copy
        return self.df

    def Multiple_Cost_WPB(self):
        self.Multiple_Cost_WB()
        selected_columns = self.df.loc[:, 'WPB_m0_w0_r0_f0':
                                       'WPB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'WPB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = self.df.Heating_System == 'WB'
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'OB') | (
                    self.df.Heating_System == 'COB') | (
                        self.df.Heating_System == 'EHP2')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = self.df.Heating_System == 'EHP'
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[120:139, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_3']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_4']).reshape(
            df_copy.shape[0], 1)
        D = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C) + np.multiply(
                condition_4, D)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_copy
        return self.df

    def Multiple_Cost_EHP(self):
        self.Multiple_Cost_WPB()
        selected_columns = self.df.loc[:, 'EHP_m0_w0_r0_f0':
                                       'EHP_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'EHP'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = self.df.Heating_System == 'WB'
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'OB') | (
                    self.df.Heating_System == 'COB') | (
                        self.df.Heating_System == 'EHP2') | (
                            self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[140:159, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_4']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_copy
        return self.df

    def Unvariable_Costs(self):
        self.Multiple_Cost_EHP()
        return self.df

# %%
DF_for_CCD_U_Prices.mro()
# Out:
# [__main__.DF_for_CCD_U_Prices,
#  __main__.Columns_for_CCD_U_Prices,
#  __main__.CCD_Prices,
#  __main__.CCD_Type,
#  __main__.All_Types,
#  __main__.Calculable_Columns_for_CxD,
#  __main__.Calculable_Columns,
#  __main__.Calculable_DFs_for_CCD,
#  object]

# %% [markdown]
# ## Class for the ID type dwellings

# %%
class Calculable_DFs_for_ID():
    def Add_ER_Columns(self):
        columns_list = []
        for m in range(20):
            for w in range(4):
                for r in range(8):
                    for f in range(4):
                        column_name = 'ER_m' + str(m) + '_w' + str(
                            w) + '_r' + str(r) + '_f' + str(f)
                        columns_list.append(column_name)
        self.df = pd.concat([
            self.df,
            pd.DataFrame(0, index=self.df.index, columns=columns_list)
        ],
                            axis=1)
        return self.df

    def Fill_ER_Columns(self):
        self.Add_ER_Columns()
        selected_columns = self.df.loc[:, 'ER_m0_w0_r0_f0':
                                       'ER_m19_w3_r7_f3'].columns.tolist()
        self.df[selected_columns] = self.df[selected_columns].apply(
            lambda x: np.add(
                self.df['U_' + x.name.split('_')[1] + '_' + x.name.split('_')[
                    2]], self.df['U_' + x.name.split('_')[3] + '_' + x.name.
                                 split('_')[4]]))
        selected_columns = self.df.loc[:, 'U_m0_w0':'U_r7_f3'].columns.tolist()
        self.df = self.df.drop(selected_columns, axis=1)
        return self.df

    def Generate_GB_Columns(self):
        self.Generate_ER_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m19_w3_r7_f3']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'GB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_CGB_Columns(self):
        self.Generate_GB_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m19_w3_r7_f3']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'CGB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_OB_Columns(self):
        self.Generate_CGB_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m19_w3_r7_f3']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'OB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_COB_Columns(self):
        self.Generate_OB_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m19_w3_r7_f3']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'COB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_EHP2_Columns(self):
        self.Generate_COB_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m19_w3_r7_f3']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'EHP2_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_WB_Columns(self):
        self.Generate_EHP2_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m19_w3_r7_f3']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'WB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_WPB_Columns(self):
        self.Generate_WB_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m19_w3_r7_f3']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'WPB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_EHP_Columns(self):
        self.Generate_WPB_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m19_w3_r7_f3']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'EHP_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

# %%
Calculable_DFs_for_ID.mro()
# Out:
# [__main__.Calculable_DFs_for_ID, object]

# %% [markdown]
# ### Class for the DataFrame with U Factors

# %%
class DF_for_ID_U_Factors(Columns_for_ID_U_Factors, Calculable_DFs_for_ID):
    def __init__(self, year, *args):
        super().__init__(year, *args)
        self.Add_Created_Columns()

    def Weighted_Surface_Total(self):
        self.Fill_ER_Columns()
        return self.df

    def Enlarged_Weighted_Surface_Total(self):
        self.Weighted_Surface_Total()
        selected_columns = self.df.loc[:, 'ER_m0_w0_r0_f0':
                                       'ER_m19_w3_r7_f3'].columns.tolist()
        self.copied_df = self.df[selected_columns].copy()
        self.copied_df = self.copied_df.apply(lambda x: np.add(
            np.multiply(9, self.df.Heightened_Surface_Habitable),
            np.multiply(2.5, x)))
        return self.copied_df

    def UEN_per_Dwelling_1(self):
        self.Enlarged_Weighted_Surface_Total()
        selected_columns = self.df.loc[:, 'ER_m0_w0_r0_f0':
                                       'ER_m19_w3_r7_f3'].columns.tolist()
        self.df[selected_columns] = self.df[selected_columns].div(
            self.copied_df)
        del self.copied_df
        return self.df

    def UEN_per_Dwelling(self):
        self.UEN_per_Dwelling_1()
        selected_columns = self.df.loc[:, 'ER_m0_w0_r0_f0':
                                       'ER_m19_w3_r7_f3'].columns.tolist()
        self.df[selected_columns] = self.df[selected_columns].apply(
            lambda x: np.multiply(x, self.df.UEN_per_Dwelling_2))
        return self.df

    def Generate_ER_Columns(self):
        self.UEN_per_Dwelling()
        return self.df

    def GHC_UEN_ER(self):
        self.Generate_EHP_Columns()
        selected_columns = self.df.loc[:, 'ER_m0_w0_r0_f0':
                                       'ER_m19_w3_r7_f3'].columns.tolist()
        condition_1 = self.df.Heating_System == 'ER'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[:19, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, A, B, matrix, df_copy
        return self.df

    def GHC_UEN_GB(self):
        self.GHC_UEN_ER()
        selected_columns = self.df.loc[:, 'GB_m0_w0_r0_f0':
                                       'GB_m19_w3_r7_f3'].columns.tolist()
        condition_1 = self.df.Heating_System == 'GB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WB') | (
                        self.df.Heating_System == 'WPB') | (
                            self.df.Heating_System == 'EHP')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'OB') | (
            self.df.Heating_System == 'COB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[20:39, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'UEN_Cost_3']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(
            matrix, np.multiply(condition_1, A)) + np.multiply(
                matrix, np.multiply(condition_2, B)) + np.multiply(
                    matrix, np.multiply(condition_3, C))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_copy
        return self.df

    def GHC_UEN_CGB(self):
        self.GHC_UEN_GB()
        selected_columns = self.df.loc[:, 'CGB_m0_w0_r0_f0':
                                       'CGB_m19_w3_r7_f3'].columns.tolist()
        condition_1 = self.df.Heating_System == 'CGB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'GB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WB') | (
                        self.df.Heating_System == 'WPB') | (
                            self.df.Heating_System == 'EHP')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'OB') | (
            self.df.Heating_System == 'COB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[40:59, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'UEN_Cost_3']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(
            matrix, np.multiply(condition_1, A)) + np.multiply(
                matrix, np.multiply(condition_2, B)) + np.multiply(
                    matrix, np.multiply(condition_3, C))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_copy
        return self.df

    def GHC_UEN_OB(self):
        self.GHC_UEN_CGB()
        selected_columns = self.df.loc[:, 'OB_m0_w0_r0_f0':
                                       'OB_m19_w3_r7_f3'].columns.tolist()
        condition_1 = self.df.Heating_System == 'OB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[60:79, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, A, B, matrix, df_copy
        return self.df

    def GHC_UEN_COB(self):
        self.GHC_UEN_OB()
        selected_columns = self.df.loc[:, 'COB_m0_w0_r0_f0':
                                       'COB_m19_w3_r7_f3'].columns.tolist()
        condition_1 = self.df.Heating_System == 'COB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[80:99, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, A, B, matrix, df_copy
        return self.df

    def GHC_UEN_EHP2(self):
        self.GHC_UEN_COB()
        selected_columns = self.df.loc[:, 'EHP2_m0_w0_r0_f0':
                                       'EHP2_m19_w3_r7_f3'].columns.tolist()
        condition_1 = self.df.Heating_System == 'EHP2'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[100:119, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, A, B, matrix, df_copy
        return self.df

    def GHC_UEN_WB(self):
        self.GHC_UEN_EHP2()
        selected_columns = self.df.loc[:, 'WB_m0_w0_r0_f0':
                                       'WB_m19_w3_r7_f3'].columns.tolist()
        condition_1 = self.df.Heating_System == 'WB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[120:139, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, A, B, matrix, df_copy
        return self.df

    def GHC_UEN_WPB(self):
        self.GHC_UEN_WB()
        selected_columns = self.df.loc[:, 'WPB_m0_w0_r0_f0':
                                       'WPB_m19_w3_r7_f3'].columns.tolist()
        condition_1 = self.df.Heating_System == 'WPB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[140:159, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, A, B, matrix, df_copy
        return self.df

    def GHC_UEN_EHP(self):
        self.GHC_UEN_WPB()
        selected_columns = self.df.loc[:, 'EHP_m0_w0_r0_f0':
                                       'EHP_m19_w3_r7_f3'].columns.tolist()
        condition_1 = self.df.Heating_System == 'EHP'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[160:179, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'UEN_Cost_1']).reshape(df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'UEN_Cost_2']).reshape(df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, A, B, matrix, df_copy
        return self.df

    def GHC_UEN_Conditions(self):
        self.GHC_UEN_EHP()
        return self.df

# %%
DF_for_ID_U_Factors.mro()
# Out:
# [__main__.DF_for_ID_U_Factors,
#  __main__.Columns_for_ID_U_Factors,
#  __main__.ID_Factors,
#  __main__.ID_Type,
#  __main__.All_Types,
#  __main__.Calculable_Columns_for_ID,
#  __main__.Calculable_Columns,
#  __main__.Calculable_DFs_for_ID,
#  object]

# %% [markdown]
# ### Class for the DataFrame with U Prices

# %%
class DF_for_ID_U_Prices(Columns_for_ID_U_Prices, Calculable_DFs_for_ID):
    def __init__(self, year, *args):
        super().__init__(year, *args)
        self.Add_Created_Columns()

    def Insulation_Cost(self):
        self.Fill_ER_Columns()
        return self.df

    def Generate_ER_Columns(self):
        self.Insulation_Cost()
        return self.df

    def Multiple_Cost_ER(self):
        self.Generate_EHP_Columns()
        selected_columns = self.df.loc[:, 'ER_m0_w0_r0_f0':
                                       'ER_m19_w3_r7_f3'].columns.tolist()
        condition_1 = self.df.Heating_System == 'ER'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'WB') | (
            self.df.Heating_System == 'EHP')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'OB') | (
                    self.df.Heating_System == 'COB') | (
                        self.df.Heating_System == 'EHP2') | (
                            self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[:19, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_2']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_copy
        return self.df

    def Multiple_Cost_GB(self):
        self.Multiple_Cost_ER()
        selected_columns = self.df.loc[:, 'GB_m0_w0_r0_f0':
                                       'GB_m19_w3_r7_f3'].columns.tolist()
        condition_1 = self.df.Heating_System == 'GB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'CGB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'OB') | (
            self.df.Heating_System == 'COB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'WB') | (self.df.Heating_System == 'EHP')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[20:39, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_2']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_4']).reshape(
            df_copy.shape[0], 1)
        D = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C) + np.multiply(
                condition_4, D)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_copy
        return self.df

    def Multiple_Cost_CGB(self):
        self.Multiple_Cost_GB()
        selected_columns = self.df.loc[:, 'CGB_m0_w0_r0_f0':
                                       'CGB_m19_w3_r7_f3'].columns.tolist()
        condition_1 = self.df.Heating_System == 'CGB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'GB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'OB') | (
            self.df.Heating_System == 'COB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'WB') | (self.df.Heating_System == 'EHP')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[40:59, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_2']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_4']).reshape(
            df_copy.shape[0], 1)
        D = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C) + np.multiply(
                condition_4, D)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_copy
        return self.df

    def Multiple_Cost_OB(self):
        self.Multiple_Cost_CGB()
        selected_columns = self.df.loc[:, 'OB_m0_w0_r0_f0':
                                       'OB_m19_w3_r7_f3'].columns.tolist()
        condition_1 = self.df.Heating_System == 'OB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'COB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'WB') | (self.df.Heating_System == 'EHP')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[60:79, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_2']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_4']).reshape(
            df_copy.shape[0], 1)
        D = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C) + np.multiply(
                condition_4, D)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_copy
        return self.df

    def Multiple_Cost_COB(self):
        self.Multiple_Cost_OB()
        selected_columns = self.df.loc[:, 'COB_m0_w0_r0_f0':
                                       'COB_m19_w3_r7_f3'].columns.tolist()
        condition_1 = self.df.Heating_System == 'COB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'OB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'WB') | (self.df.Heating_System == 'EHP')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[80:99, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_2']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_4']).reshape(
            df_copy.shape[0], 1)
        D = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C) + np.multiply(
                condition_4, D)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_copy
        return self.df

    def Multiple_Cost_EHP2(self):
        self.Multiple_Cost_COB()
        selected_columns = self.df.loc[:, 'EHP2_m0_w0_r0_f0':
                                       'EHP2_m19_w3_r7_f3'].columns.tolist()
        condition_1 = self.df.Heating_System == 'EHP2'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'OB') | (
                    self.df.Heating_System == 'COB') | (
                        self.df.Heating_System == 'WPB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'WB') | (self.df.Heating_System == 'EHP')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[100:119, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_4']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_copy
        return self.df

    def Multiple_Cost_WB(self):
        self.Multiple_Cost_EHP2()
        selected_columns = self.df.loc[:, 'WB_m0_w0_r0_f0':
                                       'WB_m19_w3_r7_f3'].columns.tolist()
        condition_1 = self.df.Heating_System == 'WB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'EHP')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'OB') | (
                    self.df.Heating_System == 'COB') | (
                        self.df.Heating_System == 'EHP2') | (
                            self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[120:139, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_2']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_copy
        return self.df

    def Multiple_Cost_WPB(self):
        self.Multiple_Cost_WB()
        selected_columns = self.df.loc[:, 'WPB_m0_w0_r0_f0':
                                       'WPB_m19_w3_r7_f3'].columns.tolist()
        condition_1 = self.df.Heating_System == 'WPB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'WB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'OB') | (
                    self.df.Heating_System == 'COB') | (
                        self.df.Heating_System == 'EHP2')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'EHP')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[140:159, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_3']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_4']).reshape(
            df_copy.shape[0], 1)
        D = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C) + np.multiply(
                condition_4, D)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_copy
        return self.df

    def Multiple_Cost_EHP(self):
        self.Multiple_Cost_WPB()
        selected_columns = self.df.loc[:, 'EHP_m0_w0_r0_f0':
                                       'EHP_m19_w3_r7_f3'].columns.tolist()
        condition_1 = self.df.Heating_System == 'EHP'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'WB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'OB') | (
                    self.df.Heating_System == 'COB') | (
                        self.df.Heating_System == 'EHP2') | (
                            self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        df_copy = self.df.loc[:, 'Initial_Age':]
        df_copy = pd.DataFrame(df_copy['Initial_Age']).merge(
            df_copy.loc[160:179, :], how='left', on=['Initial_Age'])
        A = np.array(df_copy.loc[:, 'Fixed_Cost_1']).reshape(
            df_copy.shape[0], 1)
        B = np.array(df_copy.loc[:, 'Fixed_Cost_2']).reshape(
            df_copy.shape[0], 1)
        C = np.array(df_copy.loc[:, 'Fixed_Cost_5']).reshape(
            df_copy.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = matrix + np.multiply(condition_1, A) + np.multiply(
            condition_2, B) + np.multiply(condition_3, C)
        self.df[selected_columns] = pd.DataFrame(matrix,
                                                 columns=selected_columns)
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_copy
        return self.df

    def Unvariable_Costs(self):
        self.Multiple_Cost_EHP()
        return self.df

# %%
DF_for_ID_U_Prices.mro()
# Out:
# [__main__.DF_for_ID_U_Prices,
#  __main__.Columns_for_ID_U_Prices,
#  __main__.ID_Prices,
#  __main__.ID_Type,
#  __main__.All_Types,
#  __main__.Calculable_Columns_for_ID,
#  __main__.Calculable_Columns,
#  __main__.Calculable_DFs_for_ID,
#  object]

# %% [markdown]
# # Class for the terminal calculator of GHC

# %%
class GHC_Terminal_Calculator():
    def __init__(self, year):
        self.year = year

    def GHC_CID(self):
        self.df_CID_F = DF_for_CID_U_Factors(self.year).GHC_UEN_Conditions()
        self.df_CID_P = DF_for_CID_U_Prices(self.year).Unvariable_Costs()
        selected_columns = self.df_CID_F.loc[:, 'ER_m0_w0_r0_f0':
                                             'EHP_m18_w3_r3_f5'].columns.tolist(
                                             )
        self.df_CID = self.df_CID_F[selected_columns] + self.df_CID_P[
            selected_columns]
        return self.df_CID

    def GHC_CCD(self):
        self.df_CCD_F = DF_for_CCD_U_Factors(self.year).GHC_UEN_Conditions()
        self.df_CCD_P = DF_for_CCD_U_Prices(self.year).Unvariable_Costs()
        selected_columns = self.df_CCD_F.loc[:, 'GB_m0_w0_r0_f0':
                                             'EHP_m18_w3_r3_f5'].columns.tolist(
                                             )
        self.df_CCD = self.df_CCD_F[selected_columns] + self.df_CCD_P[
            selected_columns]
        return self.df_CCD

    def GHC_ID(self):
        self.df_ID_F = DF_for_ID_U_Factors(self.year).GHC_UEN_Conditions()
        self.df_ID_P = DF_for_ID_U_Prices(self.year).Unvariable_Costs()
        selected_columns = self.df_ID_F.loc[:, 'ER_m0_w0_r0_f0':
                                            'EHP_m19_w3_r7_f3'].columns.tolist(
                                            )
        self.df_ID = self.df_ID_F[selected_columns] + self.df_ID_P[
            selected_columns]
        return self.df_ID

    def Reorder_Columns_CID(self):
        self.GHC_CID()
        selected_columns = self.df_CID.columns.tolist()
        new_columns = []
        for i in range(1824):
            HS_list = selected_columns[i::1824]
            new_columns += HS_list
        self.df_CID = self.df_CID[new_columns]
        return self.df_CID

    def Reorder_Columns_CCD(self):
        self.GHC_CCD()
        selected_columns = self.df_CCD.columns.tolist()
        new_columns = []
        for i in range(1824):
            HS_list = selected_columns[i::1824]
            new_columns += HS_list
        self.df_CCD = self.df_CCD[new_columns]
        return self.df_CCD

    def Reorder_Columns_ID(self):
        self.GHC_ID()
        selected_columns = self.df_ID.columns.tolist()
        new_columns = []
        for i in range(2560):
            HS_list = selected_columns[i::2560]
            new_columns += HS_list
        self.df_ID = self.df_ID[new_columns]
        return self.df_ID


#
# def DF_GHC_Concat():
#     selected_columns = [
#           'Dwelling_Type', 'Climate_Type', 'Construction_Period',
#           'Size_Factor', 'Heating_System', 'Initial_Age', 'Headcount'
#       ]
#       self.df = self.df_CID_F[selected_columns]
#       self.df['self.year'] = self.self.year
#       del self.df_CID_F, self.df_CID_P
#     self.Reorder_HS_Columns()
#     self.df_ghc = pd.concat([self.df, self.df_ghc], axis=1, join='outer')
#     del self.df
#     return self.df_ghc

# %%
GHC_Terminal_Calculator.mro()
# Out:
# [__main__.GHC_Terminal_Calculator, object]

# %%
a = GHC_Terminal_Calculator(1)

# %%
b = a.Reorder_Columns_CID()

# %%
c = a.Reorder_Columns_CCD()

# %%
d = a.Reorder_Columns_ID()

# %%
b
# Out:
#        ER_m0_w0_r0_f0  GB_m0_w0_r0_f0  CGB_m0_w0_r0_f0  OB_m0_w0_r0_f0  \
# 0        50800.656539   214429.295085    213802.739014   219331.350992
# 1        50863.233977   214429.295085    213802.739014   219331.350992
# 2        50928.940288   214429.295085    213802.739014   219331.350992
# 3        50997.931914   214429.295085    213802.739014   219331.350992
# 4        51070.373122   214429.295085    213802.739014   219331.350992
# 5        51146.436390   214429.295085    213802.739014   219331.350992
# 6        51226.302822   214429.295085    213802.739014   219331.350992
# 7        51310.162575   214429.295085    213802.739014   219331.350992
# 8        51398.215315   214429.295085    213802.739014   219331.350992
# 9        51490.670693   214429.295085    213802.739014   219331.350992
# 10       51587.748839   214429.295085    213802.739014   219331.350992
# 11       51689.680893   214429.295085    213802.739014   219331.350992
# 12       51796.709550   214429.295085    213802.739014   219331.350992
# 13       51909.089639   214429.295085    213802.739014   219331.350992
# 14       52027.088733   214429.295085    213802.739014   219331.350992
# 15       52150.987782   214429.295085    213802.739014   219331.350992
# 16       52281.081783   214429.295085    213802.739014   219331.350992
# 17       52417.680484   214429.295085    213802.739014   219331.350992
# 18       52561.109120   214429.295085    213802.739014   219331.350992
# 19       52711.709188   214429.295085    213802.739014   219331.350992
# 20      234211.709188    28430.798493     31502.739014    37831.350992
# 21      234211.709188    28558.454804     31502.739014    37831.350992
# 22      234211.709188    28692.493931     31502.739014    37831.350992
# 23      234211.709188    28833.235015     31502.739014    37831.350992
# 24      234211.709188    28981.013152     31502.739014    37831.350992
# 25      234211.709188    29136.180197     31502.739014    37831.350992
# 26      234211.709188    29299.105593     31502.739014    37831.350992
# 27      234211.709188    29470.177259     31502.739014    37831.350992
# 28      234211.709188    29649.802509     31502.739014    37831.350992
# 29      234211.709188    29838.409021     31502.739014    37831.350992
# ...               ...             ...              ...             ...
# 11310   193031.331821    12996.646363     14626.702761    14418.783991
# 11311   193031.331821    12996.646363     14626.702761    14418.783991
# 11312   193031.331821    12996.646363     14626.702761    14418.783991
# 11313   193031.331821    12996.646363     14626.702761    14418.783991
# 11314   193031.331821    12996.646363     14626.702761    14418.783991
# 11315   193031.331821    12996.646363     14626.702761    14418.783991
# 11316   193031.331821    12996.646363     14626.702761    14418.783991
# 11317   193031.331821    12996.646363     14626.702761    14418.783991
# 11318   193031.331821    12996.646363     14626.702761    14418.783991
# 11319   193031.331821    12996.646363     14626.702761    14418.783991
# 11320    11531.331821   194496.646363    196126.702761   195918.783991
# 11321    11531.331821   194496.646363    196126.702761   195918.783991
# 11322    11531.331821   194496.646363    196126.702761   195918.783991
# 11323    11531.331821   194496.646363    196126.702761   195918.783991
# 11324    11531.331821   194496.646363    196126.702761   195918.783991
# 11325    11531.331821   194496.646363    196126.702761   195918.783991
# 11326    11531.331821   194496.646363    196126.702761   195918.783991
# 11327    11531.331821   194496.646363    196126.702761   195918.783991
# 11328    11531.331821   194496.646363    196126.702761   195918.783991
# 11329    11531.331821   194496.646363    196126.702761   195918.783991
# 11330    11531.331821   194496.646363    196126.702761   195918.783991
# 11331    11531.331821   194496.646363    196126.702761   195918.783991
# 11332    11531.331821   194496.646363    196126.702761   195918.783991
# 11333    11531.331821   194496.646363    196126.702761   195918.783991
# 11334    11531.331821   194496.646363    196126.702761   195918.783991
# 11335    11531.331821   194496.646363    196126.702761   195918.783991
# 11336    11531.331821   194496.646363    196126.702761   195918.783991
# 11337    11531.331821   194496.646363    196126.702761   195918.783991
# 11338    11531.331821   194496.646363    196126.702761   195918.783991
# 11339    11531.331821   194496.646363    196126.702761   195918.783991
#
#        COB_m0_w0_r0_f0  EHP2_m0_w0_r0_f0  WB_m0_w0_r0_f0  WPB_m0_w0_r0_f0  \
# 0        218507.575132     219792.319076    9.781740e+05     1.165334e+06
# 1        218507.575132     219792.319076    9.781740e+05     1.165334e+06
# 2        218507.575132     219792.319076    9.781740e+05     1.165334e+06
# 3        218507.575132     219792.319076    9.781740e+05     1.165334e+06
# 4        218507.575132     219792.319076    9.781740e+05     1.165334e+06
# 5        218507.575132     219792.319076    9.781740e+05     1.165334e+06
# 6        218507.575132     219792.319076    9.781740e+05     1.165334e+06
# 7        218507.575132     219792.319076    9.781740e+05     1.165334e+06
# 8        218507.575132     219792.319076    9.781740e+05     1.165334e+06
# 9        218507.575132     219792.319076    9.781740e+05     1.165334e+06
# 10       218507.575132     219792.319076    9.781740e+05     1.165334e+06
# 11       218507.575132     219792.319076    9.781740e+05     1.165334e+06
# 12       218507.575132     219792.319076    9.781740e+05     1.165334e+06
# 13       218507.575132     219792.319076    9.781740e+05     1.165334e+06
# 14       218507.575132     219792.319076    9.781740e+05     1.165334e+06
# 15       218507.575132     219792.319076    9.781740e+05     1.165334e+06
# 16       218507.575132     219792.319076    9.781740e+05     1.165334e+06
# 17       218507.575132     219792.319076    9.781740e+05     1.165334e+06
# 18       218507.575132     219792.319076    9.781740e+05     1.165334e+06
# 19       218507.575132     219792.319076    9.781740e+05     1.165334e+06
# 20        37007.575132      38292.319076    1.159674e+06     9.838336e+05
# 21        37007.575132      38292.319076    1.159674e+06     9.838336e+05
# 22        37007.575132      38292.319076    1.159674e+06     9.838336e+05
# 23        37007.575132      38292.319076    1.159674e+06     9.838336e+05
# 24        37007.575132      38292.319076    1.159674e+06     9.838336e+05
# 25        37007.575132      38292.319076    1.159674e+06     9.838336e+05
# 26        37007.575132      38292.319076    1.159674e+06     9.838336e+05
# 27        37007.575132      38292.319076    1.159674e+06     9.838336e+05
# 28        37007.575132      38292.319076    1.159674e+06     9.838336e+05
# 29        37007.575132      38292.319076    1.159674e+06     9.838336e+05
# ...                ...               ...             ...              ...
# 11310     16230.715323      22239.234662    1.139966e+06     6.269277e+05
# 11311     16230.715323      22239.234662    1.139966e+06     6.580023e+05
# 11312     16230.715323      22239.234662    1.139966e+06     6.906307e+05
# 11313     16230.715323      22239.234662    1.139966e+06     7.248905e+05
# 11314     16230.715323      22239.234662    1.139966e+06     7.608633e+05
# 11315     16230.715323      22239.234662    1.139966e+06     7.986347e+05
# 11316     16230.715323      22239.234662    1.139966e+06     8.382947e+05
# 11317     16230.715323      22239.234662    1.139966e+06     8.799377e+05
# 11318     16230.715323      22239.234662    1.139966e+06     9.236629e+05
# 11319     16230.715323      22239.234662    1.139966e+06     9.695743e+05
# 11320    197730.715323     203739.234662    9.584663e+05     1.153574e+06
# 11321    197730.715323     203739.234662    9.584663e+05     1.153574e+06
# 11322    197730.715323     203739.234662    9.584663e+05     1.153574e+06
# 11323    197730.715323     203739.234662    9.584663e+05     1.153574e+06
# 11324    197730.715323     203739.234662    9.584663e+05     1.153574e+06
# 11325    197730.715323     203739.234662    9.584663e+05     1.153574e+06
# 11326    197730.715323     203739.234662    9.584663e+05     1.153574e+06
# 11327    197730.715323     203739.234662    9.584663e+05     1.153574e+06
# 11328    197730.715323     203739.234662    9.584663e+05     1.153574e+06
# 11329    197730.715323     203739.234662    9.584663e+05     1.153574e+06
# 11330    197730.715323     203739.234662    9.584663e+05     1.153574e+06
# 11331    197730.715323     203739.234662    9.584663e+05     1.153574e+06
# 11332    197730.715323     203739.234662    9.584663e+05     1.153574e+06
# 11333    197730.715323     203739.234662    9.584663e+05     1.153574e+06
# 11334    197730.715323     203739.234662    9.584663e+05     1.153574e+06
# 11335    197730.715323     203739.234662    9.584663e+05     1.153574e+06
# 11336    197730.715323     203739.234662    9.584663e+05     1.153574e+06
# 11337    197730.715323     203739.234662    9.584663e+05     1.153574e+06
# 11338    197730.715323     203739.234662    9.584663e+05     1.153574e+06
# 11339    197730.715323     203739.234662    9.584663e+05     1.153574e+06
#
#        EHP_m0_w0_r0_f0  ER_m0_w0_r0_f1  ...  EHP_m18_w3_r3_f4  \
# 0         41099.686744    51059.029135  ...      38168.308105
# 1         41099.686744    51120.752192  ...      38168.308105
# 2         41099.686744    51185.561402  ...      38168.308105
# 3         41099.686744    51253.611072  ...      38168.308105
# 4         41099.686744    51325.063226  ...      38168.308105
# 5         41099.686744    51400.087988  ...      38168.308105
# 6         41099.686744    51478.863988  ...      38168.308105
# 7         41099.686744    51561.578787  ...      38168.308105
# 8         41099.686744    51648.429327  ...      38
# <b>limit_output extension: Maximum message size of 10000 exceeded with 39064 characters</b>

# %%
c
# Out:
#        GB_m0_w0_r0_f0  CGB_m0_w0_r0_f0  OB_m0_w0_r0_f0  COB_m0_w0_r0_f0  \
# 0        24364.451049     26398.882395    34186.516391     33067.076088
# 1        24466.576098     26398.882395    34186.516391     33067.076088
# 2        24573.807399     26398.882395    34186.516391     33067.076088
# 3        24686.400266     26398.882395    34186.516391     33067.076088
# 4        24804.622776     26398.882395    34186.516391     33067.076088
# 5        24928.756411     26398.882395    34186.516391     33067.076088
# 6        25059.096729     26398.882395    34186.516391     33067.076088
# 7        25195.954062     26398.882395    34186.516391     33067.076088
# 8        25339.654261     26398.882395    34186.516391     33067.076088
# 9        25490.539471     26398.882395    34186.516391     33067.076088
# 10       25648.968941     26398.882395    34186.516391     33067.076088
# 11       25815.319885     26398.882395    34186.516391     33067.076088
# 12       25989.988376     26398.882395    34186.516391     33067.076088
# 13       26173.390292     26398.882395    34186.516391     33067.076088
# 14       26365.962303     26398.882395    34186.516391     33067.076088
# 15       26568.162915     26398.882395    34186.516391     33067.076088
# 16       26780.473557     26398.882395    34186.516391     33067.076088
# 17       27003.399732     26398.882395    34186.516391     33067.076088
# 18       27237.472215     26398.882395    34186.516391     33067.076088
# 19       27483.248322     26398.882395    34186.516391     33067.076088
# 20       27483.248322     22286.168510    34186.516391     33067.076088
# 21       27483.248322     22407.741365    34186.516391     33067.076088
# 22       27483.248322     22535.392862    34186.516391     33067.076088
# 23       27483.248322     22669.426934    34186.516391     33067.076088
# 24       27483.248322     22810.162710    34186.516391     33067.076088
# 25       27483.248322     22957.935275    34186.516391     33067.076088
# 26       27483.248322     23113.096468    34186.516391     33067.076088
# 27       27483.248322     23276.015721    34186.516391     33067.076088
# 28       27483.248322     23447.080936    34186.516391     33067.076088
# 29       27483.248322     23626.699412    34186.516391     33067.076088
# ...               ...              ...             ...              ...
# 10050    10621.922447     11885.144858    12291.391753     13728.694772
# 10051    10621.922447     11885.144858    12291.391753     13728.694772
# 10052    10621.922447     11885.144858    12291.391753     13728.694772
# 10053    10621.922447     11885.144858    12291.391753     13728.694772
# 10054    10621.922447     11885.144858    12291.391753     13728.694772
# 10055    10621.922447     11885.144858    12291.391753     13728.694772
# 10056    10621.922447     11885.144858    12291.391753     13728.694772
# 10057    10621.922447     11885.144858    12291.391753     13728.694772
# 10058    10621.922447     11885.144858    12291.391753     13728.694772
# 10059    10621.922447     11885.144858    12291.391753     13728.694772
# 10060    10621.922447     11885.144858    12291.391753     13728.694772
# 10061    10621.922447     11885.144858    12291.391753     13728.694772
# 10062    10621.922447     11885.144858    12291.391753     13728.694772
# 10063    10621.922447     11885.144858    12291.391753     13728.694772
# 10064    10621.922447     11885.144858    12291.391753     13728.694772
# 10065    10621.922447     11885.144858    12291.391753     13728.694772
# 10066    10621.922447     11885.144858    12291.391753     13728.694772
# 10067    10621.922447     11885.144858    12291.391753     13728.694772
# 10068    10621.922447     11885.144858    12291.391753     13728.694772
# 10069    10621.922447     11885.144858    12291.391753     13728.694772
# 10070    10621.922447     11885.144858    12291.391753     13728.694772
# 10071    10621.922447     11885.144858    12291.391753     13728.694772
# 10072    10621.922447     11885.144858    12291.391753     13728.694772
# 10073    10621.922447     11885.144858    12291.391753     13728.694772
# 10074    10621.922447     11885.144858    12291.391753     13728.694772
# 10075    10621.922447     11885.144858    12291.391753     13728.694772
# 10076    10621.922447     11885.144858    12291.391753     13728.694772
# 10077    10621.922447     11885.144858    12291.391753     13728.694772
# 10078    10621.922447     11885.144858    12291.391753     13728.694772
# 10079    10621.922447     11885.144858    12291.391753     13728.694772
#
#        EHP2_m0_w0_r0_f0  WB_m0_w0_r0_f0  WPB_m0_w0_r0_f0  EHP_m0_w0_r0_f0  \
# 0          1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 1          1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 2          1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 3          1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 4          1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 5          1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 6          1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 7          1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 8          1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 9          1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 10         1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 11         1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 12         1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 13         1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 14         1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 15         1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 16         1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 17         1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 18         1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 19         1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 20         1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 21         1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 22         1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 23         1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 24         1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 25         1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 26         1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 27         1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 28         1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# 29         1.402014e+06    1.394999e+06     26602.246014     1.404947e+06
# ...                 ...             ...              ...              ...
# 10050      1.383064e+06    1.382382e+06     10080.285243     1.384462e+06
# 10051      1.383064e+06    1.382382e+06     10369.054655     1.384462e+06
# 10052      1.383064e+06    1.382382e+06     10672.262539     1.384462e+06
# 10053      1.383064e+06    1.382382e+06     10990.630816     1.384462e+06
# 10054      1.383064e+06    1.382382e+06     11324.917507     1.384462e+06
# 10055      1.383064e+06    1.382382e+06     11675.918533     1.384462e+06
# 10056      1.383064e+06    1.382382e+06     12044.469610     1.384462e+06
# 10057      1.383064e+06    1.382382e+06     12431.448241     1.384462e+06
# 10058      1.383064e+06    1.382382e+06     12837.775803     1.384462e+06
# 10059      1.383064e+06    1.382382e+06     13264.419744     1.384462e+06
# 10060      1.383064e+06    1.382382e+06     15764.419744     5.514527e+05
# 10061      1.383064e+06    1.382382e+06     15764.419744     5.786969e+05
# 10062      1.383064e+06    1.382382e+06     15764.419744     6.073033e+05
# 10063      1.383064e+06    1.382382e+06     15764.419744     6.373399e+05
# 10064      1.383064e+06    1.382382e+06     15764.419744     6.688785e+05
# 10065      1.383064e+06    1.382382e+06     15764.419744     7.019939e+05
# 10066      1.383064e+06    1.382382e+06     15764.419744     7.367651e+05
# 10067      1.383064e+06    1.382382e+06     15764.419744     7.732749e+05
# 10068      1.383064e+06    1.382382e+06     15764.419744     8.116102e+05
# 10069      1.383064e+06    1.382382e+06     15764.419744     8.518622e+05
# 10070      1.383064e+06    1.382382e+06     15764.419744     8.941268e+05
# 10071      1.383064e+06    1.382382e+06     15764.419744     9.385047e+05
# 10072      1.383064e+06    1.382382e+06     15764.419744     9.851015e+05
# 10073      1.383064e+06    1.382382e+06     15764.419744     1.034028e+06
# 10074      1.383064e+06    1.382382e+06     15764.419744     1.085401e+06
# 10075      1.383064e+06    1.382382e+06     15764.419744     1.139343e+06
# 10076      1.383064e+06    1.382382e+06     15764.419744     1.195981e+06
# 10077      1.383064e+06    1.382382e+06     15764.419744     1.255452e+06
# 10078      1.383064e+06    1.382382e+06     15764.419744     1.317896e+06
# 10079      1.383064e+06    1.382382e+06     15764.419744     1.383462e+06
#
#        GB_m0_w0_r0_f1  CGB_m0_w0_r0_f1  ...  WPB_m18_w3_r3_f4  \
# 0        25167.842979     27240.326203  ...      35968.831322
# 1        25269.557925     27240.326203  ...      35968.831322
# 2        25376.358618     27240.326203  ...      35968.831322
# 3        25488.499346     27240.326203  ...      35968.831322
# 4        25606.247110     27240.326203  ...      35968.831322
# 5        25729.882263     27240.326203  ...      35968.831322
# 6        25859.699173     27240.326203  ...      35968.831322
# 7        25996.006928     27240.326203  ...      35968
# <b>limit_output extension: Maximum message size of 10000 exceeded with 38546 characters</b>

# %%
d
# Out:
#        ER_m0_w0_r0_f0  GB_m0_w0_r0_f0  CGB_m0_w0_r0_f0  OB_m0_w0_r0_f0  \
# 0        97233.339888   378525.623819    375284.289143   387459.925396
# 1        97337.954767   378525.623819    375284.289143   387459.925396
# 2        97447.800390   378525.623819    375284.289143   387459.925396
# 3        97563.138294   378525.623819    375284.289143   387459.925396
# 4        97684.243093   378525.623819    375284.289143   387459.925396
# 5        97811.403132   378525.623819    375284.289143   387459.925396
# 6        97944.921173   378525.623819    375284.289143   387459.925396
# 7        98085.115116   378525.623819    375284.289143   387459.925396
# 8        98232.318757   378525.623819    375284.289143   387459.925396
# 9        98386.882579   378525.623819    375284.289143   387459.925396
# 10       98549.174592   378525.623819    375284.289143   387459.925396
# 11       98719.581206   378525.623819    375284.289143   387459.925396
# 12       98898.508151   378525.623819    375284.289143   387459.925396
# 13       99086.381443   378525.623819    375284.289143   387459.925396
# 14       99283.648400   378525.623819    375284.289143   387459.925396
# 15       99490.778704   378525.623819    375284.289143   387459.925396
# 16       99708.265524   378525.623819    375284.289143   387459.925396
# 17       99936.626684   378525.623819    375284.289143   387459.925396
# 18      100176.405903   378525.623819    375284.289143   387459.925396
# 19      100428.174083   378525.623819    375284.289143   387459.925396
# 20      422928.174083    50756.858300     51984.289143    64959.925396
# 21      422928.174083    50909.737075     51984.289143    64959.925396
# 22      422928.174083    51070.259789     51984.289143    64959.925396
# 23      422928.174083    51238.808639     51984.289143    64959.925396
# 24      422928.174083    51415.784932     51984.289143    64959.925396
# 25      422928.174083    51601.610039     51984.289143    64959.925396
# 26      422928.174083    51796.726401     51984.289143    64959.925396
# 27      422928.174083    52001.598581     51984.289143    64959.925396
# 28      422928.174083    52216.714371     51984.289143    64959.925396
# 29      422928.174083    52442.585950     51984.289143    64959.925396
# ...               ...             ...              ...             ...
# 11310   349398.469491    20434.843306     21222.807506    23155.569891
# 11311   349398.469491    20434.843306     21222.807506    23155.569891
# 11312   349398.469491    20434.843306     21222.807506    23155.569891
# 11313   349398.469491    20434.843306     21222.807506    23155.569891
# 11314   349398.469491    20434.843306     21222.807506    23155.569891
# 11315   349398.469491    20434.843306     21222.807506    23155.569891
# 11316   349398.469491    20434.843306     21222.807506    23155.569891
# 11317   349398.469491    20434.843306     21222.807506    23155.569891
# 11318   349398.469491    20434.843306     21222.807506    23155.569891
# 11319   349398.469491    20434.843306     21222.807506    23155.569891
# 11320    26898.469491   342934.843306    343722.807506   345655.569891
# 11321    26898.469491   342934.843306    343722.807506   345655.569891
# 11322    26898.469491   342934.843306    343722.807506   345655.569891
# 11323    26898.469491   342934.843306    343722.807506   345655.569891
# 11324    26898.469491   342934.843306    343722.807506   345655.569891
# 11325    26898.469491   342934.843306    343722.807506   345655.569891
# 11326    26898.469491   342934.843306    343722.807506   345655.569891
# 11327    26898.469491   342934.843306    343722.807506   345655.569891
# 11328    26898.469491   342934.843306    343722.807506   345655.569891
# 11329    26898.469491   342934.843306    343722.807506   345655.569891
# 11330    26898.469491   342934.843306    343722.807506   345655.569891
# 11331    26898.469491   342934.843306    343722.807506   345655.569891
# 11332    26898.469491   342934.843306    343722.807506   345655.569891
# 11333    26898.469491   342934.843306    343722.807506   345655.569891
# 11334    26898.469491   342934.843306    343722.807506   345655.569891
# 11335    26898.469491   342934.843306    343722.807506   345655.569891
# 11336    26898.469491   342934.843306    343722.807506   345655.569891
# 11337    26898.469491   342934.843306    343722.807506   345655.569891
# 11338    26898.469491   342934.843306    343722.807506   345655.569891
# 11339    26898.469491   342934.843306    343722.807506   345655.569891
#
#        COB_m0_w0_r0_f0  EHP2_m0_w0_r0_f0  WB_m0_w0_r0_f0  WPB_m0_w0_r0_f0  \
# 0        383582.106865     381593.324893    57151.958421    369320.418949
# 1        383582.106865     381593.324893    57151.958421    369320.418949
# 2        383582.106865     381593.324893    57151.958421    369320.418949
# 3        383582.106865     381593.324893    57151.958421    369320.418949
# 4        383582.106865     381593.324893    57151.958421    369320.418949
# 5        383582.106865     381593.324893    57151.958421    369320.418949
# 6        383582.106865     381593.324893    57151.958421    369320.418949
# 7        383582.106865     381593.324893    57151.958421    369320.418949
# 8        383582.106865     381593.324893    57151.958421    369320.418949
# 9        383582.106865     381593.324893    57151.958421    369320.418949
# 10       383582.106865     381593.324893    57151.958421    369320.418949
# 11       383582.106865     381593.324893    57151.958421    369320.418949
# 12       383582.106865     381593.324893    57151.958421    369320.418949
# 13       383582.106865     381593.324893    57151.958421    369320.418949
# 14       383582.106865     381593.324893    57151.958421    369320.418949
# 15       383582.106865     381593.324893    57151.958421    369320.418949
# 16       383582.106865     381593.324893    57151.958421    369320.418949
# 17       383582.106865     381593.324893    57151.958421    369320.418949
# 18       383582.106865     381593.324893    57151.958421    369320.418949
# 19       383582.106865     381593.324893    57151.958421    369320.418949
# 20        61082.106865      59093.324893   379651.958421     46820.418949
# 21        61082.106865      59093.324893   379651.958421     46820.418949
# 22        61082.106865      59093.324893   379651.958421     46820.418949
# 23        61082.106865      59093.324893   379651.958421     46820.418949
# 24        61082.106865      59093.324893   379651.958421     46820.418949
# 25        61082.106865      59093.324893   379651.958421     46820.418949
# 26        61082.106865      59093.324893   379651.958421     46820.418949
# 27        61082.106865      59093.324893   379651.958421     46820.418949
# 28        61082.106865      59093.324893   379651.958421     46820.418949
# 29        61082.106865      59093.324893   379651.958421     46820.418949
# ...                ...               ...             ...              ...
# 11310     23983.943570      30429.708135   344462.825589     18363.413033
# 11311     23983.943570      30429.708135   344462.825589     18813.246815
# 11312     23983.943570      30429.708135   344462.825589     19285.572285
# 11313     23983.943570      30429.708135   344462.825589     19781.514029
# 11314     23983.943570      30429.708135   344462.825589     20302.252861
# 11315     23983.943570      30429.708135   344462.825589     20849.028633
# 11316     23983.943570      30429.708135   344462.825589     21423.143195
# 11317     23983.943570      30429.708135   344462.825589     22025.963484
# 11318     23983.943570      30429.708135   344462.825589     22658.924788
# 11319     23983.943570      30429.708135   344462.825589     23323.534157
# 11320    346483.943570     352929.708135    21962.825589    348323.534157
# 11321    346483.943570     352929.708135    21962.825589    348323.534157
# 11322    346483.943570     352929.708135    21962.825589    348323.534157
# 11323    346483.943570     352929.708135    21962.825589    348323.534157
# 11324    346483.943570     352929.708135    21962.825589    348323.534157
# 11325    346483.943570     352929.708135    21962.825589    348323.534157
# 11326    346483.943570     352929.708135    21962.825589    348323.534157
# 11327    346483.943570     352929.708135    21962.825589    348323.534157
# 11328    346483.943570     352929.708135    21962.825589    348323.534157
# 11329    346483.943570     352929.708135    21962.825589    348323.534157
# 11330    346483.943570     352929.708135    21962.825589    348323.534157
# 11331    346483.943570     352929.708135    21962.825589    348323.534157
# 11332    346483.943570     352929.708135    21962.825589    348323.534157
# 11333    346483.943570     352929.708135    21962.825589    348323.534157
# 11334    346483.943570     352929.708135    21962.825589    348323.534157
# 11335    346483.943570     352929.708135    21962.825589    348323.534157
# 11336    346483.943570     352929.708135    21962.825589    348323.534157
# 11337    346483.943570     352929.708135    21962.825589    348323.534157
# 11338    346483.943570     352929.708135    21962.825589    348323.534157
# 11339    346483.943570     352929.708135    21962.825589    348323.534157
#
#        EHP_m0_w0_r0_f0  ER_m0_w0_r0_f1  ...  EHP_m19_w3_r7_f2  \
# 0         68083.797037    99731.551089  ...      84398.011951
# 1         68083.797037    99832.164402  ...      84398.011951
# 2         68083.797037    99937.808381  ...      84398.011951
# 3         68083.797037   100048.734558  ...      84398.011951
# 4         68083.797037   100165.207045  ...      84398.011951
# 5         68083.797037   100287.503156  ...      84398.011951
# 6         68083.797037   100415.914072  ...      84398.011951
# 7         68083.797037   100550.745534  ...      84398.011951
# 8         68083.797037   100692.318570  ...      84
# <b>limit_output extension: Maximum message size of 10000 exceeded with 39213 characters</b>

# %% [markdown]
# ## Class instantiation for each type of dwelling

# %% [markdown]
# Instance_CID_GHC_UEN_Conditions = DF_for_CID_U_Factors(Prepared_df_CID_UF)
# df_CID_GHC_UEN_Conditions = Instance_CID_GHC_UEN_Conditions.GHC_UEN_EHP()
# df_CID_GHC_UEN_Conditions.shape

# %% [markdown]
# Instance_CID_Unvariable_Costs = DF_for_CID_U_Prices(Prepared_df_CID_UP)
# df_CID_Unvariable_Costs = Instance_CID_Unvariable_Costs.Multiple_Cost_EHP()
# df_CID_Unvariable_Costs.shape

# %% [markdown]
# df_CID_GHC = b.astype(np.int32)
# df_CID_GHC.shape

# %% [markdown]
# Test_CID_0 = df_1_sorted[new_columns_CID][
#     (df_1_sorted["Dwelling Type"] == 'CID')
#     & (df_1_sorted["Climate Type"] == 'H1') &
#     (df_1_sorted["Construction Period"] == '<1948') &
#     (df_1_sorted["Size Factor"] == 'Middle') &
#     (df_1_sorted["__init__ial Age"] == 0)]
#
# CID_H1_P1_T1_A00 = pd.read_csv('../Test_Samples/CID_H1_P1_T1_A00.csv',
#                                sep=';',
#                                index_col=None,
#                                header=None)
#
# Test_CID_0 = Test_CID_0.T.reset_index(drop=True)
#
# Test_CID_0.columns = list(range(9))
#
# Test_CID_0 - CID_H1_P1_T1_A00

# %% [markdown]
# Test_CID_19 = df_1_sorted[new_columns_CID][
#     (df_1_sorted["Dwelling Type"] == 'CID')
#     & (df_1_sorted["Climate Type"] == 'H1') &
#     (df_1_sorted["Construction Period"] == '<1948') &
#     (df_1_sorted["Size Factor"] == 'Middle') &
#     (df_1_sorted["__init__ial Age"] == 19)]
#
# CID_H1_P1_T1_A19 = pd.read_csv('../Test_Samples/CID_H1_P1_T1_A19.csv',
#                                sep=';',
#                                index_col=None,
#                                header=None)
#
# Test_CID_19 = Test_CID_19.T.reset_index(drop=True)
#
# Test_CID_19.columns = list(range(9))
#
# Test_CID_19 - CID_H1_P1_T1_A19

# %% [markdown]
# Instance_CCD_GHC_UEN_Conditions = DF_for_CCD_U_Factors(Prepared_df_CCD_UF)
# df_CCD_GHC_UEN_Conditions = Instance_CCD_GHC_UEN_Conditions.GHC_UEN_EHP()
# df_CCD_GHC_UEN_Conditions.shape

# %% [markdown]
# Instance_CCD_Unvariable_Costs = DF_for_CCD_U_Prices(Prepared_df_CCD_UP)
# df_CCD_Unvariable_Costs = Instance_CCD_Unvariable_Costs.Multiple_Cost_EHP()
# df_CCD_Unvariable_Costs.shape

# %% [markdown]
# selected_columns_CCD = df_CCD_Unvariable_Costs.loc[:, 'GB_m0_w0_r0_f0':
#                                                    'EHP_m18_w3_r3_f5'].columns.tolist(
#                                                    )
# df_CCD_GHC = df_CCD_GHC_UEN_Conditions[
#     selected_columns_CCD] + df_CCD_Unvariable_Costs[selected_columns_CCD]
# df_CCD_GHC = df_CCD_GHC.astype(np.int32)
# df_CCD_GHC.shape

# %% [markdown]
# new_columns_CCD = []
# for i in range(1824):
#     list_i = selected_columns_CCD[i::1824]
#     new_columns_CCD += list_i
# df_CCD_GHC_new = df_CCD_GHC[new_columns_CCD]
# df_CCD_GHC_new

# %% [markdown]
# df_2 = pd.concat([df_CCD, df_CCD_GHC_new], axis=1, join='outer')
# df_2_sorted = df_2.sort_values(by='__init__ial Age', kind='mergesort')
# df_2_sorted

# %% [markdown]
# Test_CCD_0 = df_2_sorted[new_columns_CCD][
#     (df_2_sorted["Dwelling Type"] == 'CCD')
#     & (df_2_sorted["Climate Type"] == 'H1') &
#     (df_2_sorted["Construction Period"] == '<1948') &
#     (df_2_sorted["Size Factor"] == 'Middle') &
#     (df_2_sorted["__init__ial Age"] == 0)]
#
# CCD_H1_P1_T1_A00 = pd.read_csv('../Test_Samples/CCD_H1_P1_T1_A00.csv',
#                                sep=';',
#                                index_col=None,
#                                header=None)
#
# CCD_H1_P1_T1_A00 = CCD_H1_P1_T1_A00.dropna(axis=0,
#                                            how='all').reset_index(drop=True)
#
# Test_CCD_0 = Test_CCD_0.T.reset_index(drop=True)
#
# Test_CCD_0.columns = list(range(8))
#
# Test_CCD_0 - CCD_H1_P1_T1_A00

# %% [markdown]
# Test_CCD_19 = df_2_sorted[new_columns_CCD][
#     (df_2_sorted["Dwelling Type"] == 'CCD')
#     & (df_2_sorted["Climate Type"] == 'H1') &
#     (df_2_sorted["Construction Period"] == '<1948') &
#     (df_2_sorted["Size Factor"] == 'Middle') &
#     (df_2_sorted["__init__ial Age"] == 19)]
#
# CCD_H1_P1_T1_A19 = pd.read_csv('../Test_Samples/CCD_H1_P1_T1_A19.csv',
#                                sep=';',
#                                index_col=None,
#                                header=None)
#
# CCD_H1_P1_T1_A19 = CCD_H1_P1_T1_A19.dropna(axis=0,
#                                            how='all').reset_index(drop=True)
#
# Test_CCD_19 = Test_CCD_19.T.reset_index(drop=True)
#
# Test_CCD_19.columns = list(range(8))
#
# Test_CCD_19 - CCD_H1_P1_T1_A19

# %% [markdown]
# Instance_ID_GHC_UEN_Conditions = DF_for_ID_U_Factors(Prepared_df_ID_UF)
# df_ID_GHC_UEN_Conditions = Instance_ID_GHC_UEN_Conditions.GHC_UEN_EHP()
# df_ID_GHC_UEN_Conditions.shape

# %% [markdown]
# Instance_ID_Unvariable_Costs = DF_for_ID_U_Prices(Prepared_df_ID_UP)
# df_ID_Unvariable_Costs = Instance_ID_Unvariable_Costs.Multiple_Cost_EHP()
# df_ID_Unvariable_Costs.shape

# %% [markdown]
# selected_columns_ID = df_ID_Unvariable_Costs.loc[:, 'ER_m0_w0_r0_f0':
#                                                  'EHP_m19_w3_r7_f3'].columns.tolist(
#                                                  )
# df_ID_GHC = df_ID_GHC_UEN_Conditions[
#     selected_columns_ID] + df_ID_Unvariable_Costs[selected_columns_ID]
# df_ID_GHC = df_ID_GHC.astype(np.int32)
# df_ID_GHC.shape

# %% [markdown]
# new_columns_ID = []
# for i in range(2560):
#     list_i = selected_columns_ID[i::2560]
#     new_columns_ID += list_i
# df_ID_GHC_new = df_ID_GHC[new_columns_ID]
# df_ID_GHC_new

# %% [markdown]
# df_3 = pd.concat([df_ID, df_ID_GHC_new], axis=1, join='outer')
# df_3_sorted = df_3.sort_values(by='__init__ial Age', kind='mergesort')
# df_3_sorted

# %% [markdown]
# Test_ID_0 = df_3_sorted[new_columns_ID][
#     (df_3_sorted["Dwelling Type"] == 'ID')
#     & (df_3_sorted["Climate Type"] == 'H1') &
#     (df_3_sorted["Construction Period"] == '<1968') &
#     (df_3_sorted["Size Factor"] == 'Middle') &
#     (df_3_sorted["__init__ial Age"] == 0)]
#
# ID_H1_P1_T1_A00 = pd.read_csv('../Test_Samples/ID_H1_P1_T1_A00.csv',
#                               sep=';',
#                               index_col=None,
#                               header=None)
#
# ID_H1_P1_T1_A00 = ID_H1_P1_T1_A00.dropna(axis=0,
#                                          how='all').reset_index(drop=True)
#
# Test_ID_0 = Test_ID_0.T.reset_index(drop=True)
#
# Test_ID_0.columns = list(range(9))
#
# Test_ID_0 - ID_H1_P1_T1_A00

# %% [markdown]
# Test_ID_19 = df_3_sorted[new_columns_ID][
#     (df_3_sorted["Dwelling Type"] == 'ID')
#     & (df_3_sorted["Climate Type"] == 'H1') &
#     (df_3_sorted["Construction Period"] == '<1968') &
#     (df_3_sorted["Size Factor"] == 'Middle') &
#     (df_3_sorted["__init__ial Age"] == 19)]
#
# ID_H1_P1_T1_A19 = pd.read_csv('../Test_Samples/ID_H1_P1_T1_A19.csv',
#                               sep=';',
#                               index_col=None,
#                               header=None)
#
# ID_H1_P1_T1_A19 = ID_H1_P1_T1_A19.dropna(axis=0,
#                                          how='all').reset_index(drop=True)
#
# Test_ID_19 = Test_ID_19.T.reset_index(drop=True)
#
# Test_ID_19.columns = list(range(9))
#
# Test_ID_19 - ID_H1_P1_T1_A19

# %% [markdown]
# Test_ID_19

# %% [markdown]
# ID_H1_P1_T1_A19

# %% [markdown]
# df = pd.concat([df_CID, Total_new], axis=1, join='outer')
# df.shape

# %% [markdown]
# Total_sorted = df.sort_values(by='__init__ial Age', kind='mergesort')
# Total_sorted

# %% [markdown]
# Total_sorted['__init__ial Age']

# %% [markdown]
# Test_1 = Total_sorted[list_all][
#     (Total_sorted["Dwelling Type"] == 'CID')
#     & (Total_sorted["Climate Type"] == 'H1') &
#     (Total_sorted["Construction Period"] == '<1948') &
#     (Total_sorted["Size Factor"] == 'Middle') &
#     (Total_sorted["__init__ial Age"] == 0)]
#
# Classeur1 = pd.read_csv('../Classeur1.csv',
#                         sep=';',
#                         index_col=None,
#                         header=None)
#
# Test_1 = Test_1.T.reset_index(drop=True)
#
# Test_1.columns = list(range(9))
#
# Test_1 - Classeur1

# %% [markdown]
# Test_2 = Total_sorted[list_all][
#     (Total_sorted["Dwelling Type"] == 'CID')
#     & (Total_sorted["Climate Type"] == 'H1') &
#     (Total_sorted["Construction Period"] == '<1948') &
#     (Total_sorted["Size Factor"] == 'Middle') &
#     (Total_sorted["__init__ial Age"] == 10)]
#
# Classeur2 = pd.read_csv('../Classeur2.csv',
#                         sep=';',
#                         index_col=None,
#                         header=None)
#
# Test_2 = Test_2.T.reset_index(drop=True)
#
# Test_2.columns = list(range(9))
#
# Test_2 - Classeur2

# %% [markdown]
# Test_2

# %% [markdown]
# Test_ID_0

# %% [markdown]
# a = DF_for_ID_U_Factors(Prepared_df_ID_UF)
# b = a.UEN_per_Dwelling()

# %% [markdown]
# b[b['Size_Factor'] == 'Large'].ER_m0_w0_r0_f0

# %% [markdown]
# Prepared_df_ID_UP.Surface_M / Prepared_df_ID_UP.Dwelling_Total

# %% [markdown]
# Prepared_df_ID_UP.U_m0_w0

# %% [markdown]
# Prepared_df_ID_UP.Dwelling_Total

# %% [markdown]
# df_ID_UP.Uw1
