# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Importation-of-necessary-libraries" data-toc-modified-id="Importation-of-necessary-libraries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Importation of necessary libraries</a></span></li><li><span><a href="#Extraction-of-data-from-CSV-files" data-toc-modified-id="Extraction-of-data-from-CSV-files-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Extraction of data from CSV files</a></span></li><li><span><a href="#Combination-of-all-the-necessary-data" data-toc-modified-id="Combination-of-all-the-necessary-data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Combination of all the necessary data</a></span><ul class="toc-item"><li><span><a href="#Class-for-all-types-of-dwellings" data-toc-modified-id="Class-for-all-types-of-dwellings-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Class for all types of dwellings</a></span></li><li><span><a href="#Class-for-the-CID-type-dwellings" data-toc-modified-id="Class-for-the-CID-type-dwellings-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Class for the CID type dwellings</a></span></li><li><span><a href="#Class-for-the-CCD-type-dwellings" data-toc-modified-id="Class-for-the-CCD-type-dwellings-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Class for the CCD type dwellings</a></span></li><li><span><a href="#Class-for-the-ID-type-dwellings" data-toc-modified-id="Class-for-the-ID-type-dwellings-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Class for the ID type dwellings</a></span></li><li><span><a href="#Class-instantiation-for-each-type-of-dwelling" data-toc-modified-id="Class-instantiation-for-each-type-of-dwelling-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Class instantiation for each type of dwelling</a></span></li><li><span><a href="#Data-retention" data-toc-modified-id="Data-retention-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Data retention</a></span></li></ul></li><li><span><a href="#Creation-of-some-calculable-columns" data-toc-modified-id="Creation-of-some-calculable-columns-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Creation of some calculable columns</a></span><ul class="toc-item"><li><span><a href="#Class-for-all-types-of-dwellings" data-toc-modified-id="Class-for-all-types-of-dwellings-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Class for all types of dwellings</a></span></li><li><span><a href="#Class-for-the-collective-dwellings" data-toc-modified-id="Class-for-the-collective-dwellings-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Class for the collective dwellings</a></span><ul class="toc-item"><li><span><a href="#Class-for-the-DataFrame-with-U-Factors" data-toc-modified-id="Class-for-the-DataFrame-with-U-Factors-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Class for the DataFrame with U Factors</a></span></li><li><span><a href="#Class-for-the-DataFrame-with-U-Prices" data-toc-modified-id="Class-for-the-DataFrame-with-U-Prices-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Class for the DataFrame with U Prices</a></span></li></ul></li><li><span><a href="#Class-for-the-individual-dwellings" data-toc-modified-id="Class-for-the-individual-dwellings-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Class for the individual dwellings</a></span><ul class="toc-item"><li><span><a href="#Class-for-the-DataFrame-with-U-Factors" data-toc-modified-id="Class-for-the-DataFrame-with-U-Factors-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Class for the DataFrame with U Factors</a></span></li><li><span><a href="#Class-for-the-DataFrame-with-U-Prices" data-toc-modified-id="Class-for-the-DataFrame-with-U-Prices-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Class for the DataFrame with U Prices</a></span></li></ul></li><li><span><a href="#Class-instantiation-for-each-type-of-dwelling" data-toc-modified-id="Class-instantiation-for-each-type-of-dwelling-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Class instantiation for each type of dwelling</a></span></li></ul></li><li><span><a href="#Creation-of-some-calculable-DataFrames" data-toc-modified-id="Creation-of-some-calculable-DataFrames-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Creation of some calculable DataFrames</a></span><ul class="toc-item"><li><span><a href="#Class-for-all-types-of-dwellings" data-toc-modified-id="Class-for-all-types-of-dwellings-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Class for all types of dwellings</a></span></li><li><span><a href="#Class-for-the-CID-type-dwellings" data-toc-modified-id="Class-for-the-CID-type-dwellings-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Class for the CID type dwellings</a></span><ul class="toc-item"><li><span><a href="#Class-for-the-DataFrame-with-U-Factors" data-toc-modified-id="Class-for-the-DataFrame-with-U-Factors-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Class for the DataFrame with U Factors</a></span></li><li><span><a href="#Class-for-the-DataFrame-with-U-Prices" data-toc-modified-id="Class-for-the-DataFrame-with-U-Prices-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Class for the DataFrame with U Prices</a></span></li></ul></li><li><span><a href="#Qin" data-toc-modified-id="Qin-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Qin</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Importation of necessary libraries

# %%
import pandas as pd

import itertools

import numpy as np

# %% [markdown]
# # Extraction of data from CSV files

# %%
df_Wall_Investment = pd.read_csv('../Input_Data_CSV/Wall_Investment.csv',
                                 sep=';',
                                 index_col=None,
                                 header=0)

df_Window_Investment = pd.read_csv('../Input_Data_CSV/Window_Investment.csv',
                                   sep=';',
                                   index_col=None,
                                   header=0)

df_Roof_Investment = pd.read_csv('../Input_Data_CSV/Roof_Investment.csv',
                                 sep=';',
                                 index_col=None,
                                 header=0)

df_Floor_Investment = pd.read_csv('../Input_Data_CSV/Floor_Investment.csv',
                                  sep=';',
                                  index_col=None,
                                  header=0)

df_Housing_Characteristics = pd.read_csv(
    '../Input_Data_CSV/Housing_Characteristics.csv',
    sep=';',
    index_col=None,
    header=0)

df_Climate_Zone = pd.read_csv('../Input_Data_CSV/Climate_Zone.csv',
                              sep=';',
                              index_col=None,
                              header=0)

df_Heating_System = pd.read_csv('../Input_Data_CSV/Heating_System.csv',
                                sep=';',
                                index_col=None,
                                header=0)

df_Headcount = pd.read_csv('../Input_Data_CSV/Headcount.csv',
                           sep=';',
                           index_col=None,
                           header=0)

df_Economic_Hypothesis = pd.read_csv(
    '../Input_Data_CSV/Economic_Hypothesis.csv',
    sep=';',
    index_col=None,
    header=0)

# %% [markdown]
# # Combination of all the necessary data
#
# ## Class for all types of dwellings

# %%
class All_Types:
    def __init__(self, *args):
        self.df_1 = df_Climate_Zone
        self.df_2 = df_Housing_Characteristics
        self.df_3 = df_Headcount
        self.df_4 = df_Heating_System
        self.df_5 = df_Economic_Hypothesis
        self.df_6 = df_Wall_Investment
        self.df_7 = df_Window_Investment
        self.df_8 = df_Roof_Investment
        self.df_9 = df_Floor_Investment

# %% [markdown]
# ## Class for the CID type dwellings

# %%
class CID_Type(All_Types):
    def init(self, *args):
        super().init(*args)

    def Combine_Lists(self):
        self.list_combined = []
        list_dwelling_type = ['CID']
        list_climate_type = self.df_1.iloc[:, 0].tolist()
        list_construction_period = self.df_2.iloc[:21, 1].tolist()[::3]
        list_size_factor = self.df_2.iloc[:3, 2].tolist()
        list_heating_system = [
            'ER', 'GB', 'CGB', 'OB', 'COB', 'EHP2', 'WB', 'WPB', 'EHP'
        ]
        list_initial_age = self.df_3.iloc[:20, 5].tolist()
        self.list_combined.append(list_dwelling_type)
        self.list_combined.append(list_climate_type)
        self.list_combined.append(list_construction_period)
        self.list_combined.append(list_size_factor)
        self.list_combined.append(list_heating_system)
        self.list_combined.append(list_initial_age)
        return self.list_combined

    def Generate_DF(self):
        self.Combine_Lists()
        itertools_product = list(itertools.product(*self.list_combined))
        self.df = pd.DataFrame(itertools_product,
                               columns=[
                                   'Dwelling Type', 'Climate Type',
                                   'Construction Period', 'Size Factor',
                                   'Heating System', 'Initial Age'
                               ])
        return self.df

    def Merge_DFs(self):
        self.Generate_DF()
        self.df = self.df.merge(self.df_1, how='left', on=['Climate Type'])
        self.df = self.df.merge(self.df_2.iloc[:21, 1:9],
                                how='left',
                                on=['Construction Period', 'Size Factor'])
        self.df = self.df.merge(self.df_4.iloc[:9, :],
                                how='left',
                                on=['Heating System'])
        return self.df

    def Add_Columns(self):
        self.Merge_DFs()
        self.df[self.df_5.columns[0]] = self.df_5.iloc[0, 0]
        self.df[self.df_5.columns[1]] = self.df_5.iloc[0, 1]
        self.df[self.df_5.columns[2]] = self.df_5.iloc[0, 2]
        self.df[self.df_5.columns[3]] = self.df_5.iloc[0, 3]
        return self.df

    def Concat_DFs(self):
        self.Add_Columns()
        self.df = pd.concat([self.df, self.df_3.iloc[0:11340, 6]],
                            axis=1,
                            join='outer')
        return self.df

    def Reorder_Columns(self):
        self.Concat_DFs()
        cols = self.df.columns.tolist()
        reordered_cols = cols[:2] + cols[6:7] + cols[2:4] + cols[7:13] + cols[
            4:5] + cols[13:28] + cols[5:6] + cols[28:29]
        self.df = self.df[reordered_cols]
        return self.df

    def Add_U_Factors(self):
        self.Reorder_Columns()
        self.df = self.df.merge(
            self.df_2.loc[:20, ['Construction Period', 'Size Factor', 'Um0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for m in range(18):
            self.df['Um' + str(m + 1)] = self.df_6.iloc[m, 2]
        self.df = self.df.merge(
            self.df_2.loc[:20, ['Construction Period', 'Size Factor', 'Uw0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for w in range(3):
            self.df['Uw' + str(w + 1)] = self.df_7.iloc[w, 2]
        self.df = self.df.merge(
            self.df_2.loc[:20, ['Construction Period', 'Size Factor', 'Ur0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for r in range(3):
            self.df['Ur' + str(r + 1)] = self.df_8.iloc[r, 2]
        self.df = self.df.merge(
            self.df_2.loc[:20, ['Construction Period', 'Size Factor', 'Uf0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for f in range(5):
            self.df['Uf' + str(f + 1)] = self.df_9.iloc[f, 2]
        return self.df

    def Add_U_Prices(self):
        self.Reorder_Columns()
        self.df['Um0'] = 0
        for m in range(18):
            self.df['Um' + str(m + 1)] = self.df_6.iloc[m, 3]
        self.df['Uw0'] = 0
        for w in range(3):
            self.df['Uw' + str(w + 1)] = self.df_7.iloc[w, 3]
        self.df['Ur0'] = 0
        for r in range(3):
            self.df['Ur' + str(r + 1)] = self.df_8.iloc[r, 3]
        self.df['Uf0'] = 0
        for f in range(5):
            self.df['Uf' + str(f + 1)] = self.df_9.iloc[f, 3]
        return self.df

# %% [markdown]
# ## Class for the CCD type dwellings

# %%
class CCD_Type(All_Types):
    def init(self, *args):
        super().init(*args)

    def Combine_Lists(self):
        self.list_combined = []
        list_dwelling_type = ['CCD']
        list_climate_type = self.df_1.iloc[:, 0].tolist()
        list_construction_period = self.df_2.iloc[:21, 1].tolist()[::3]
        list_size_factor = self.df_2.iloc[:3, 2].tolist()
        list_heating_system = [
            'GB', 'CGB', 'OB', 'COB', 'EHP2', 'WB', 'WPB', 'EHP'
        ]
        list_initial_age = self.df_3.iloc[:20, 5].tolist()
        self.list_combined.append(list_dwelling_type)
        self.list_combined.append(list_climate_type)
        self.list_combined.append(list_construction_period)
        self.list_combined.append(list_size_factor)
        self.list_combined.append(list_heating_system)
        self.list_combined.append(list_initial_age)
        return self.list_combined

    def Generate_DF(self):
        self.Combine_Lists()
        itertools_product = list(itertools.product(*self.list_combined))
        self.df = pd.DataFrame(itertools_product,
                               columns=[
                                   'Dwelling Type', 'Climate Type',
                                   'Construction Period', 'Size Factor',
                                   'Heating System', 'Initial Age'
                               ])
        return self.df

    def Merge_DFs(self):
        self.Generate_DF()
        self.df = self.df.merge(self.df_1, how='left', on=['Climate Type'])
        self.df = self.df.merge(self.df_2.iloc[:21, 1:9],
                                how='left',
                                on=['Construction Period', 'Size Factor'])
        self.df = self.df.merge(self.df_4.iloc[9:17, :],
                                how='left',
                                on=['Heating System'])
        return self.df

    def Add_Columns(self):
        self.Merge_DFs()
        self.df[self.df_5.columns[0]] = self.df_5.iloc[0, 0]
        self.df[self.df_5.columns[1]] = self.df_5.iloc[0, 1]
        self.df[self.df_5.columns[2]] = self.df_5.iloc[0, 2]
        self.df[self.df_5.columns[3]] = self.df_5.iloc[0, 3]
        return self.df

    def Concat_DFs(self):
        self.Add_Columns()
        self.df = pd.concat(
            [self.df, self.df_3.iloc[11340:21420, 6].reset_index(drop=True)],
            axis=1,
            join='outer')
        return self.df

    def Reorder_Columns(self):
        self.Concat_DFs()
        cols = self.df.columns.tolist()
        reordered_cols = cols[:2] + cols[6:7] + cols[2:4] + cols[7:13] + cols[
            4:5] + cols[13:28] + cols[5:6] + cols[28:29]
        self.df = self.df[reordered_cols]
        return self.df

    def Add_U_Factors(self):
        self.Reorder_Columns()
        self.df = self.df.merge(
            self.df_2.loc[:20, ['Construction Period', 'Size Factor', 'Um0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for m in range(18):
            self.df['Um' + str(m + 1)] = self.df_6.iloc[m, 2]
        self.df = self.df.merge(
            self.df_2.loc[:20, ['Construction Period', 'Size Factor', 'Uw0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for w in range(3):
            self.df['Uw' + str(w + 1)] = self.df_7.iloc[w, 2]
        self.df = self.df.merge(
            self.df_2.loc[:20, ['Construction Period', 'Size Factor', 'Ur0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for r in range(3):
            self.df['Ur' + str(r + 1)] = self.df_8.iloc[r, 2]
        self.df = self.df.merge(
            self.df_2.loc[:20, ['Construction Period', 'Size Factor', 'Uf0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for f in range(5):
            self.df['Uf' + str(f + 1)] = self.df_9.iloc[f, 2]
        return self.df

    def Add_U_Prices(self):
        self.Reorder_Columns()
        self.df['Um0'] = 0
        for m in range(18):
            self.df['Um' + str(m + 1)] = self.df_6.iloc[m, 3]
        self.df['Uw0'] = 0
        for w in range(3):
            self.df['Uw' + str(w + 1)] = self.df_7.iloc[w, 3]
        self.df['Ur0'] = 0
        for r in range(3):
            self.df['Ur' + str(r + 1)] = self.df_8.iloc[r, 3]
        self.df['Uf0'] = 0
        for f in range(5):
            self.df['Uf' + str(f + 1)] = self.df_9.iloc[f, 3]
        return self.df

# %% [markdown]
# ## Class for the ID type dwellings

# %%
class ID_Type(All_Types):
    def init(self, *args):
        super().init(*args)

    def Combine_Lists(self):
        self.list_combined = []
        list_dwelling_type = ['ID']
        list_climate_type = self.df_1.iloc[:, 0].tolist()
        list_construction_period = self.df_2.iloc[21:, 1].tolist()[::3]
        list_size_factor = self.df_2.iloc[:3, 2].tolist()
        list_heating_system = [
            'ER', 'GB', 'CGB', 'OB', 'COB', 'EHP2', 'WB', 'WPB', 'EHP'
        ]
        list_initial_age = self.df_3.iloc[:20, 5].tolist()
        self.list_combined.append(list_dwelling_type)
        self.list_combined.append(list_climate_type)
        self.list_combined.append(list_construction_period)
        self.list_combined.append(list_size_factor)
        self.list_combined.append(list_heating_system)
        self.list_combined.append(list_initial_age)
        return self.list_combined

    def Generate_DF(self):
        self.Combine_Lists()
        itertools_product = list(itertools.product(*self.list_combined))
        self.df = pd.DataFrame(itertools_product,
                               columns=[
                                   'Dwelling Type', 'Climate Type',
                                   'Construction Period', 'Size Factor',
                                   'Heating System', 'Initial Age'
                               ])
        return self.df

    def Merge_DFs(self):
        self.Generate_DF()
        self.df = self.df.merge(self.df_1, how='left', on=['Climate Type'])
        self.df = self.df.merge(self.df_2.iloc[21:, 1:9],
                                how='left',
                                on=['Construction Period', 'Size Factor'])
        self.df = self.df.merge(self.df_4.iloc[17:, :],
                                how='left',
                                on=['Heating System'])
        return self.df

    def Add_Columns(self):
        self.Merge_DFs()
        self.df[self.df_5.columns[0]] = self.df_5.iloc[0, 0]
        self.df[self.df_5.columns[1]] = self.df_5.iloc[0, 1]
        self.df[self.df_5.columns[2]] = self.df_5.iloc[0, 2]
        self.df[self.df_5.columns[3]] = self.df_5.iloc[0, 3]
        return self.df

    def Concat_DFs(self):
        self.Add_Columns()
        self.df = pd.concat(
            [self.df, self.df_3.iloc[21420:, 6].reset_index(drop=True)],
            axis=1,
            join='outer')
        return self.df

    def Reorder_Columns(self):
        self.Concat_DFs()
        cols = self.df.columns.tolist()
        reordered_cols = cols[:2] + cols[6:7] + cols[2:4] + cols[7:13] + cols[
            4:5] + cols[13:28] + cols[5:6] + cols[28:29]
        self.df = self.df[reordered_cols]
        return self.df

    def Add_U_Factors(self):
        self.Reorder_Columns()
        self.df = self.df.merge(
            self.df_2.loc[21:, ['Construction Period', 'Size Factor', 'Um0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for m in range(19):
            self.df['Um' + str(m + 1)] = self.df_6.iloc[m + 18, 2]
        self.df = self.df.merge(
            self.df_2.loc[21:, ['Construction Period', 'Size Factor', 'Uw0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for w in range(3):
            self.df['Uw' + str(w + 1)] = self.df_7.iloc[w + 3, 2]
        self.df = self.df.merge(
            self.df_2.loc[21:, ['Construction Period', 'Size Factor', 'Ur0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for r in range(7):
            self.df['Ur' + str(r + 1)] = self.df_8.iloc[r + 3, 2]
        self.df = self.df.merge(
            self.df_2.loc[21:, ['Construction Period', 'Size Factor', 'Uf0']],
            how='left',
            on=['Construction Period', 'Size Factor'])
        for f in range(3):
            self.df['Uf' + str(f + 1)] = self.df_9.iloc[f + 5, 2]
        return self.df

    def Add_U_Prices(self):
        self.Reorder_Columns()
        self.df['Um0'] = 0
        for m in range(19):
            self.df['Um' + str(m + 1)] = self.df_6.iloc[m + 18, 3]
        self.df['Uw0'] = 0
        for w in range(3):
            self.df['Uw' + str(w + 1)] = self.df_7.iloc[w + 3, 3]
        self.df['Ur0'] = 0
        for r in range(7):
            self.df['Ur' + str(r + 1)] = self.df_8.iloc[r + 3, 3]
        self.df['Uf0'] = 0
        for f in range(3):
            self.df['Uf' + str(f + 1)] = self.df_9.iloc[f + 5, 3]
        return self.df

# %% [markdown]
# ## Class instantiation for each type of dwelling

# %%
Instance_CID = CID_Type()

df_CID = Instance_CID.Reorder_Columns()
df_CID_UF = Instance_CID.Add_U_Factors()
df_CID_UP = Instance_CID.Add_U_Prices()

df_CID.shape
# Out:
# (11340, 29)

# %%
Instance_CCD = CCD_Type()

df_CCD = Instance_CCD.Reorder_Columns()
df_CCD_UF = Instance_CCD.Add_U_Factors()
df_CCD_UP = Instance_CCD.Add_U_Prices()

df_CCD.shape
# Out:
# (10080, 29)

# %%
Instance_ID = ID_Type()

df_ID = Instance_ID.Reorder_Columns()
df_ID_UF = Instance_ID.Add_U_Factors()
df_ID_UP = Instance_ID.Add_U_Prices()

df_ID.shape
# Out:
# (11340, 29)

# %% [markdown]
# ## Data retention

# %%
df_CID.to_csv(
    '../Output_Data_CSV/Combination_with_Input_Data/CID_Type_Dwellings.csv',
    sep=';',
    index=None,
    header=True,
    encoding='utf-8')

df_CID_UF.to_csv(
    '../Output_Data_CSV/Combination_with_Input_Data/CID_Type_Dwellings_with_U_Factors.csv',
    sep=';',
    index=None,
    header=True,
    encoding='utf-8')

df_CID_UP.to_csv(
    '../Output_Data_CSV/Combination_with_Input_Data/CID_Type_Dwellings_with_U_Prices.csv',
    sep=';',
    index=None,
    header=True,
    encoding='utf-8')

df_CCD.to_csv(
    '../Output_Data_CSV/Combination_with_Input_Data/CCD_Type_Dwellings.csv',
    sep=';',
    index=None,
    header=True,
    encoding='utf-8')

df_CCD_UF.to_csv(
    '../Output_Data_CSV/Combination_with_Input_Data/CCD_Type_Dwellings_with_U_Factors.csv',
    sep=';',
    index=None,
    header=True,
    encoding='utf-8')

df_CCD_UP.to_csv(
    '../Output_Data_CSV/Combination_with_Input_Data/CCD_Type_Dwellings_with_U_Prices.csv',
    sep=';',
    index=None,
    header=True,
    encoding='utf-8')

df_ID.to_csv(
    '../Output_Data_CSV/Combination_with_Input_Data/ID_Type_Dwellings.csv',
    sep=';',
    index=None,
    header=True,
    encoding='utf-8')

df_ID_UF.to_csv(
    '../Output_Data_CSV/Combination_with_Input_Data/ID_Type_Dwellings_with_U_Factors.csv',
    sep=';',
    index=None,
    header=True,
    encoding='utf-8')

df_ID_UP.to_csv(
    '../Output_Data_CSV/Combination_with_Input_Data/ID_Type_Dwellings_with_U_Prices.csv',
    sep=';',
    index=None,
    header=True,
    encoding='utf-8')

# %% [markdown]
# # Creation of some calculable columns
#
# ## Class for all types of dwellings

# %%
class Calculable_Columns:
    def __init__(self, df, year):
        self.df = df
        self.year = year

    def Rename_Columns(self):
        self.df.columns = self.df.columns.str.replace(' ', '_')
        return self.df

    def Carbon_Tax(self):
        self.Rename_Columns()
        self.df['Carbon_Tax'] = np.multiply(self.df.Emission_Factor,
                                            self.df.Carbon_Price)
        return self.df

    def Total_Prices(self):
        self.Carbon_Tax()
        self.df['Total_Prices'] = 0
        for i in range(self.year, 40 + self.year):
            self.df['Total_Prices'] = np.add(
                np.divide(
                    np.add(
                        np.multiply(
                            self.df.Energy_Price,
                            np.power(np.add(1, self.df.Annual_Variation), i)),
                        self.df.Carbon_Tax),
                    np.power(np.add(1, self.df.Discount_Rate), i)),
                self.df.Total_Prices)
        return self.df

    def Inflation_Rate_19(self):
        self.Rename_Columns()
        self.df['Inflation_Rate_19'] = np.power(
            np.add(1, self.df.Inflation_Rate), np.add(19, self.year))
        return self.df

    def Inflation_Rate_39(self):
        self.Rename_Columns()
        self.df['Inflation_Rate_39'] = np.power(
            np.add(1, self.df.Inflation_Rate), np.add(39, self.year))
        return self.df

    def Discount_19(self):
        self.Rename_Columns()
        self.df['Discount_19'] = np.power(np.add(1, self.df.Discount_Rate),
                                          np.add(19, self.df.Initial_Age))
        return self.df

    def Discount_39(self):
        self.Rename_Columns()
        self.df['Discount_39'] = np.power(np.add(1, self.df.Discount_Rate),
                                          np.add(39, self.df.Initial_Age))
        return self.df

    def Fraction_19_39(self):
        self.Inflation_Rate_19()
        self.Inflation_Rate_39()
        self.Discount_19()
        self.Discount_39()
        self.df['Fraction_19_39'] = np.divide(
            np.add(np.multiply(self.df.Inflation_Rate_19, self.df.Discount_39),
                   np.multiply(self.df.Inflation_Rate_39,
                               self.df.Discount_19)),
            np.multiply(self.df.Discount_19, self.df.Discount_39))
        return self.df

    def GHC_Total_Prices_19_39(self):
        self.Total_Prices()
        self.Fraction_19_39()
        self.df['GHC_Total_Prices_19_39'] = np.add(
            np.multiply(self.df.B_Investment, self.df.Fraction_19_39),
            np.divide(self.df.Total_Prices, self.df.Efficiency))
        return self.df

    def Discount_20(self):
        self.Rename_Columns()
        self.df['Discount_20'] = np.power(np.add(1, self.df.Discount_Rate), 20)
        return self.df

    def Inflation_Rate_0(self):
        self.Rename_Columns()
        self.df['Inflation_Rate_0'] = np.power(
            np.add(1, self.df.Inflation_Rate), self.year)
        return self.df

    def Inflation_Rate_20(self):
        self.Rename_Columns()
        self.df['Inflation_Rate_20'] = np.power(
            np.add(1, self.df.Inflation_Rate), np.add(20, self.year))
        return self.df

    def Fraction_0_20(self):
        self.Inflation_Rate_0()
        self.Inflation_Rate_20()
        self.Discount_20()
        self.df['Fraction_0_20'] = np.divide(
            np.add(np.multiply(self.df.Discount_20, self.df.Inflation_Rate_0),
                   self.df.Inflation_Rate_20), self.df.Discount_20)
        return self.df

    def GHC_Total_Prices_0_20(self):
        self.Total_Prices()
        self.Fraction_0_20()
        self.df['GHC_Total_Prices_0_20'] = np.add(
            np.multiply(self.df.B_Investment, self.df.Fraction_0_20),
            np.divide(self.df.Total_Prices, self.df.Efficiency))
        return self.df

    def No_Gas_Prices(self):
        self.Carbon_Tax()
        self.df['No_Gas_Prices'] = 0
        for i in range(self.year, 40 + self.year):
            self.df['No_Gas_Prices'] = np.add(
                np.divide(
                    np.add(
                        np.multiply(
                            self.df.Specific_Gas_Price,
                            np.power(np.add(1, self.df.Annual_Variation), i)),
                        self.df.Carbon_Tax),
                    np.power(np.add(1, self.df.Discount_Rate), i),
                ), self.df.No_Gas_Prices)
        return self.df

    def GHC_No_Gas_Prices(self):
        self.No_Gas_Prices()
        self.Fraction_0_20()
        self.df['GHC_No_Gas_Prices'] = np.add(
            np.multiply(self.df.B_Investment, self.df.Fraction_0_20),
            np.divide(self.df.No_Gas_Prices, self.df.Efficiency))
        return self.df

    def Maintenance(self):
        self.Rename_Columns()
        self.df['Maintenance'] = 0
        for i in range(self.year, 40 + self.year):
            self.df['Maintenance'] = np.add(
                np.divide(
                    np.multiply(self.df.Maintenance_Cost,
                                np.power(np.add(1, self.df.Inflation_Rate),
                                         i)),
                    np.power(np.add(1, self.df.Discount_Rate), i)),
                self.df.Maintenance)
        return self.df

    def Maintenance_19_39(self):
        self.Maintenance()
        self.Fraction_19_39()
        self.df['Maintenance_19_39'] = np.add(
            np.multiply(self.df.A_Investment, self.df.Fraction_19_39),
            self.df.Maintenance)
        return self.df

    def Maintenance_Same(self):
        self.Maintenance()
        self.Fraction_0_20()
        self.df['Maintenance_Same'] = np.add(
            np.multiply(self.df.A_Investment, self.df.Fraction_0_20),
            np.add(self.df.Maintenance, self.df.Same_Switch_Cost))
        return self.df

    def Maintenance_Different(self):
        self.Maintenance()
        self.Fraction_0_20()
        self.df['Maintenance_Different'] = np.add(
            np.multiply(self.df.A_Investment, self.df.Fraction_0_20),
            np.add(self.df.Maintenance, self.df.Different_Switch_Cost))
        return self.df

    def Control_Cost(self):
        self.Rename_Columns()
        self.df['Control_Cost'] = np.multiply(self.df.Delevery_Type_Cost,
                                              self.df.Surface)
        return self.df

    def Maintenance_Same_Plus(self):
        self.Maintenance_Same()
        self.Control_Cost()
        self.df['Maintenance_Same_Plus'] = np.add(self.df.Maintenance_Same,
                                                  self.df.Control_Cost)
        return self.df

    def Maintenance_Different_Plus(self):
        self.Maintenance_Different()
        self.Control_Cost()
        self.df['Maintenance_Different_Plus'] = np.add(
            self.df.Maintenance_Different, self.df.Control_Cost)
        return self.df

# %% [markdown]
# ## Class for the collective dwellings

# %%
class Calculable_Columns_for_CxD(Calculable_Columns):
    def init(self, df, year):
        super().init(df)

    def Surface_M(self):
        self.Rename_Columns()
        self.df['Surface_M'] = np.multiply(
            np.multiply(
                np.multiply(
                    np.subtract(1, self.df.Share_of_Windows),
                    np.sqrt(
                        np.multiply(self.df.Surface,
                                    self.df.Dwelling_per_Floor))), 4),
            np.multiply(self.df.Ceiling_Height, np.add(self.df.Floors, 1)))
        return self.df

    def Surface_W(self):
        self.Rename_Columns()
        self.df['Surface_W'] = np.multiply(
            np.multiply(
                np.multiply(
                    self.df.Share_of_Windows,
                    np.sqrt(
                        np.multiply(self.df.Surface,
                                    self.df.Dwelling_per_Floor))), 4),
            np.multiply(self.df.Ceiling_Height, np.add(self.df.Floors, 1)))
        return self.df

# %% [markdown]
# ### Class for the DataFrame with U Factors

# %%
class Columns_for_CxD_U_Factors(Calculable_Columns_for_CxD):
    def init(self, df):
        super().init(df)

    def Surface_R(self):
        self.Rename_Columns()
        self.df['Surface_R'] = np.multiply(self.df.Surface,
                                           self.df.Dwelling_per_Floor)
        return self.df

    def Heightened_Surface_Habitable(self):
        self.Surface_R()
        self.df['Heightened_Surface_Habitable'] = np.multiply(
            np.multiply(self.df.Surface_R, np.add(self.df.Floors, 1)),
            self.df.Ceiling_Height)
        return self.df

    def UEN_per_Dwelling_2(self):
        self.Rename_Columns()
        self.df['UEN_per_Dwelling_2'] = np.multiply(
            np.multiply(
                np.multiply(self.df.Ceiling_Height, self.df.Intermittence),
                np.multiply(self.df.Degrees_of_Reference, self.df.Surface)),
            0.01)
        return self.df

    def Weighted_Surface(self):
        self.Surface_M()
        self.Surface_W()
        self.Surface_R()
        self.df.loc[:, 'Um0':'Um18'] = self.df.loc[:, 'Um0':'Um18'].apply(
            lambda x: np.multiply(x, self.df.Surface_M))
        self.df.loc[:, 'Uw0':'Uw3'] = self.df.loc[:, 'Uw0':'Uw3'].apply(
            lambda x: np.multiply(x, self.df.Surface_W))
        self.df.loc[:, 'Ur0':'Ur3'] = self.df.loc[:, 'Ur0':'Ur3'].apply(
            lambda x: np.multiply(x, self.df.Surface_R))
        self.df.loc[:, 'Uf0':'Uf5'] = self.df.loc[:, 'Uf0':'Uf5'].apply(
            lambda x: np.multiply(x, self.df.Surface_R))
        return self.df

    def Duo_Weighted_Surface(self):
        self.Weighted_Surface()
        columns_list = []
        columns_list_1 = []
        columns_list_2 = []
        for m in range(19):
            for w in range(4):
                column_name = 'U_m' + str(m) + '_w' + str(w)
                columns_list_1.append(column_name)
        for r in range(4):
            for f in range(6):
                column_name = 'U_r' + str(r) + '_f' + str(f)
                columns_list_2.append(column_name)
        columns_list = columns_list_1 + columns_list_2
        self.df = pd.concat([
            self.df,
            pd.DataFrame(0, index=self.df.index, columns=columns_list)
        ],
                            axis=1)
        self.df[columns_list_1] = self.df[columns_list_1].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        self.df[columns_list_2] = self.df[columns_list_2].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        selected_columns = self.df.loc[:, 'Um0':'Uf5'].columns.tolist()
        self.df = self.df.drop(selected_columns, axis=1)
        return self.df

    def Add_Created_Columns(self):
        self.Heightened_Surface_Habitable()
        self.UEN_per_Dwelling_2()
        self.Duo_Weighted_Surface()
        self.GHC_Total_Prices_19_39()
        self.GHC_Total_Prices_0_20()
        self.GHC_No_Gas_Prices()
        return self.df

# %% [markdown]
# ### Class for the DataFrame with U Prices

# %%
class Columns_for_CxD_U_Prices(Calculable_Columns_for_CxD):
    def init(self, df):
        super().init(df)

    def Dwelling_Total(self):
        self.Rename_Columns()
        self.df['Dwelling_Total'] = np.multiply(self.df.Dwelling_per_Floor,
                                                np.add(self.df.Floors, 1))
        return self.df

    def Priced_Surface(self):
        self.Surface_M()
        self.Surface_W()
        self.Dwelling_Total()
        self.df.loc[:, 'Um0':'Um18'] = self.df.loc[:, 'Um0':'Um18'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface_M, self.df.Dwelling_Total)))
        self.df.loc[:, 'Uw0':'Uw3'] = self.df.loc[:, 'Uw0':'Uw3'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface_W, self.df.Dwelling_Total)))
        self.df.loc[:, 'Ur0':'Ur3'] = self.df.loc[:, 'Ur0':'Ur3'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface, np.add(self.df.Floors, 1))))
        self.df.loc[:, 'Uf0':'Uf5'] = self.df.loc[:, 'Uf0':'Uf5'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface, np.add(self.df.Floors, 1))))
        return self.df

    def Duo_Priced_Surface(self):
        self.Priced_Surface()
        columns_list = []
        columns_list_1 = []
        columns_list_2 = []
        for m in range(19):
            for w in range(4):
                column_name = 'U_m' + str(m) + '_w' + str(w)
                columns_list_1.append(column_name)
        for r in range(4):
            for f in range(6):
                column_name = 'U_r' + str(r) + '_f' + str(f)
                columns_list_2.append(column_name)
        columns_list = columns_list_1 + columns_list_2
        self.df = pd.concat([
            self.df,
            pd.DataFrame(0, index=self.df.index, columns=columns_list)
        ],
                            axis=1)
        self.df[columns_list_1] = self.df[columns_list_1].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        self.df[columns_list_2] = self.df[columns_list_2].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        selected_columns = self.df.loc[:, 'Um0':'Uf5'].columns.tolist()
        self.df = self.df.drop(selected_columns, axis=1)
        return self.df

    def Add_Created_Columns(self):
        self.Duo_Priced_Surface()
        self.Maintenance_19_39()
        self.Maintenance_Same_Plus()
        self.Maintenance_Different_Plus()
        return self.df

# %% [markdown]
# ## Class for the individual dwellings

# %%
class Calculable_Columns_for_ID(Calculable_Columns):
    def init(self, df, year):
        super().init(df)

    def Surface_M(self):
        self.Rename_Columns()
        self.df['Surface_M'] = np.multiply(
            np.multiply(
                np.multiply(
                    np.subtract(1, self.df.Share_of_Windows),
                    np.sqrt(
                        np.divide(self.df.Surface, np.add(self.df.Floors,
                                                          1)))), 4),
            np.multiply(self.df.Ceiling_Height, np.add(self.df.Floors, 1)))
        return self.df

    def Surface_W(self):
        self.Rename_Columns()
        self.df['Surface_W'] = np.multiply(
            np.multiply(
                np.multiply(
                    self.df.Share_of_Windows,
                    np.sqrt(
                        np.divide(self.df.Surface, np.add(self.df.Floors,
                                                          1)))), 4),
            np.multiply(self.df.Ceiling_Height, np.add(self.df.Floors, 1)))
        return self.df

# %% [markdown]
# ### Class for the DataFrame with U Factors

# %%
class Columns_for_ID_U_Factors(Calculable_Columns_for_ID):
    def init(self, df):
        super().init(df)

    def Surface_R(self):
        self.Rename_Columns()
        self.df['Surface_R'] = np.divide(self.df.Surface,
                                         np.add(self.df.Floors, 1))
        return self.df

    def Heightened_Surface_Habitable(self):
        self.Surface_R()
        self.df['Heightened_Surface_Habitable'] = np.multiply(
            self.df.Surface, self.df.Ceiling_Height)
        return self.df

    def UEN_per_Dwelling_2(self):
        self.Rename_Columns()
        self.df['UEN_per_Dwelling_2'] = np.multiply(
            np.multiply(
                np.multiply(self.df.Ceiling_Height, self.df.Intermittence),
                np.multiply(self.df.Degrees_of_Reference, self.df.Surface)),
            0.01)
        return self.df

    def Weighted_Surface(self):
        self.Surface_M()
        self.Surface_W()
        self.Surface_R()
        self.df.loc[:, 'Um0':'Um19'] = self.df.loc[:, 'Um0':'Um19'].apply(
            lambda x: np.multiply(x, self.df.Surface_M))
        self.df.loc[:, 'Uw0':'Uw3'] = self.df.loc[:, 'Uw0':'Uw3'].apply(
            lambda x: np.multiply(x, self.df.Surface_W))
        self.df.loc[:, 'Ur0':'Ur7'] = self.df.loc[:, 'Ur0':'Ur7'].apply(
            lambda x: np.multiply(x, self.df.Surface_R))
        self.df.loc[:, 'Uf0':'Uf3'] = self.df.loc[:, 'Uf0':'Uf3'].apply(
            lambda x: np.multiply(x, self.df.Surface_R))
        return self.df

    def Duo_Weighted_Surface(self):
        self.Weighted_Surface()
        columns_list = []
        columns_list_1 = []
        columns_list_2 = []
        for m in range(20):
            for w in range(4):
                column_name = 'U_m' + str(m) + '_w' + str(w)
                columns_list_1.append(column_name)
        for r in range(8):
            for f in range(4):
                column_name = 'U_r' + str(r) + '_f' + str(f)
                columns_list_2.append(column_name)
        columns_list = columns_list_1 + columns_list_2
        self.df = pd.concat([
            self.df,
            pd.DataFrame(0, index=self.df.index, columns=columns_list)
        ],
                            axis=1)
        self.df[columns_list_1] = self.df[columns_list_1].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        self.df[columns_list_2] = self.df[columns_list_2].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        selected_columns = self.df.loc[:, 'Um0':'Uf3'].columns.tolist()
        self.df = self.df.drop(selected_columns, axis=1)
        return self.df

    def Add_Created_Columns(self):
        self.Heightened_Surface_Habitable()
        self.UEN_per_Dwelling_2()
        self.Duo_Weighted_Surface()
        self.GHC_Total_Prices_19_39()
        self.GHC_Total_Prices_0_20()
        self.GHC_No_Gas_Prices()
        return self.df

# %% [markdown]
# ### Class for the DataFrame with U Prices

# %%
class Columns_for_ID_U_Prices(Calculable_Columns_for_ID):
    def init(self, df):
        super().init(df)

    def Dwelling_Total(self):
        self.Rename_Columns()
        self.df['Dwelling_Total'] = 1
        return self.df

    def Priced_Surface(self):
        self.Surface_M()
        self.Surface_W()
        self.Dwelling_Total()
        self.df.loc[:, 'Um0':'Um19'] = self.df.loc[:, 'Um0':'Um19'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface_M, self.df.Dwelling_Total)))
        self.df.loc[:, 'Uw0':'Uw3'] = self.df.loc[:, 'Uw0':'Uw3'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface_W, self.df.Dwelling_Total)))
        self.df.loc[:, 'Ur0':'Ur7'] = self.df.loc[:, 'Ur0':'Ur7'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface, np.add(self.df.Floors, 1))))
        self.df.loc[:, 'Uf0':'Uf3'] = self.df.loc[:, 'Uf0':'Uf3'].apply(
            lambda x: np.multiply(
                x, np.divide(self.df.Surface, np.add(self.df.Floors, 1))))
        return self.df

    def Duo_Priced_Surface(self):
        self.Priced_Surface()
        columns_list = []
        columns_list_1 = []
        columns_list_2 = []
        for m in range(20):
            for w in range(4):
                column_name = 'U_m' + str(m) + '_w' + str(w)
                columns_list_1.append(column_name)
        for r in range(8):
            for f in range(4):
                column_name = 'U_r' + str(r) + '_f' + str(f)
                columns_list_2.append(column_name)
        columns_list = columns_list_1 + columns_list_2
        self.df = pd.concat([
            self.df,
            pd.DataFrame(0, index=self.df.index, columns=columns_list)
        ],
                            axis=1)
        self.df[columns_list_1] = self.df[columns_list_1].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        self.df[columns_list_2] = self.df[columns_list_2].apply(
            lambda x: np.add(self.df['U' + x.name.split('_')[1]], self.df[
                'U' + x.name.split('_')[2]]))
        selected_columns = self.df.loc[:, 'Um0':'Uf3'].columns.tolist()
        self.df = self.df.drop(selected_columns, axis=1)
        return self.df

    def Add_Created_Columns(self):
        self.Duo_Priced_Surface()
        self.Maintenance_19_39()
        self.Maintenance_Same_Plus()
        self.Maintenance_Different_Plus()
        return self.df

# %% [markdown]
# ## Class instantiation for each type of dwelling

# %%
Instance_df_CID_UF = Columns_for_CxD_U_Factors(df_CID_UF, 0)

Prepared_df_CID_UF = Instance_df_CID_UF.Add_Created_Columns()

Prepared_df_CID_UF.shape
# Out:
# (11340, 149)

# %%
Prepared_df_CID_UF.U_m0_w0
# Out:
# 0        2297.22240
# 1        2297.22240
# 2        2297.22240
# 3        2297.22240
# 4        2297.22240
# 5        2297.22240
# 6        2297.22240
# 7        2297.22240
# 8        2297.22240
# 9        2297.22240
# 10       2297.22240
# 11       2297.22240
# 12       2297.22240
# 13       2297.22240
# 14       2297.22240
# 15       2297.22240
# 16       2297.22240
# 17       2297.22240
# 18       2297.22240
# 19       2297.22240
# 20       2297.22240
# 21       2297.22240
# 22       2297.22240
# 23       2297.22240
# 24       2297.22240
# 25       2297.22240
# 26       2297.22240
# 27       2297.22240
# 28       2297.22240
# 29       2297.22240
#             ...
# 11310     829.49033
# 11311     829.49033
# 11312     829.49033
# 11313     829.49033
# 11314     829.49033
# 11315     829.49033
# 11316     829.49033
# 11317     829.49033
# 11318     829.49033
# 11319     829.49033
# 11320     829.49033
# 11321     829.49033
# 11322     829.49033
# 11323     829.49033
# 11324     829.49033
# 11325     829.49033
# 11326     829.49033
# 11327     829.49033
# 11328     829.49033
# 11329     829.49033
# 11330     829.49033
# 11331     829.49033
# 11332     829.49033
# 11333     829.49033
# 11334     829.49033
# 11335     829.49033
# 11336     829.49033
# 11337     829.49033
# 11338     829.49033
# 11339     829.49033
# Name: U_m0_w0, Length: 11340, dtype: float64

# %%
Prepared_df_CID_UF.U_r0_f0
# Out:
# 0        447.70
# 1        447.70
# 2        447.70
# 3        447.70
# 4        447.70
# 5        447.70
# 6        447.70
# 7        447.70
# 8        447.70
# 9        447.70
# 10       447.70
# 11       447.70
# 12       447.70
# 13       447.70
# 14       447.70
# 15       447.70
# 16       447.70
# 17       447.70
# 18       447.70
# 19       447.70
# 20       447.70
# 21       447.70
# 22       447.70
# 23       447.70
# 24       447.70
# 25       447.70
# 26       447.70
# 27       447.70
# 28       447.70
# 29       447.70
#           ...
# 11310     78.96
# 11311     78.96
# 11312     78.96
# 11313     78.96
# 11314     78.96
# 11315     78.96
# 11316     78.96
# 11317     78.96
# 11318     78.96
# 11319     78.96
# 11320     78.96
# 11321     78.96
# 11322     78.96
# 11323     78.96
# 11324     78.96
# 11325     78.96
# 11326     78.96
# 11327     78.96
# 11328     78.96
# 11329     78.96
# 11330     78.96
# 11331     78.96
# 11332     78.96
# 11333     78.96
# 11334     78.96
# 11335     78.96
# 11336     78.96
# 11337     78.96
# 11338     78.96
# 11339     78.96
# Name: U_r0_f0, Length: 11340, dtype: float64

# %%
Prepared_df_CID_UF.Heightened_Surface_Habitable
# Out:
# 0        2163.48
# 1        2163.48
# 2        2163.48
# 3        2163.48
# 4        2163.48
# 5        2163.48
# 6        2163.48
# 7        2163.48
# 8        2163.48
# 9        2163.48
# 10       2163.48
# 11       2163.48
# 12       2163.48
# 13       2163.48
# 14       2163.48
# 15       2163.48
# 16       2163.48
# 17       2163.48
# 18       2163.48
# 19       2163.48
# 20       2163.48
# 21       2163.48
# 22       2163.48
# 23       2163.48
# 24       2163.48
# 25       2163.48
# 26       2163.48
# 27       2163.48
# 28       2163.48
# 29       2163.48
#           ...
# 11310    3421.60
# 11311    3421.60
# 11312    3421.60
# 11313    3421.60
# 11314    3421.60
# 11315    3421.60
# 11316    3421.60
# 11317    3421.60
# 11318    3421.60
# 11319    3421.60
# 11320    3421.60
# 11321    3421.60
# 11322    3421.60
# 11323    3421.60
# 11324    3421.60
# 11325    3421.60
# 11326    3421.60
# 11327    3421.60
# 11328    3421.60
# 11329    3421.60
# 11330    3421.60
# 11331    3421.60
# 11332    3421.60
# 11333    3421.60
# 11334    3421.60
# 11335    3421.60
# 11336    3421.60
# 11337    3421.60
# 11338    3421.60
# 11339    3421.60
# Name: Heightened_Surface_Habitable, Length: 11340, dtype: float64

# %%
Instance_df_CID_UP = Columns_for_CxD_U_Prices(df_CID_UP, 0)

Prepared_df_CID_UP = Instance_df_CID_UP.Add_Created_Columns()

Prepared_df_CID_UP.shape
# Out:
# (11340, 148)

# %%
Instance_df_CCD_UF = Columns_for_CxD_U_Factors(df_CCD_UF, 0)

Prepared_df_CCD_UF = Instance_df_CCD_UF.Add_Created_Columns()

Prepared_df_CCD_UF.shape
# Out:
# (10080, 149)

# %%
Instance_df_CCD_UP = Columns_for_CxD_U_Prices(df_CCD_UP, 0)

Prepared_df_CCD_UP = Instance_df_CCD_UP.Add_Created_Columns()

Prepared_df_CCD_UP.shape
# Out:
# (10080, 148)

# %%
Instance_df_ID_UF = Columns_for_ID_U_Factors(df_ID_UF, 0)

Prepared_df_ID_UF = Instance_df_ID_UF.Add_Created_Columns()

Prepared_df_ID_UF.shape
# Out:
# (11340, 161)

# %%
Instance_df_ID_UP = Columns_for_ID_U_Prices(df_ID_UF, 0)

Prepared_df_ID_UP = Instance_df_ID_UP.Add_Created_Columns()

Prepared_df_ID_UP.shape
# Out:
# (11340, 163)

# %% [markdown]
# # Creation of some calculable DataFrames
#
# ## Class for all types of dwellings

# %%
class Calculable_DFs:
    def __init__(self, df):
        self.df = df

# %% [markdown]
# ## Class for the CID type dwellings

# %%
class Calculable_DFs_for_CD(Calculable_DFs):
    def init(self, df):
        super().init(df)

    def Add_ER_Columns(self):
        columns_list = []
        for m in range(19):
            for w in range(4):
                for r in range(4):
                    for f in range(6):
                        column_name = 'ER_m' + str(m) + '_w' + str(
                            w) + '_r' + str(r) + '_f' + str(f)
                        columns_list.append(column_name)
        self.df = pd.concat([
            self.df,
            pd.DataFrame(0, index=self.df.index, columns=columns_list)
        ],
                            axis=1)
        return self.df

    def Fill_ER_Columns(self):
        self.Add_ER_Columns()
        selected_columns = self.df.loc[:, 'ER_m0_w0_r0_f0':
                                       'ER_m18_w3_r3_f5'].columns.tolist()
        self.df[selected_columns] = self.df[selected_columns].apply(
            lambda x: np.add(
                self.df['U_' + x.name.split('_')[1] + '_' + x.name.split('_')[
                    2]], self.df['U_' + x.name.split('_')[3] + '_' + x.name.
                                 split('_')[4]]))
        selected_columns = self.df.loc[:, 'U_m0_w0':'U_r3_f5'].columns.tolist()
        self.df = self.df.drop(selected_columns, axis=1)
        return self.df

    def Generate_GB_Columns(self):
        self.Generate_ER_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'GB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_CGB_Columns(self):
        self.Generate_GB_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'CGB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_OB_Columns(self):
        self.Generate_CGB_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'OB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_COB_Columns(self):
        self.Generate_OB_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'COB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_EHP2_Columns(self):
        self.Generate_COB_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'EHP2_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_WB_Columns(self):
        self.Generate_EHP2_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'WB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_WPB_Columns(self):
        self.Generate_WB_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'WPB_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

    def Generate_EHP_Columns(self):
        self.Generate_WPB_Columns()
        duplicate_df = self.df.loc[:, 'ER_m0_w0_r0_f0':'ER_m18_w3_r3_f5']
        duplicate_df.columns = duplicate_df.columns.str.replace('ER_', 'EHP_')
        self.df = pd.concat([self.df, duplicate_df], axis=1)
        del duplicate_df
        return self.df

# %% [markdown]
# ### Class for the DataFrame with U Factors

# %%
class DF_for_CD_U_Factors(Calculable_DFs_for_CD):
    def init(self, df):
        super().init(df)

    def Weighted_Surface_Total(self):
        self.Fill_ER_Columns()
        return self.df

    def Enlarged_Weighted_Surface_Total(self):
        self.Weighted_Surface_Total()
        selected_columns = self.df.loc[:, 'ER_m0_w0_r0_f0':
                                       'ER_m18_w3_r3_f5'].columns.tolist()
        self.copied_df = self.df[selected_columns].copy()
        self.copied_df = self.copied_df.apply(lambda x: np.add(
            np.multiply(9, self.df.Heightened_Surface_Habitable),
            np.multiply(2.5, x)))
        return self.copied_df

    def UEN_per_Dwelling_1(self):
        self.Enlarged_Weighted_Surface_Total()
        selected_columns = self.df.loc[:, 'ER_m0_w0_r0_f0':
                                       'ER_m18_w3_r3_f5'].columns.tolist()
        self.df[selected_columns] = self.df[selected_columns].div(
            self.copied_df)
        del self.copied_df
        return self.df

    def UEN_per_Dwelling(self):
        self.UEN_per_Dwelling_1()
        selected_columns = self.df.loc[:, 'ER_m0_w0_r0_f0':
                                       'ER_m18_w3_r3_f5'].columns.tolist()
        self.df[selected_columns] = self.df[selected_columns].apply(
            lambda x: np.multiply(x, self.df.UEN_per_Dwelling_2))
        return self.df

    def Generate_ER_Columns(self):
        self.UEN_per_Dwelling()
        return self.df

    def GHC_UEN_ER(self):
        self.Generate_EHP_Columns()
        selected_columns = self.df.loc[:, 'ER_m0_w0_r0_f0':
                                       'ER_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'ER'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        A = np.array(self.df.loc[:, 'GHC_Total_Prices_19_39']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'GHC_Total_Prices_0_20']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1,
            A))  + np.multiply(matrix, np.multiply(condition_2, B))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, A, B, matrix, df_matrix
        return self.df

    def GHC_UEN_GB(self):
        self.GHC_UEN_ER()
        selected_columns = self.df.loc[:, 'GB_m0_w0_r0_f0':
                                       'GB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'GB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WB') | (
                        self.df.Heating_System == 'WPB') | (
                            self.df.Heating_System == 'EHP')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'OB') | (
            self.df.Heating_System == 'COB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        A = np.array(self.df.loc[:, 'GHC_Total_Prices_19_39']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'GHC_Total_Prices_0_20']).reshape(
            self.df.shape[0], 1)
        C = np.array(self.df.loc[:, 'GHC_No_Gas_Prices']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(
            matrix, np.multiply(condition_1, A)) + np.multiply(
                matrix, np.multiply(condition_2, B)) + np.multiply(
                    matrix, np.multiply(condition_3, C))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_matrix
        return self.df

    def GHC_UEN_CGB(self):
        self.GHC_UEN_GB()
        selected_columns = self.df.loc[:, 'CGB_m0_w0_r0_f0':
                                       'CGB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'CGB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'GB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WB') | (
                        self.df.Heating_System == 'WPB') | (
                            self.df.Heating_System == 'EHP')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'OB') | (
            self.df.Heating_System == 'COB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        A = np.array(self.df.loc[:, 'GHC_Total_Prices_19_39']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'GHC_Total_Prices_0_20']).reshape(
            self.df.shape[0], 1)
        C = np.array(self.df.loc[:, 'GHC_No_Gas_Prices']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(
            matrix, np.multiply(condition_1, A)) + np.multiply(
                matrix, np.multiply(condition_2, B)) + np.multiply(
                    matrix, np.multiply(condition_3, C))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_matrix
        return self.df

    def GHC_UEN_OB(self):
        self.GHC_UEN_CGB()
        selected_columns = self.df.loc[:, 'OB_m0_w0_r0_f0':
                                       'OB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'OB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        A = np.array(self.df.loc[:, 'GHC_Total_Prices_19_39']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'GHC_Total_Prices_0_20']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, A, B, matrix, df_matrix
        return self.df

    def GHC_UEN_COB(self):
        self.GHC_UEN_OB()
        selected_columns = self.df.loc[:, 'COB_m0_w0_r0_f0':
                                       'COB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'COB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        A = np.array(self.df.loc[:, 'GHC_Total_Prices_19_39']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'GHC_Total_Prices_0_20']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, A, B, matrix, df_matrix
        return self.df

    def GHC_UEN_EHP2(self):
        self.GHC_UEN_COB()
        selected_columns = self.df.loc[:, 'EHP2_m0_w0_r0_f0':
                                       'EHP2_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'EHP2'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        A = np.array(self.df.loc[:, 'GHC_Total_Prices_19_39']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'GHC_Total_Prices_0_20']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, A, B, matrix, df_matrix
        return self.df

    def GHC_UEN_WB(self):
        self.GHC_UEN_EHP2()
        selected_columns = self.df.loc[:, 'WB_m0_w0_r0_f0':
                                       'WB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'WB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        A = np.array(self.df.loc[:, 'GHC_Total_Prices_19_39']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'GHC_Total_Prices_0_20']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, A, B, matrix, df_matrix
        return self.df

    def GHC_UEN_WPB(self):
        self.GHC_UEN_WB()
        selected_columns = self.df.loc[:, 'WPB_m0_w0_r0_f0':
                                       'WPB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'WPB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        A = np.array(self.df.loc[:, 'GHC_Total_Prices_19_39']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'GHC_Total_Prices_0_20']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, A, B, matrix, df_matrix
        return self.df

    def GHC_UEN_EHP(self):
        self.GHC_UEN_WPB()
        selected_columns = self.df.loc[:, 'EHP_m0_w0_r0_f0':
                                       'EHP_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'EHP'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = ~condition_1
        A = np.array(self.df.loc[:, 'GHC_Total_Prices_19_39']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'GHC_Total_Prices_0_20']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.multiply(matrix, np.multiply(
            condition_1, A)) + np.multiply(matrix, np.multiply(condition_2, B))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, A, B, matrix, df_matrix
        return self.df

# %% [markdown]
# ### Class for the DataFrame with U Prices

# %%
class DF_for_CD_U_Prices(Calculable_DFs_for_CD):
    def init(self, df):
        super().init(df)

    def Insulation_Cost(self):
        self.Fill_ER_Columns()
        return self.df

    def Generate_ER_Columns(self):
        self.Insulation_Cost()
        return self.df

    def Multiple_Cost_ER(self):
        self.Generate_EHP_Columns()
        selected_columns = self.df.loc[:, 'ER_m0_w0_r0_f0':
                                       'ER_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'ER'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'WB') | (
            self.df.Heating_System == 'EHP')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'OB') | (
                    self.df.Heating_System == 'COB') | (
                        self.df.Heating_System == 'EHP2') | (
                            self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        A = np.array(self.df.loc[:, 'Maintenance_19_39']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'Maintenance_Same']).reshape(
            self.df.shape[0], 1)
        C = np.array(self.df.loc[:, 'Maintenance_Different_Plus']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.add(matrix, np.multiply(condition_1, A)) + np.add(
            matrix, np.multiply(condition_2, B)) + np.add(
                matrix, np.multiply(condition_3, C))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_matrix
        return self.df

    def Multiple_Cost_GB(self):
        self.Multiple_Cost_ER()
        selected_columns = self.df.loc[:, 'GB_m0_w0_r0_f0':
                                       'GB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'GB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'CGB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'OB') | (
            self.df.Heating_System == 'COB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'WB') | (self.df.Heating_System == 'EHP')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        A = np.array(self.df.loc[:, 'Maintenance_19_39']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'Maintenance_Same']).reshape(
            self.df.shape[0], 1)
        C = np.array(self.df.loc[:, 'Maintenance_Different']).reshape(
            self.df.shape[0], 1)
        D = np.array(self.df.loc[:, 'Maintenance_Different_Plus']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.add(matrix, np.multiply(condition_1, A)) + np.add(
            matrix, np.multiply(condition_2, B)) + np.add(
                matrix, np.multiply(condition_3, C)) + np.add(
                    matrix, np.multiply(condition_4, D))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_matrix
        return self.df

    def Multiple_Cost_CGB(self):
        self.Multiple_Cost_GB()
        selected_columns = self.df.loc[:, 'CGB_m0_w0_r0_f0':
                                       'CGB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'CGB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'GB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'OB') | (
            self.df.Heating_System == 'COB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'WB') | (self.df.Heating_System == 'EHP')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        A = np.array(self.df.loc[:, 'Maintenance_19_39']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'Maintenance_Same']).reshape(
            self.df.shape[0], 1)
        C = np.array(self.df.loc[:, 'Maintenance_Different']).reshape(
            self.df.shape[0], 1)
        D = np.array(self.df.loc[:, 'Maintenance_Different_Plus']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.add(matrix, np.multiply(condition_1, A)) + np.add(
            matrix, np.multiply(condition_2, B)) + np.add(
                matrix, np.multiply(condition_3, C)) + np.add(
                    matrix, np.multiply(condition_4, D))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_matrix
        return self.df

    def Multiple_Cost_OB(self):
        self.Multiple_Cost_CGB()
        selected_columns = self.df.loc[:, 'OB_m0_w0_r0_f0':
                                       'OB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'OB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'COB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'WB') | (self.df.Heating_System == 'EHP')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        A = np.array(self.df.loc[:, 'Maintenance_19_39']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'Maintenance_Same']).reshape(
            self.df.shape[0], 1)
        C = np.array(self.df.loc[:, 'Maintenance_Different']).reshape(
            self.df.shape[0], 1)
        D = np.array(self.df.loc[:, 'Maintenance_Different_Plus']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.add(matrix, np.multiply(condition_1, A)) + np.add(
            matrix, np.multiply(condition_2, B)) + np.add(
                matrix, np.multiply(condition_3, C)) + np.add(
                    matrix, np.multiply(condition_4, D))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_matrix
        return self.df

    def Multiple_Cost_COB(self):
        self.Multiple_Cost_OB()
        selected_columns = self.df.loc[:, 'COB_m0_w0_r0_f0':
                                       'COB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'COB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'OB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'EHP2') | (
                    self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'WB') | (self.df.Heating_System == 'EHP')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        A = np.array(self.df.loc[:, 'Maintenance_19_39']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'Maintenance_Same']).reshape(
            self.df.shape[0], 1)
        C = np.array(self.df.loc[:, 'Maintenance_Different']).reshape(
            self.df.shape[0], 1)
        D = np.array(self.df.loc[:, 'Maintenance_Different_Plus']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.add(matrix, np.multiply(condition_1, A)) + np.add(
            matrix, np.multiply(condition_2, B)) + np.add(
                matrix, np.multiply(condition_3, C)) + np.add(
                    matrix, np.multiply(condition_4, D))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_matrix
        return self.df

    def Multiple_Cost_EHP2(self):
        self.Multiple_Cost_COB()
        selected_columns = self.df.loc[:, 'EHP2_m0_w0_r0_f0':
                                       'EHP2_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'EHP2'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'OB') | (
                    self.df.Heating_System == 'COB') | (
                        self.df.Heating_System == 'WPB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'WB') | (self.df.Heating_System == 'EHP')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        A = np.array(self.df.loc[:, 'Maintenance_19_39']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'Maintenance_Different']).reshape(
            self.df.shape[0], 1)
        C = np.array(self.df.loc[:, 'Maintenance_Different_Plus']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.add(matrix, np.multiply(condition_1, A)) + np.add(
            matrix, np.multiply(condition_2, B)) + np.add(
                matrix, np.multiply(condition_3, C))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_matrix
        return self.df

    def Multiple_Cost_WB(self):
        self.Multiple_Cost_EHP2()
        selected_columns = self.df.loc[:, 'WB_m0_w0_r0_f0':
                                       'WB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'WB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'EHP')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'OB') | (
                    self.df.Heating_System == 'COB') | (
                        self.df.Heating_System == 'EHP2') | (
                            self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        A = np.array(self.df.loc[:, 'Maintenance_19_39']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'Maintenance_Same']).reshape(
            self.df.shape[0], 1)
        C = np.array(self.df.loc[:, 'Maintenance_Different_Plus']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.add(matrix, np.multiply(condition_1, A)) + np.add(
            matrix, np.multiply(condition_2, B)) + np.add(
                matrix, np.multiply(condition_3, C))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_matrix
        return self.df

    def Multiple_Cost_WPB(self):
        self.Multiple_Cost_WB()
        selected_columns = self.df.loc[:, 'WPB_m0_w0_r0_f0':
                                       'WPB_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'WPB'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'WB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'OB') | (
                    self.df.Heating_System == 'COB') | (
                        self.df.Heating_System == 'EHP2')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        condition_4 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'EHP')
        condition_4 = np.array(condition_4).reshape(self.df.shape[0], 1)
        A = np.array(self.df.loc[:, 'Maintenance_19_39']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'Maintenance_Same_Plus']).reshape(
            self.df.shape[0], 1)
        C = np.array(self.df.loc[:, 'Maintenance_Different']).reshape(
            self.df.shape[0], 1)
        D = np.array(self.df.loc[:, 'Maintenance_Different_Plus']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.add(matrix, np.multiply(condition_1, A)) + np.add(
            matrix, np.multiply(condition_2, B)) + np.add(
                matrix, np.multiply(condition_3, C)) + np.add(
                    matrix, np.multiply(condition_4, D))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, condition_3, condition_4, A, B, C, D, matrix, df_matrix
        return self.df

    def Multiple_Cost_EHP(self):
        self.Multiple_Cost_WPB()
        selected_columns = self.df.loc[:, 'EHP_m0_w0_r0_f0':
                                       'EHP_m18_w3_r3_f5'].columns.tolist()
        condition_1 = self.df.Heating_System == 'EHP'
        condition_1 = np.array(condition_1).reshape(self.df.shape[0], 1)
        condition_2 = (self.df.Heating_System == 'ER') | (
            self.df.Heating_System == 'WB')
        condition_2 = np.array(condition_2).reshape(self.df.shape[0], 1)
        condition_3 = (self.df.Heating_System == 'GB') | (
            self.df.Heating_System == 'CGB') | (
                self.df.Heating_System == 'OB') | (
                    self.df.Heating_System == 'COB') | (
                        self.df.Heating_System == 'EHP2') | (
                            self.df.Heating_System == 'WPB')
        condition_3 = np.array(condition_3).reshape(self.df.shape[0], 1)
        A = np.array(self.df.loc[:, 'Maintenance_19_39']).reshape(
            self.df.shape[0], 1)
        B = np.array(self.df.loc[:, 'Maintenance_Same']).reshape(
            self.df.shape[0], 1)
        C = np.array(self.df.loc[:, 'Maintenance_Different_Plus']).reshape(
            self.df.shape[0], 1)
        matrix = self.df[selected_columns].values
        matrix = np.add(matrix, np.multiply(condition_1, A)) + np.add(
            matrix, np.multiply(condition_2, B)) + np.add(
                matrix, np.multiply(condition_3, C))
        df_matrix = pd.DataFrame(matrix, columns=selected_columns)
        self.df[selected_columns] = df_matrix
        del condition_1, condition_2, condition_3, A, B, C, matrix, df_matrix
        return self.df

# %%
c = DF_for_CD_U_Factors(Prepared_df_CID_UF)
d = c.GHC_UEN_EHP()

# %%
d.ER_m0_w0_r0_f0
# Out:
# 0        53534.743983
# 1        53462.925848
# 2        53394.527624
# 3        53329.386459
# 4        53267.347253
# 5        53208.262296
# 6        53151.990908
# 7        53098.399110
# 8        53047.359302
# 9        52998.749962
# 10       52952.455352
# 11       52908.365247
# 12       52866.374671
# 13       52826.383646
# 14       52788.296956
# 15       52752.023917
# 16       52717.478167
# 17       52684.577451
# 18       52653.243437
# 19       52623.401519
# 20       26471.041629
# 21       26471.041629
# 22       26471.041629
# 23       26471.041629
# 24       26471.041629
# 25       26471.041629
# 26       26471.041629
# 27       26471.041629
# 28       26471.041629
# 29       26471.041629
#              ...
# 11310     3227.840306
# 11311     3227.840306
# 11312     3227.840306
# 11313     3227.840306
# 11314     3227.840306
# 11315     3227.840306
# 11316     3227.840306
# 11317     3227.840306
# 11318     3227.840306
# 11319     3227.840306
# 11320     6392.855901
# 11321     6392.855901
# 11322     6392.855901
# 11323     6392.855901
# 11324     6392.855901
# 11325     6392.855901
# 11326     6392.855901
# 11327     6392.855901
# 11328     6392.855901
# 11329     6392.855901
# 11330     6392.855901
# 11331     6392.855901
# 11332     6392.855901
# 11333     6392.855901
# 11334     6392.855901
# 11335     6392.855901
# 11336     6392.855901
# 11337     6392.855901
# 11338     6392.855901
# 11339     6392.855901
# Name: ER_m0_w0_r0_f0, Length: 11340, dtype: float64

# %%
d
# Out:
#       Dwelling_Type Climate_Type  Degrees_of_Reference Construction_Period  \
# 0               CID           H1                 59488               <1948
# 1               CID           H1                 59488               <1948
# 2               CID           H1                 59488               <1948
# 3               CID           H1                 59488               <1948
# 4               CID           H1                 59488               <1948
# 5               CID           H1                 59488               <1948
# 6               CID           H1                 59488               <1948
# 7               CID           H1                 59488               <1948
# 8               CID           H1                 59488               <1948
# 9               CID           H1                 59488               <1948
# 10              CID           H1                 59488               <1948
# 11              CID           H1                 59488               <1948
# 12              CID           H1                 59488               <1948
# 13              CID           H1                 59488               <1948
# 14              CID           H1                 59488               <1948
# 15              CID           H1                 59488               <1948
# 16              CID           H1                 59488               <1948
# 17              CID           H1                 59488               <1948
# 18              CID           H1                 59488               <1948
# 19              CID           H1                 59488               <1948
# 20              CID           H1                 59488               <1948
# 21              CID           H1                 59488               <1948
# 22              CID           H1                 59488               <1948
# 23              CID           H1                 59488               <1948
# 24              CID           H1                 59488               <1948
# 11318       Large     94.0            2.60              0.30
# 11319       Large     94.0            2.60              0.30
# 11320       Large     94.0            2.60              0.30
# 11321       Large     94.0            2.60              0.30
# 11322       Large     94.0            2.60              0.30
# 11323       Large     94.0            2.60              0.30
# 11324       Large     94.0            2.60              0.30
# 11325       Large     94.0            2.60              0.30
# 11326       Large     94.0            2.60              0.30
# 11327       Large     94.0            2.60              0.30
# 11328       Large     94.0            2.60              0.30
# 11329       Large     94.0            2.60              0.30
# 11330       Large     94.0            2.60              0.30
# 11331       Large     94.0            2.60              0.30
# 11332       Large     94.0            2.60              0.30
# 11333       Large     94.0            2.60              0.30
# 11334       Large     94.0            2.60              0.30
# 11335       Large     94.0            2.60              0.30
# 11336       Large     94.0            2.60              0.30
# 11337       Large     94.0            2.60              0.30
# 11338       Large     94.0            2.60              0.30
# 11339       Large     94.0            2.60              0.30
#
#        Dwelling_per_Floor  Floors  ...  EHP_m18_w3_r2_f2 EHP_m18_w3_r2_f3  \
# 0                       2       5  ...      12330.942293     12070.881753
# 1                       2       5  ...      12330.942293     12070.881753
# 2                       2       5  ...      12330.942293     12070.881753
# 3                       2       5  ...      12330.942293     12070.881753
# 4                       2       5  ...      12330.942293     12070.881753
# 5                       2       5  ...      12330.942293     12070.881753
# 6                       2       5  ...      12330.942293     12070.881753
# 7                       2       5  ...      12330.942293     12070.881753
# 8                       2       5  ...      12330.942293     12070.881753
# 9                       2       5  ...      12330.942293     12070.881753
# 10                      2       5  ...      12330.942293     12070.881753
# 11                      2       5  ...      12330.942293     12070.881753
# 12                      2       5  ...      12330.942293     12070.881753
# 13                      2       5  ...      12330.942293     12070.881753
# 14                      2       5  ...
# <b>limit_output extension: Maximum message size of 10000 exceeded with 33217 characters</b>

# %%
d.GHC_Total_Prices_19_39
# Out:
# 0        4.788674
# 1        4.782250
# 2        4.776132
# 3        4.770305
# 4        4.764756
# 5        4.759471
# 6        4.754437
# 7        4.749643
# 8        4.745078
# 9        4.740730
# 10       4.736589
# 11       4.732645
# 12       4.728889
# 13       4.725312
# 14       4.721905
# 15       4.718660
# 16       4.715570
# 17       4.712627
# 18       4.709824
# 19       4.707155
# 20       2.308371
# 21       2.304517
# 22       2.300846
# 23       2.297350
# 24       2.294020
# 25       2.290849
# 26       2.287829
# 27       2.284952
# 28       2.282213
# 29       2.279604
#            ...
# 11310    1.301480
# 11311    1.298851
# 11312    1.296347
# 11313    1.293962
# 11314    1.291691
# 11315    1.289528
# 11316    1.287468
# 11317    1.285506
# 11318    1.283637
# 11319    1.281857
# 11320    2.645115
# 11321    2.636549
# 11322    2.628392
# 11323    2.620622
# 11324    2.613223
# 11325    2.606176
# 11326    2.599465
# 11327    2.593073
# 11328    2.586986
# 11329    2.581189
# 11330    2.575667
# 11331    2.570409
# 11332    2.565401
# 11333    2.560631
# 11334    2.556089
# 11335    2.551762
# 11336    2.547642
# 11337    2.543718
# 11338    2.539981
# 11339    2.536422
# Name: GHC_Total_Prices_19_39, Length: 11340, dtype: float64

# %% [markdown]
# ## Qin

# %%
A = Columns_for_CxD_U_Prices(df_CID_UP, 0)
B = A.Add_Created_Columns()
C = DF_for_CD_U_Prices(B)
D = C.Multiple_Cost_EHP()

# %%
D.ER_m0_w0_r0_f0
# Out:
# 0        5.576137e+02
# 1        5.310607e+02
# 2        5.057721e+02
# 3        4.816877e+02
# 4        4.587502e+02
# 5        4.369049e+02
# 6        4.160999e+02
# 7        3.962856e+02
# 8        3.774149e+02
# 9        3.594428e+02
# 10       3.423264e+02
# 11       3.260252e+02
# 12       3.105002e+02
# 13       2.957144e+02
# 14       2.816328e+02
# 15       2.682217e+02
# 16       2.554493e+02
# 17       2.432850e+02
# 18       2.317000e+02
# 19       2.206667e+02
# 20       1.907229e+05
# 21       1.907229e+05
# 22       1.907229e+05
# 23       1.907229e+05
# 24       1.907229e+05
# 25       1.907229e+05
# 26       1.907229e+05
# 27       1.907229e+05
# 28       1.907229e+05
# 29       1.907229e+05
#              ...
# 11310    1.380130e+06
# 11311    1.380130e+06
# 11312    1.380130e+06
# 11313    1.380130e+06
# 11314    1.380130e+06
# 11315    1.380130e+06
# 11316    1.380130e+06
# 11317    1.380130e+06
# 11318    1.380130e+06
# 11319    1.380130e+06
# 11320    1.382004e+04
# 11321    1.382004e+04
# 11322    1.382004e+04
# 11323    1.382004e+04
# 11324    1.382004e+04
# 11325    1.382004e+04
# 11326    1.382004e+04
# 11327    1.382004e+04
# 11328    1.382004e+04
# 11329    1.382004e+04
# 11330    1.382004e+04
# 11331    1.382004e+04
# 11332    1.382004e+04
# 11333    1.382004e+04
# 11334    1.382004e+04
# 11335    1.382004e+04
# 11336    1.382004e+04
# 11337    1.382004e+04
# 11338    1.382004e+04
# 11339    1.382004e+04
# Name: ER_m0_w0_r0_f0, Length: 11340, dtype: float64

# %%
D.Maintenance.loc[20]
# Out:
# 2882.701497630158

# %%
d.No_Gas_Prices.loc[120]
# Out:
# 1.7722233617378393

# %%
np.divide(
    np.multiply(D.Maintenance_Cost, np.power(np.add(1, D.Inflation_Rate), 1)),
    np.power(np.add(1, D.Discount_Rate), 1))
# Out:
# 0          0.000000
# 1          0.000000
# 2          0.000000
# 3          0.000000
# 4          0.000000
# 5          0.000000
# 6          0.000000
# 7          0.000000
# 8          0.000000
# 9          0.000000
# 10         0.000000
# 11         0.000000
# 12         0.000000
# 13         0.000000
# 14         0.000000
# 15         0.000000
# 16         0.000000
# 17         0.000000
# 18         0.000000
# 19         0.000000
# 20       116.571429
# 21       116.571429
# 22       116.571429
# 23       116.571429
# 24       116.571429
# 25       116.571429
# 26       116.571429
# 27       116.571429
# 28       116.571429
# 29       116.571429
#             ...
# 11310    145.714286
# 11311    145.714286
# 11312    145.714286
# 11313    145.714286
# 11314    145.714286
# 11315    145.714286
# 11316    145.714286
# 11317    145.714286
# 11318    145.714286
# 11319    145.714286
# 11320    165.142857
# 11321    165.142857
# 11322    165.142857
# 11323    165.142857
# 11324    165.142857
# 11325    165.142857
# 11326    165.142857
# 11327    165.142857
# 11328    165.142857
# 11329    165.142857
# 11330    165.142857
# 11331    165.142857
# 11332    165.142857
# 11333    165.142857
# 11334    165.142857
4.371620e+06    4.535176e+06    3.323554e+06    7.020197e+06
# 29       4.371620e+06    4.535176e+06    3.323554e+06    7.020197e+06
# ...               ...             ...             ...             ...
# 11310    1.445402e+07    1.496858e+07    1.116073e+07    2.279075e+07
# 11311    1.445402e+07    1.496858e+07    1.116073e+07    2.279075e+07
# 11312    1.445402e+07    1.496858e+07    1.116073e+07    2.279075e+07
# 11313    1.445402e+07    1.496858e+07    1.116073e+07    2.279075e+07
# 11314    1.445402e+07    1.496858e+07    1.116073e+07    2.279075e+07
# 11315    1.445402e+07    1.496858e+07    1.116073e+07    2.279075e+07
# 11316    1.445402e+07    1.496858e+07    1.116073e+07    2.279075e+07
# 11317    1.445402e+07    1.496858e+07    1.116073e+07    2.279075e+07
# 11318    1.445402e+07    1.496858e+07    1.116073e+07    2.279075e+07
# 11319    1.445402e+07    1.496858e+07    1.116073e+07    2.279075e+07
# 11320    1.309090e+07    1.360544e+07    9.797718e+06    2.142796e+07
# 11321    1.309090e+07    1.360544e+07    9.797718e+06    2.142796e+07
# 11322    1.309090e+07    1.360544e+07    9.797718e+06    2.142796e+07
# 11323    1.309090e+07    1.360544e+07    9.797718e+06    2.142796e+07
# 11324    1.309090e+07    1.360544e+07    9.797718e+06    2.142796e+07
# 11325    1.309090e+07    1.360544e+07    9.797718e+06    2.142796e+07
# 11326    1.309090e+07    1.360544e+07    9.797718e+06    2.142796e+07
# 11327    1.309090e+07    1.360544e+07    9.797718e+06    2.142796e+07
# 11328    1.309090e+07    1.360544e+07    9.797718e+06    2.142796e+07
# 11329    1.309090e+07    1.360544e+07    9.797718e+06    2.142796e+07
# 11330    1.309090e+07    1.360544e+07    9.797718e+06    2.142796e+07
# 11331    1.309090e+07    1.360544e+07    9.797718e+06    2.142796e+07
# 11332    1.309090e+07    1.360544e+07    9.797718e+06    2.142796e+07
# 11333    1.309090e+07    1.360544e+07    9.797718e+06    2.142796e+07
# 11334    1.309090e+07    1.360544e+07    9.797718e+06    2.142796e+07
# 11335    1.309090e+07    1.360544e+07    9.797718e+06    2.142796e+07
# 11336    1.309090e+07    1.360544e+07    9.797718e+06    2.142796e+07
# 11337    1.309090e+07    1.360544e+07    9.797718e+06    2.142796e+07
# 11338    1.309090e+07    1.360544e+07    9.797718e+06    2.142796e+07
# 11339    1.309090e+07    1.360544e+07    9.797718e+06    2.142796e+07
#
#        ER_m0_w0_r1_f2  ER_m0_w0_r1_f3  ...  EHP_m18_w3_r2_f2  \
# 0        7.017866e+06    7.148571e+06  ...      2.904984e+09
# 1        7.017775e+06    7.148480e+06  ...      2.904984e+09
# 2        7.017688e+06    7.148393e+06  ...      2.904984e+09
# 3        7.017605e+06    7.148310e+06  ...      2.904984e+09
# 4        7.017526e+06    7.148231e+06  ...      2.904984e+09
# 5        7.017451e+06    7.148156e+06  ...      2.904984e+09
# 6        7.017379e+06    7.148085e+06  ...      2.904984e+09
# 7        7.017311e+06    7.148017e+06  ...      2.904984e+09
# 8        7.017246e+06    7.147952e+06  ...      2.904984e+09
# 9        7.017184e+06    7.147891e+06  ...      2.904984e+09
# 10       7.017125e+06    7.147832e+06  ...      2.904984e+09
# 11       7.017069e+06    7.147776e+06  ...      2.904984e+09
# 12       7.017016e+06    7.147723e+06  ...      2.904984e+09
# 13       7.016965e+06    7.147672e+06  ...      2.
# <b>limit_output extension: Maximum message size of 10000 exceeded with 38541 characters</b>

# %%
columns = total.columns.tolist()
list_all = []
for i in range(1824):
    list_i = columns[i::1824]
    list_all += list_i
list_all
# Out:
# ['ER_m0_w0_r0_f0',
#  'GB_m0_w0_r0_f0',
#  'CGB_m0_w0_r0_f0',
#  'OB_m0_w0_r0_f0',
#  'COB_m0_w0_r0_f0',
#  'EHP2_m0_w0_r0_f0',
#  'WB_m0_w0_r0_f0',
#  'WPB_m0_w0_r0_f0',
#  'EHP_m0_w0_r0_f0',
#  'ER_m0_w0_r0_f1',
#  'GB_m0_w0_r0_f1',
#  'CGB_m0_w0_r0_f1',
#  'OB_m0_w0_r0_f1',
#  'COB_m0_w0_r0_f1',
#  'EHP2_m0_w0_r0_f1',
#  'WB_m0_w0_r0_f1',
#  'WPB_m0_w0_r0_f1',
#  'EHP_m0_w0_r0_f1',
#  'ER_m0_w0_r0_f2',
#  'GB_m0_w0_r0_f2',
#  'CGB_m0_w0_r0_f2',
#  'OB_m0_w0_r0_f2',
#  'COB_m0_w0_r0_f2',
#  'EHP2_m0_w0_r0_f2',
#  'WB_m0_w0_r0_f2',
#  'WPB_m0_w0_r0_f2',
#  'EHP_m0_w0_r0_f2',
#  'ER_m0_w0_r0_f3',
#  'GB_m0_w0_r0_f3',
#  'CGB_m0_w0_r0_f3',
#  'OB_m0_w0_r0_f3',
#  'COB_m0_w0_r0_f3',
#  'EHP2_m0_w0_r0_f3',
#  'WB_m0_w0_r0_f3',
#  'WPB_m0_w0_r0_f3',
#  'EHP_m0_w0_r0_f3',
#  'ER_m0_w0_r0_f4',
#  'GB_m0_w0_r0_f4',
#  'CGB_m0_w0_r0_f4',
#  'OB_m0_w0_r0_f4',
#  'COB_m0_w0_r0_f4',
#  'EHP2_m0_w0_r0_f4',
#  'WB_m0_w0_r0_f4',
#  'WPB_m0_w0_r0_f4',
#  'EHP_m0_w0_r0_f4',
#  'ER_m0_w0_r0_f5',
#  'GB_m0_w0_r0_f5',
#  'CGB_m0_w0_r0_f5',
#  'OB_m0_w0_r0_f5',
#  'COB_m0_w0_r0_f5',
#  'EHP2_m0_w0_r0_f5',
#  'WB_m0_w0_r0_f5',
#  'WPB_m0_w0_r0_f5',
#  'EHP_m0_w0_r0_f5',
#  'ER_m0_w0_r1_f0',
#  'GB_m0_w0_r1_f0',
#  'CGB_m0_w0_r1_f0',
#  'OB_m0_w0_r1_f0',
#  'COB_m0_w0_r1_f0',
#  'EHP2_m0_w0_r1_f0',
#  'WB_m0_w0_r1_f0',
#  'WPB_m0_w0_r1_f0',
#  'EHP_m0_w0_r1_f0',
#  'ER_m0_w0_r1_f1',
#  'GB_m0_w0_r1_f1',
#  'CGB_m0_w0_r1_f1',
#  'OB_m0_w0_r1_f1',
#  'COB_m0_w0_r1_f1',
#  'EHP2_m0_w0_r1_f1',
#  'WB_m0_w0_r1_f1',
#  'WPB_m0_w0_r1_f1',
#  'EHP_m0_w0_r1_f1',
#  'ER_m0_w0_r1_f2',
#  'GB_m0_w0_r1_f2',
#  'CGB_m0_w0_r1_f2',
#  'OB_m0_w0_r1_f2',
#  'COB_m0_w0_r1_f2',
#  'EHP2_m0_w0_r1_f2',
#  'WB_m0_w0_r1_f2',
#  'WPB_m0_w0_r1_f2',
#  'EHP_m0_w0_r1_f2',
#  'ER_m0_w0_r1_f3',
#  'GB_m0_w0_r1_f3',
#  'CGB_m0_w0_r1_f3',
#  'OB_m0_w0_r1_f3',
#  'COB_m0_w0_r1_f3',
#  'EHP2_m0_w0_r1_f3',
#  'WB_m0_w0_r1_f3',
#  'WPB_m0_w0_r1_f3',
#  'EHP_m0_w0_r1_f3',
#  'ER_m0_w0_r1_f4',
#  'GB_m0_w0_r1_f4',
#  'CGB_m0_w0_r1_f4',
#  'OB_m0_w0_r1_f4',
#  'COB_m0_w0_r1_f4',
#  'EHP2_m0_w0_r1_f4',
#  'WB_m0_w0_r1_f4',
#  'WPB_m0_w0_r1_f4',
#  'EHP_m0_w0_r1_f4',
#  'ER_m0_w0_r1_f5',
#  'GB_m0_w0_r1_f5',
#  'CGB_m0_w0_r1_f5',
#  'OB_m0_w0_r1_f5',
#  'COB_m0_w0_r1_f5',
#  'EHP2_m0_w0_r1_f5',
#  'WB_m0_w0_r1_f5',
#  'WPB_m0_w0_r1_f5',
#  'EHP_m0_w0_r1_f5',
#  'ER_m0_w0_r2_f0',
#  'GB_m0_w0_r2_f0',
#  'CGB_m0_w0_r2_f0',
#  'OB_m0_w0_r2_f0',
#  'COB_m0_w0_r2_f0',
#  'EHP2_m0_w0_r2_f0',
#  'WB_m0_w0_r2_f0',
#  'WPB_m0_w0_r2_f0',
#  'EHP_m0_w0_r2_f0',
#  'ER_m0_w0_r2_f1',
#  'GB_m0_w0_r2_f1',
#  'CGB_m0_w0_r2_f1',
#  'OB_m0_w0_r2_f1',
#  'COB_m0_w0_r2_f1',
#  'EHP2_m0_w0_r2_f1',
#  'WB_m0_w0_r2_f1',
#  'WPB_m0_w0_r2_f1',
#  'EHP_m0_w0_r2_f1',
#  'ER_m0_w0_r2_f2',
#  'GB_m0_w0_r2_f2',
#  'CGB_m0_w0_r2_f2',
#  'OB_m0_w0_r2_f2',
#  'COB_m0_w0_r2_f2',
#  'EHP2_m0_w0_r2_f2',
#  'WB_m0_w0_r2_f2',
#  'WPB_m0_w0_r2_f2',
#  'EHP_m0_w0_r2_f2',
#  'ER_m0_w0_r2_f3',
#  'GB_m0_w0_r2_f3',
#  'CGB_m0_w0_r2_f3',
#  'OB_m0_w0_r2_f3',
#  'COB_m0_w0_r2_f3',
#  'EHP2_m0_w0_r2_f3',
#  'WB_m0_w0_r2_f3',
#  'WPB_m0_w0_r2_f3',
#  'EHP_m0_w0_r2_f3',
#  'ER_m0_w0_r2_f4',
#  'GB_m0_w0_r2_f4',
#  'CGB_m0_w0_r2_f4',
#  'OB_m0_w0_r2_f4',
#  'COB_m0_w0_r2_f4',
#  'EHP2_m0_w0_r2_f4',
#  'WB_m0_w0_r2_f4',
#  'WPB_m0_w0_r2_f4',
#  'EHP_m0_w0_r2_f4',
#  'ER_m0_w0_r2_f5',
#  'GB_m0_w0_r2_f5',
#  'CGB_m0_w0_r2_f5',
#  'OB_m0_w0_r2_f5',
#  'COB_m0_w0_r2_f5',
#  'EHP2_m0_w0_r2_f5',
#  'WB_m0_w0_r2_f5',
#  'WPB_m0_w0_r2_f5',
#  'EHP_m0_w0_r2_f5',
#  'ER_m0_w0_r3_f0',
#  'GB_m0_w0_r3_f0',
#  'CGB_m0_w0_r3_f0',
#  'OB_m0_w0_r3_f0',
#  'COB_m0_w0_r3_f0',
#  'EHP2_m0_w0_r3_f0',
#  'WB_m0_w0_r3_f0',
#  'WPB_m0_w0_r3_f0',
#  'EHP_m0_w0_r3_f0',
#  'ER_m0_w0_r3_f1',
#  'GB_m0_w0_r3_f1',
#  'CGB_m0_w0_r3_f1',
#  'OB_m0_w0_r3_f1',
#  'COB_m0_w0_r3_f1',
#  'EHP2_m0_w0_r3_f1',
#  'WB_m0_w0_r3_f1',
#  'WPB_m0_w0_r3_f1',
#  'EHP_m0_w0_r3_f1',
#  'ER_m0_w0_r3_f2',
#  'GB_m0_w0_r3_f2',
#  'CGB_m0_w0_r3_f2',
#  'OB_m0_w0_r3_f2',
#  'COB_m0_w0_r3_f2',
#  'EHP2_m0_w0_r3_f2',
#  'WB_m0_w0_r3_f2',
#  'WPB_m0_w0_r3_f2',
#  'EHP_m0_w0_r3_f2',
#  'ER_m0_w0_r3_f3',
#  'GB_m0_w0_r3_f3',
#  'CGB_m0_w0_r3_f3',
#  'OB_m0_w0_r3_f3',
#  'COB_m0_w0_r3_f3',
#  'EHP2_m0_w0_r3_f3',
#  'WB_m0_w0_r3_f3',
#  'WPB_m0_w0_r3_f3',
#  'EHP_m0_w0_r3_f3',
#  'ER_m0_w0_r3_f4',
#  'GB_m0_w0_r3_f4',
#  'CGB_m0_w0_r3_f4',
#  'OB_m0_w0_r3_f4',
#  'COB_m0_w0_r3_f4',
#  'EHP2_m0_w0_r3_f4',
#  'WB_m0_w0_r3_f4',
#  'WPB_m0_w0_r3_f4',
#  'EHP_m0_w0_r3_f4',
#  'ER_m0_w0_r3_f5',
#  'GB_m0_w0_r3_f5',
#  'CGB_m0_w0_r3_f5',
#  'OB_m0_w0_r3_f5',
#  'COB_m0_w0_r3_f5',
#  'EHP2_m0_w0_r3_f5',
#  'WB_m0_w0_r3_f5',
#  'WPB_m0_w0_r3_f5',
#  'EHP_m0_w0_r3_f5',
#  'ER_m0_w1_r0_f0',
#  'GB_m0_w1_r0_f0',
#  'CGB_m0_w1_r0_f0',
#  'OB_m0_w1_r0_f0',
#  'COB_m0_w1_r0_f0',
#  'EHP2_m0_w1_r0_f0',
#  'WB_m0_w1_r0_f0',
#  'WPB_m0_w1_r0_f0',
#  'EHP_m0_w1_r0_f0',
#  'ER_m0_w1_r0_f1',
#  'GB_m0_w1_r0_f1',
#  'CGB_m0_w1_r0_f1',
#  'OB_m0_w1_r0_f1',
#  'COB_m0_w1_r0_f1',
#  'EHP2_m0_w1_r0_f1',
#  'WB_m0_w1_r0_f1',
#  'WPB_m0_w1_r0_f1',
#  'EHP_m0_w1_r0_f1',
#  'ER_m0_w1_r0_f2',
#  'GB_m0_w1_r0_f2',
#  'CGB_m0_w1_r0_f2',
#  'OB_m0_w1_r0_f2',
#  'COB_m0_w1_r0_f2',
#  'EHP2_m0_w1_r0_f2',
#  'WB_m0_w1_r0_f2',
#  'WPB_m0_w1_r0_f2',
#  'EHP_m0_w1_r0_f2',
#  'ER_m0_w1_r0_f3',
#  'GB_m0_w1_r0_f3',
#  'CGB_m0_w1_r0_f3',
#  'OB_m0_w1_r0_f3',
#  'COB_m0_w1_r0_f3',
#  'EHP2_m0_w1_r0_f3',
#  'WB_m0_w1_r0_f3',
#  'WPB_m0_w1_r0_f3',
#  'EHP_m0_w1_r0_f3',
#  'ER_m0_w1_r0_f4',
#  'GB_m0_w1_r0_f4',
#  'CGB_m0_w1_r0_f4',
#  'OB_m0_w1_r0_f4',
#  'COB_m0_w1_r0_f4',
#  'EHP2_m0_w1_r0_f4',
#  'WB_m0_w1_r0_f4',
#  'WPB_m0_w1_r0_f4',
#  'EHP_m0_w1_r0_f4',
#  'ER_m0_w1_r0_f5',
#  'GB_m0_w1_r0_f5',
#  'CGB_m0_w1_r0_f5',
#  'OB_m0_w1_r0_f5',
#  'COB_m0_w1_r0_f5',
#  'EHP2_m0_w1_r0_f5',
#  'WB_m0_w1_r0_f5',
#  'WPB_m0_w1_r0_f5',
#  'EHP_m0_w1_r0_f5',
#  'ER_m0_w1_r1_f0',
#  'GB_m0_w1_r1_f0',
#  'CGB_m0_w1_r1_f0',
#  'OB_m0_w1_r1_f0',
#  'COB_m0_w1_r1_f0',
#  'EHP2_m0_w1_r1_f0',
#  'WB_m0_w1_r1_f0',
#  'WPB_m0_w1_r1_f0',
#  'EHP_m0_w1_r1_f0',
#  'ER_m0_w1_r1_f1',
#  'GB_m0_w1_r1_f1',
#  'CGB_m0_w1_r1_f1',
#  'OB_m0_w1_r1_f1',
#  'COB_m0_w1_r1_f1',
#  'EHP2_m0_w1_r1_f1',
#  'WB_m0_w1_r1_f1',
#  'WPB_m0_w1_r1_f1',
#  'EHP_m0_w1_r1_f1',
#  'ER_m0_w1_r1_f2',
#  'GB_m0_w1_r1_f2',
#  'CGB_m0_w1_r1_f2',
#  'OB_m0_w1_r1_f2',
#  'COB_m0_w1_r1_f2',
#  'EHP2_m0_w1_r1_f2',
#  'WB_m0_w1_r1_f2',
#  'WPB_m0_w1_r1_f2',
#  'EHP_m0_w1_r1_f2',
#  'ER_m0_w1_r1_f3',
#  'GB_m0_w1_r1_f3',
#  'CGB_m0_w1_r1_f3',
#  'OB_m0_w1_r1_f3',
#  'COB_m0_w1_r1_f3',
#  'EHP2_m0_w1_r1_f3',
#  'WB_m0_w1_r1_f3',
#  'WPB_m0_w1_r1_f3',
#  'EHP_m0_w1_r1_f3',
#  'ER_m0_w1_r1_f4',
#  'GB_m0_w1_r1_f4',
#  'CGB_m0_w1_r1_f4',
#  'OB_m0_w1_r1_f4',
#  'COB_m0_w1_r1_f4',
#  'EHP2_m0_w1_r1_f4',
#  'WB_m0_w1_r1_f4',
#  'WPB_m0_w1_r1_f4',
#  'EHP_m0_w1_r1_f4',
#  'ER_m0_w1_r1_f5',
#  'GB_m0_w1_r1_f5',
#  'CGB_m0_w1_r1_f5',
#  'OB_m0_w1_r1_f5',
#  'COB_m0_w1_r1_f5',
#  'EHP2_m0_w1_r1_f5',
#  'WB_m0_w1_r1_f5',
#  'WPB_m0_w1_r1_f5',
#  'EHP_m0_w1_r1_f5',
#  'ER_m0_w1_r2_f0',
#  'GB_m0_w1_r2_f0',
#  'CGB_m0_w1_r2_f0',
#  'OB_m0_w1_r2_f0',
#  'COB_m0_w1_r2_f0',
#  'EHP2_m0_w1_r2_f0',
#  'WB_m0_w1_r2_f0',
#  'WPB_m0_w1_r2_f0',
#  'EHP_m0_w1_r2_f0',
#  'ER_m0_w1_r2_f1',
#  'GB_m0_w1_r2_f1',
#  'CGB_m0_w1_r2_f1',
#  'OB_m0_w1_r2_f1',
#  'COB_m0_w1_r2_f1',
#  'EHP2_m0_w1_r2_f1',
#  'WB_m0_w1_r2_f1',
#  'WPB_m0_w1_r2_f1',
#  'EHP_m0_w1_r2_f1',
#  'ER_m0_w1_r2_f2',
#  'GB_m0_w1_r2_f2',
#  'CGB_m0_w1_r2_f2',
#  'OB_m0_w1_r2_f2',
#  'COB_m0_w1_r2_f2',
#  'EHP2_m0_w1_r2_f2',
#  'WB_m0_w1_r2_f2',
#  'WPB_m0_w1_r2_f2',
#  'EHP_m0_w1_r2_f2',
#  'ER_m0_w1_r2_f3',
#  'WPB_m0_w1_r3_f5',
#  'EHP_m0_w1_r3_f5',
#  'ER_m0_w2_r0_f0',
#  'GB_m0_w2_r0_f0',
#  'CGB_m0_w2_r0_f0',
#  'OB_m0_w2_r0_f0',
#  'COB_m0_w2_r0_f0',
#  'EHP2_m0_w2_r0_f0',
#  'WB_m0_w2_r0_f0',
#  'WPB_m0_w2_r0_f0',
#  'EHP_m0_w2_r0_f0',
#  'ER_m0_w2_r0_f1',
#  'GB_m0_w2_r0_f1',
#  'CGB_m0_w2_r0_f1',
#  'OB_m0_w2_r0_f1',
#  'COB_m0_w2_r0_f1',
#  'EHP2_m0_w2_r0_f1',
#  'WB_m0_w2_r0_f1',
#  'WPB_m0_w2_r0_f1',
#  'EHP_m0_w2_r0_f1',
#  'ER_m0_w2_r0_f2',
#  'GB_m0_w2_r0_f2',
#  'CGB_m0_w2_r0_f2',
#  'OB_m0_w2_r0_f2',
#  'COB_m0_w2_r0_f2',
#  'EHP2_m0_w2_r0_f2',
#  'WB_m0_w2_r0_f2',
#  'WPB_m0_w2_r0_f2',
#  'EHP_m0_w2_r0_f2',
#  'ER_m0_w2_r0_f3',
#  'GB_m0_w2_r0_f3',
#  'CGB_m0_w2_r0_f3',
#  'OB_m0_w2_r0_f3',
#  'COB_m0_w2_r0_f3',
#  'EHP2_m0_w2_r0_f3',
#  'WB_m0_w2_r0_f3',
#  'WPB_m0_w2_r0_f3',
#  'EHP_m0_w2_r0_f3',
#  'ER_m0_w2_r0_f4',
#  'GB_m0_w2_r0_f4',
#  'CGB_m0_w2_r0_f4',
#  'OB_m0_w2_r0_f4',
#  'COB_m0_w2_r0_f4',
#  'EHP2_m0_w2_r0_f4',
#  'WB_m0_w2_r0_f4',
#  'WPB_m0_w2_r0_f4',
#  'EHP_m0_w2_r0_f4',
#  'ER_m0_w2_r0_f5',
#  'GB_m0_w2_r0_f5',
#  'CGB_m0_w2_r0_f5',
#  'OB_m0_w2_r0_f5',
#  'COB_m0_w2_r0_f5',
#  'EHP2_m0_w2_r0_f5',
#  'WB_m0_w2_r0_f5',
#  'WPB_m0_w2_r0_f5',
#  'EHP_m0_w2_r0_f5',
#  'ER_m0_w2_r1_f0',
#  'GB_m0_w2_r1_f0',
#  'CGB_m0_w2_r1_f0',
#  'OB_m0_w2_r1_f0',
#  'COB_m0_w2_r1_f0',
#  'EHP2_m0_w2_r1_f0',
#  'WB_m0_w2_r1_f0',
#  'WPB_m0_w2_r1_f0',
#  'EHP_m0_w2_r1_f0',
#  'ER_m0_w2_r1_f1',
#  'GB_m0_w2_r1_f1',
#  'CGB_m0_w2_r1_f1',
#  'OB_m0_w2_r1_f1',
#  'COB_m0_w2_r1_f1',
#  'EHP2_m0_w2_r1_f1',
#  'WB_m0_w2_r1_f1',
#  'WPB_m0_w2_r1_f1',
#  'EHP_m0_w2_r1_f1',
#  'ER_m0_w2_r1_f2',
#  'GB_m0_w2_r1_f2',
#  'CGB_m0_w2_r1_f2',
#  'OB_m0_w2_r1_f2',
#  'COB_m0_w2
# 11334           20212            6392             6392            6392
# 11335           20212            6392             6392            6392
# 11336           20212            6392             6392            6392
# 11337           20212            6392             6392            6392
# 11338           20212            6392             6392            6392
# 11339           20212            6392             6392            6392
#
#        COB_m0_w0_r0_f0  EHP2_m0_w0_r0_f0  WB_m0_w0_r0_f0  WPB_m0_w0_r0_f0  \
# 0                54642             54642           54642            54642
# 1                54642             54642           54642            54642
# 2                54642             54642           54642            54642
# 3                54642             54642           54642            54642
# 4                54642             54642           54642            54642
# 5                54642             54642           54642            54642
# 6                54642             54642           54642            54642
# 7                54642             54642           54642            54642
# 8                54642             54642           54642            54642
# 9                54642             54642           54642            54642
# 10               54642             54642           54642            54642
# 11               54642             54642           54642            54642
# 12               54642             54642           54642            54642
# 13               54642             54642           54642            54642
# 14               54642             54642           54642            54642
# 15               54642             54642           54642            54642
# 16               54642             54642           54642            54642
# 17               54642             54642           54642            54642
# 18               54642             54642           54642            54642
# 19               54642             54642           54642            54642
# 20               26471             26471           26471            26471
# 21               26471             26471           26471            26471
# 22               26471             26471           26471            26471
# 23               26471             26471           26471            26471
# 24               26471             26471           26471            26471
# 25               26471             26471           26471            26471
# 26               26471             26471           26471            26471
# 27               26471             26471           26471            26471
# 28               26471             26471           26471            26471
# 29               26471             26471           26471            26471
# ...                ...               ...             ...              ...
# 11310             3227              3227            3227             2995
# 11311             3227              3227            3227             2989
# 11312             3227              3227            3227             2984
# 11313             3227              3227            3227             2978
# 11314             3227              3227            3227             2973
# 11315             3227              3227            3227             2968
# 11316             3227              3227            3227             2963
# 11317             3227              3227            3227             2959
# 11318             3227              3227            3227             2954
# 11319             3227              3227            3227             2950
# 11320             6392              6392            6392             6392
# 11321             6392              6392            6392             6392
# 11322             6392              6392            6392             6392
# 11323             6392              6392            6392             6392
# 11324             6392              6392            6392             6392
# 11325             6392              6392            6392             6392
# 11326             6392              6392            6392             6392
# 11327             6392              6392            6392             6392
# 11328             6392              6392            6392             6392
# 11329             6392              6392            6392             6392
# 11330             6392              6392            6392             6392
# 11331             6392              6392            6392             6392
# 11332             6392              6392            6392             6392
# 11333             6392              6392            6392             6392
# 11334             6392              6392            6392             6392
# 11335             6392              6392            6392             6392
# 11336             6392              6392            6392             6392
# 11337             6392              6392            6392             6392
# 11338             6392              6392            6392             6392
# 11339             6392              6392            6392             6392
#
#        EHP_m0_w0_r0_f0  ER_m0_w0_r0_f1  ...  EHP_m18_w3_r3_f4  \
# 0                54642          419752  ...          22551895
# 1                54642          419655  ...          22551895
# 2                54642          419562  ...          22551895
# 3                54642          419474  ...          22551895
# 4                54642          419390  ...          22551895
# 5                54642          419310  ...          22551895
# 6                54642          419234  ...          22551895
# 7                54642          419162  ...          22551895
# 8                54642          419093  ...
# <b>limit_output extension: Maximum message size of 10000 exceeded with 31804 characters</b>

# %%
D[selected_columns]

# %%
D.Maintenance_19_39

# %%
d.GHC_Total_Prices_19_39

# %%
#total.to_csv('../Output_Data_CSV/Combination_with_Input_Data/total.csv',
#             sep=';',
#             index=None,
#             header=True,
#             encoding='utf-8')
